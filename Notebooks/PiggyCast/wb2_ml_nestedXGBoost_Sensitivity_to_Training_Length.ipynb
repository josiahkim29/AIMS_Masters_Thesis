# %%
# @title Import Libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import joblib
from collections import defaultdict
from pprint import pprint

from sklearn.model_selection import KFold, cross_validate, TimeSeriesSplit
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import xgboost

import matplotlib.dates as mdates
from datetime import timedelta
from dateutil.relativedelta import relativedelta

# %%
# @title Mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# drive_data_path = "/content/drive/Shareddrives/Ishango/Programs/AIMS_MSc_Theses_Supervision/AIWP/Project26_MLStacking/data/oliver/"
# df = pd.read_pickle(drive_data_path + "era5_ml_setup_500geopotential_32x64_2020.pkl")
# data_path = "/content/drive/MyDrive/_shared_drive_shortcut/MastersProject/Data/"

# data_path = "/content/drive/MyDrive/_shared/MastersProject/Data/"
# data_plot_path = "/content/drive/MyDrive/_shared/MastersProject/Plots/"

data_path="/content/drive/MyDrive/MastersProject/Data/"
data_plot_path="/content/drive/MyDrive/MastersProject/Plots/"

# %%
# @title Load forecasts & ERA5 truth

df =pd.read_pickle(data_path+"era5_ml_setup_500geopotential_32x64_2020.pkl")

lead_times=[48, 72, 96, 120, 144, 168, 192, 216, 240]
# lead_times=[48]

for lead_time in lead_times:
    print(lead_time)
    df_aiwp = pd.read_pickle(data_path + f"aiwp_ml_setup_500geopotential_32x64_2020_leadtime{lead_time}.pkl").drop(columns=["area_weight"])
    df_aiwp = df_aiwp.rename(columns={col: col + "_lt" + str(lead_time) for col in df_aiwp.columns if col not in ["time", "longitude", "latitude"]})
    if lead_time == 48:
      df_aiwp_full = df_aiwp
    else:
      df_aiwp_full = df_aiwp_full.merge(df_aiwp, on=["time", "longitude", "latitude"], how="outer")

print(f"Shape of df :{df.shape}")
print(f"Shape of df_aiwp_full :{df_aiwp_full.shape}")
# Out:
# 48
# 72
# 96
# 120
# 144
# 168
# 192
# 216
# 240
# Shape of df :(1556480, 5)
# Shape of df_aiwp_full :(1531904, 48)

# %%
# @title Merge ERA5 and Forecasts Across all lead times
full_df = df.merge(df_aiwp_full, on=["time", "longitude", "latitude"], how="outer")
print(full_df.shape)
full_df.head()
# Out:
# (1556480, 50)
#         time  longitude  latitude          era5  area_weight  graphcast_lt48  \
# 0 2020-01-01        0.0  -87.1875  49846.941406     0.049068             NaN
# 1 2020-01-01        0.0  -81.5625  50196.523438     0.146730             NaN
# 2 2020-01-01        0.0  -75.9375  50391.101562     0.242980             NaN
# 3 2020-01-01        0.0  -70.3125  49667.398438     0.336890             NaN
# 4 2020-01-01        0.0  -64.6875  49277.945312     0.427555             NaN
#
#    pangu_lt48  neuralgcm_lt48  keisler_lt48  ifshres_lt48  ...  \
# 0         NaN             NaN           NaN           NaN  ...
# 1         NaN             NaN           NaN           NaN  ...
# 2         NaN             NaN           NaN           NaN  ...
# 3         NaN             NaN           NaN           NaN  ...
# 4         NaN             NaN           NaN           NaN  ...
#
#    graphcast_lt216  pangu_lt216  neuralgcm_lt216  keisler_lt216  \
# 0              NaN          NaN              NaN            NaN
# 1              NaN          NaN              NaN            NaN
# 2              NaN          NaN              NaN            NaN
# 3              NaN          NaN              NaN            NaN
# 4              NaN          NaN              NaN            NaN
#
#    ifshres_lt216  graphcast_lt240  pangu_lt240  neuralgcm_lt240  \
# 0            NaN              NaN          NaN              NaN
# 1            NaN              NaN          NaN              NaN
# 2            NaN              NaN          NaN              NaN
# 3            NaN              NaN          NaN              NaN
# 4            NaN              NaN          NaN              NaN
#
#    keisler_lt240  ifshres_lt240
# 0            NaN            NaN
# 1            NaN            NaN
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN
#
# [5 rows x 50 columns]

# %%
# @title Filter for subset of data for each lead time

def data_per_lead_time(df,lead_time):
  valid_time_lower = df['time'][0]+timedelta(days=int(lead_time/24))
  valid_time_upper = valid_time_lower + relativedelta(years=1)
  df_filtered = df[(df['time'] > valid_time_lower) & (df['time'] < valid_time_upper)]
  return df_filtered[['time','latitude','longitude',"era5","area_weight",
                      f'graphcast_lt{lead_time}',
                      f'pangu_lt{lead_time}',
                      f'neuralgcm_lt{lead_time}',
                      # f'keisler_lt{lead_time}'
                      f'ifshres_lt{lead_time}'
                      ]]

# %%
for lead_time in lead_times:
  print(f"========{lead_time}=======")
  df_filter=data_per_lead_time(full_df,lead_time)
  print(df_filter[df_filter.isna().any(axis=1)]["time"].value_counts())
# Out:
# ========48=======
# Series([], Name: count, dtype: int64)
# ========72=======
# Series([], Name: count, dtype: int64)
# ========96=======
# Series([], Name: count, dtype: int64)
# ========120=======
# Series([], Name: count, dtype: int64)
# ========144=======
# Series([], Name: count, dtype: int64)
# ========168=======
# Series([], Name: count, dtype: int64)
# ========192=======
# Series([], Name: count, dtype: int64)
# ========216=======
# Series([], Name: count, dtype: int64)
# ========240=======
# Series([], Name: count, dtype: int64)

# %%
# @title Plot the train-test splits for each Fold

def cross_validation_plot(df, cv, lead_time):
  # Extract datetime info using the filtered df
  time_index = df["time"].reset_index(drop=True)

  X = df[[f"graphcast_lt{lead_time}", f"pangu_lt{lead_time}",
          f"neuralgcm_lt{lead_time}",
          # f"keisler_lt{lead_time}",
          f"ifshres_lt{lead_time}", "longitude", "latitude"]]

  # Store train/test index lists
  train_indices_list = []
  test_indices_list = []
  for train_index, test_index in cv.split(X):
      train_indices_list.append(train_index)
      test_indices_list.append(test_index)


  # Create the plot
  fig, ax = plt.subplots(figsize=(12, 6))

  # Plot each fold
  for i in range(10):
      # Convert indices to datetime for x-axis
      train_times = time_index.iloc[train_indices_list[i]]
      print(f"Train times Min Date: {train_times.min()} Train times Max Date:{train_times.max()}")
      test_times = time_index.iloc[test_indices_list[i]]
      print(f"Test times Min Date: {test_times.min()} Test times Max Date:{test_times.max()}")


      ax.plot(train_times, [i + 1] * len(train_times), 'bo', label='Train' if i == 0 else "", markersize=5)
      ax.plot(test_times, [i + 1] * len(test_times), 'ro', label='Test' if i == 0 else "", markersize=5)
      ax.axhline(y=i + 1.5, color='lightgray', linestyle='--')

  # Format x-axis as months
  ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
  ax.xaxis.set_major_formatter(mdates.DateFormatter('%b\n%Y'))

  # Labels and title
  ax.set_xlabel('Month')
  ax.set_ylabel('Fold')
  ax.set_yticks(range(1, 11))
  ax.set_yticklabels([f'Fold {i+1}' for i in range(10)])
  ax.set_title(f'Training, Gap and Testing Windows Across 10 Folds for {lead_time} hours lead time.')
  ax.legend(loc='upper right')

  # Improve layout and save
  plt.tight_layout()
  # plt.savefig(data_plot_path + f'Training_Testing_Folds_By_Month_{lead_time}.pdf',
  #             dpi=300, bbox_inches="tight")

  plt.show()

# %%
# @title RMSE Comparison for each model and fold

def train_and_evaluate(xgb, cv,X,y, area_weight,lead_time):
  # Create a dictionary to store the results for each fold
  results = {}

  for fold, (train_index, test_index) in enumerate(cv.split(X)):
      print(f"Fold {fold+1}:")
      fold_results = {}

      X_train, X_test = X.iloc[train_index], X.iloc[test_index]
      y_train, y_test = y.iloc[train_index], y.iloc[test_index]

      xgb.fit(X_train, y_train, sample_weight=area_weight.iloc[train_index])

      y_pred = xgb.predict(X_test)
      mse = mean_squared_error(y_test, y_pred)
      print(f"  mse: {mse}")

      area_weighted_rmse = np.sqrt(((y_test-y_pred)**2 * area_weight.iloc[test_index]).mean() / area_weight.iloc[test_index].mean())
      print(f"  PiggyCast: area weighted rmse: {area_weighted_rmse}")
      fold_results["PiggyCast"] = area_weighted_rmse

      for model in [f"graphcast_lt{lead_time}",
                    f"pangu_lt{lead_time}",
                    f"neuralgcm_lt{lead_time}",
                    # f"keisler_lt{lead_time}",
                    f"ifshres_lt{lead_time}"]:
          area_weighted_rmse = np.sqrt(((y_test-X_test[model])**2 * area_weight.iloc[test_index]).mean() / area_weight.iloc[test_index].mean())
          print(f"  {model.split('_')[0]}: area weighted rmse: {area_weighted_rmse}")
          fold_results[model.split('_')[0]] = area_weighted_rmse

      results[fold+1] = fold_results
  return results

# %%
# @title Plot RMSE per fold and Model
def rmse_per_fold_plot(results, lead_time):
  fig, ax = plt.subplots(figsize=(8, 6))

  for model in results[1].keys():  # Iterate through all model names
      rmse_values = [results[fold][model] for fold in results]
      fold_numbers = list(results.keys())
      ax.plot(fold_numbers, rmse_values, label=model, marker='o')

  ax.set_xlabel('Fold')
  ax.set_ylabel('RMSE')
  ax.set_title(f'RMSE for Each Fold and Model at {lead_time} hours lead time.')
  ax.legend(loc="upper right")
  plt.grid(True)
  # plt.savefig(data_plot_path + f'RMSE_for_Each_Fold_and_Model_{lead_time}.pdf', dpi=300, bbox_inches="tight")

  plt.show()

# %%
# @title Calculate RMSE Mean of Model per Lead time

def rmse_mean_per_lead_time_and_model(rmse_results):
  # average scores per lead time and model
  average_scores = {}

  for lead_time, folds in rmse_results.items():
      model_scores = defaultdict(list)

      # collect values per model
      for fold_scores in folds.values():
          for model, value in fold_scores.items():
              model_scores[model].append(value)

      # average for each model
      average_scores[lead_time] = {model: float(np.mean(scores)) for model, scores in model_scores.items()}
  return average_scores

# %%
# @title Training and Evaluation Loop - Longer time series split: 60 days Training, 5 Days Gap and 30 Days Testing

# Initialize xgb regressor
xgb = xgboost.XGBRegressor(random_state=42, device="cuda")

# Calculate Cross-Validation using 10 folds
cv_timeseries = TimeSeriesSplit(n_splits=10, max_train_size=32 * 64 * 2 * 60,
                                test_size= 32 * 64 * 2 * 30, gap=32 * 64 * 2 * 5)

# Lead Times
lead_times=[48,72]
# lead_times=[48, 72, 96, 120, 144, 168, 192, 216, 240]


nested_scores = {} # Nested scores for each lead time
rmse_results = {} # rmse results for each lead time, models

for lead_time in lead_times:
  print(f"======Lead time: {lead_time}========")

  df_filtered = data_per_lead_time(full_df,lead_time)

  X = df_filtered[[f"graphcast_lt{lead_time}", f"pangu_lt{lead_time}",
                   f"neuralgcm_lt{lead_time}",
                  #  f"keisler_lt{lead_time}",
                   f"ifshres_lt{lead_time}", "longitude", "latitude"]]
  y = df_filtered["era5"]
  area_weight = df_filtered["area_weight"]

  print(f"Shape of x :{X.shape}")
  print(f"Shape of y : {y.shape}")

  # Nested Scores
  nested_score = cross_validate(xgb, X=X, y=y, cv=cv_timeseries,
                              scoring=('neg_mean_squared_error', 'r2'),
                              params={'sample_weight': area_weight}
                              )
  nested_scores[lead_time] = nested_score

  # Cross validation plot
  cross_validation_plot(df_filtered, cv_timeseries, lead_time)

  # RMSE
  rmse_result = train_and_evaluate(xgb, cv_timeseries,X,y, area_weight, lead_time)
  rmse_results[lead_time] = rmse_result

  # RMSE plots per model
  rmse_per_fold_plot(rmse_result, lead_time)

  # print nicely average RMSE per Leadtime
  average_scores = rmse_mean_per_lead_time_and_model(rmse_results)
  pprint(average_scores)
# Out:
# ======Lead time: 48========
# Shape of x :(1497088, 6)
# Shape of y : (1497088,)
# Train times Min Date: 2020-01-04 00:00:00 Train times Max Date:2020-03-03 12:00:00
# Test times Min Date: 2020-03-09 00:00:00 Test times Max Date:2020-04-07 12:00:00
# Train times Min Date: 2020-02-03 00:00:00 Train times Max Date:2020-04-02 12:00:00
# Test times Min Date: 2020-04-08 00:00:00 Test times Max Date:2020-05-07 12:00:00
# Train times Min Date: 2020-03-04 00:00:00 Train times Max Date:2020-05-02 12:00:00
# Test times Min Date: 2020-05-08 00:00:00 Test times Max Date:2020-06-06 12:00:00
# Train times Min Date: 2020-04-03 00:00:00 Train times Max Date:2020-06-01 12:00:00
# Test times Min Date: 2020-06-07 00:00:00 Test times Max Date:2020-07-06 12:00:00
# Train times Min Date: 2020-05-03 00:00:00 Train times Max Date:2020-07-01 12:00:00
# Test times Min Date: 2020-07-07 00:00:00 Test times Max Date:2020-08-05 12:00:00
# Train times Min Date: 2020-06-02 00:00:00 Train times Max Date:2020-07-31 12:00:00
# Test times Min Date: 2020-08-06 00:00:00 Test times Max Date:2020-09-04 12:00:00
# Train times Min Date: 2020-07-02 00:00:00 Train times Max Date:2020-08-30 12:00:00
# Test times Min Date: 2020-09-05 00:00:00 Test times Max Date:2020-10-04 12:00:00
# Train times Min Date: 2020-08-01 00:00:00 Train times Max Date:2020-09-29 12:00:00
# Test times Min Date: 2020-10-05 00:00:00 Test times Max Date:2020-11-03 12:00:00
# Train times Min Date: 2020-08-31 00:00:00 Train times Max Date:2020-10-29 12:00:00
# Test times Min Date: 2020-11-04 00:00:00 Test times Max Date:2020-12-03 12:00:00
# Train times Min Date: 2020-09-30 00:00:00 Train times Max Date:2020-11-28 12:00:00
# Test times Min Date: 2020-12-04 00:00:00 Test times Max Date:2021-01-02 12:00:00
# Fold 1:
#   mse: 15209.0927734375
#   PiggyCast: area weighted rmse: 76.76277746972184
#   graphcast: area weighted rmse: 72.89521727913798
#   pangu: area weighted rmse: 81.53557879205798
#   neuralgcm: area weighted rmse: 61.32865112702906
#   ifshres: area weighted rmse: 77.69317822238818
# Fold 2:
#   mse: 9210.8720703125
#   PiggyCast: area weighted rmse: 66.86750469041097
#   graphcast: area weighted rmse: 70.89595346008002
#   pangu: area weighted rmse: 80.0969255422813
#   neuralgcm: area weighted rmse: 62.04284877201307
#   ifshres: area weighted rmse: 76.40121126092066
# Fold 3:
#   mse: 7203.16845703125
#   PiggyCast: area weighted rmse: 64.48324208575639
#   graphcast: area weighted rmse: 70.5749420055696
#   pangu: area weighted rmse: 74.76480428843476
#   neuralgcm: area weighted rmse: 61.50660557160111
#   ifshres: area weighted rmse: 74.98039911101573
# Fold 4:
#   mse: 10929.08203125
#   PiggyCast: area weighted rmse: 74.77433859172058
#   graphcast: area weighted rmse: 67.91825353957019
#   pangu: area weighted rmse: 76.16479857995013
#   neuralgcm: area weighted rmse: 62.250790723830846
#   ifshres: area weighted rmse: 73.43334240838122
# Fold 5:
#   mse: 8148.28466796875
#   PiggyCast: area weighted rmse: 66.73400462634106
#   graphcast: area weighted rmse: 69.53456496945665
#   pangu: area weighted rmse: 75.85023366861931
#   neuralgcm: area weighted rmse: 62.624352826375855
#   ifshres: area weighted rmse: 72.50229375754877
# Fold 6:
#   mse: 6738.87451171875
#   PiggyCast: area weighted rmse: 63.203693254164506
#   graphcast: area weighted rmse: 71.15578888510981
#   pangu: area weighted rmse: 79.14745069733286
#   neuralgcm: area weighted rmse: 62.07276362611518
#   ifshres: area weighted rmse: 76.14583308236563
# Fold 7:
#   mse: 5440.23681640625
#   PiggyCast: area weighted rmse: 57.703994908461134
#   graphcast: area weighted rmse: 69.66994844888492
#   pangu: area weighted rmse: 72.788993851112
#   neuralgcm: area weighted rmse: 58.926894752920596
#   ifshres: area weighted rmse: 74.32574619854132
# Fold 8:
#   mse: 6500.96728515625
#   PiggyCast: area weighted rmse: 61.61347686369192
#   graphcast: area weighted rmse: 68.89431861982807
#   pangu: area weighted rmse: 71.99590819591062
#   neuralgcm: area weighted rmse: 59.96465876609652
#   ifshres: area weighted rmse: 71.63665664407932
# Fold 9:
#   mse: 4908.22314453125
#   PiggyCast: area weighted rmse: 56.23334828212137
#   graphcast: area weighted rmse: 67.17698776540674
#   pangu: area weighted rmse: 73.03220021188946
#   neuralgcm: area weighted rmse: 59.111146835608
#   ifshres: area weighted rmse: 72.73303912220229
# Fold 10:
#   mse: 4107.1357421875
#   PiggyCast: area weighted rmse: 53.399204142035124
#   graphcast: area weighted rmse: 67.66405819770297
#   pangu: area weighted rmse: 72.19549100526328
#   neuralgcm: area weighted rmse: 57.786025245321035
#   ifshres: area weighted rmse: 72.01147844713772
# {48: {'PiggyCast': 64.1775584914425,
#       'graphcast': 69.63800331707469,
#       'ifshres': 74.18631782545808,
#       'neuralgcm': 60.76147382469113,
#       'pangu': 75.75723848328518}}
# ======Lead time: 72========
# Shape of x :(1497088, 6)
# Shape of y : (1497088,)
# Train times Min Date: 2020-01-05 00:00:00 Train times Max Date:2020-03-04 12:00:00
# Test times Min Date: 2020-03-10 00:00:00 Test times Max Date:2020-04-08 12:00:00
# Train times Min Date: 2020-02-04 00:00:00 Train times Max Date:2020-04-03 12:00:00
# Test times Min Date: 2020-04-09 00:00:00 Test times Max Date:2020-05-08 12:00:00
# Train times Min Date: 2020-03-05 00:00:00 Train times Max Date:2020-05-03 12:00:00
# Test times Min Date: 2020-05-09 00:00:00 Test times Max Date:2020-06-07 12:00:00
# Train times Min Date: 2020-04-04 00:00:00 Train times Max Date:2020-06-02 12:00:00
# Test times Min Date: 2020-06-08 00:00:00 Test times Max Date:2020-07-07 12:00:00
# Train times Min Date: 2020-05-04 00:00:00 Train times Max Date:2020-07-02 12:00:00
# Test times Min Date: 2020-07-08 00:00:00 Test times Max Date:2020-08-06 12:00:00
# Train times Min Date: 2020-06-03 00:00:00 Train times Max Date:2020-08-01 12:00:00
# Test times Min Date: 2020-08-07 00:00:00 Test times Max Date:2020-09-05 12:00:00
# Train times Min Date: 2020-07-03 00:00:00 Train times Max Date:2020-08-31 12:00:00
# Test times Min Date: 2020-09-06 00:00:00 Test times Max Date:2020-10-05 12:00:00
# Train times Min Date: 2020-08-02 00:00:00 Train times Max Date:2020-09-30 12:00:00
# Test times Min Date: 2020-10-06 00:00:00 Test times Max Date:2020-11-04 12:00:00
# Train times Min Date: 2020-09-01 00:00:00 Train times Max Date:2020-10-30 12:00:00
# Test times Min Date: 2020-11-05 00:00:00 Test times Max Date:2020-12-04 12:00:00
# Train times Min Date: 2020-10-01 00:00:00 Train times Max Date:2020-11-29 12:00:00
# Test times Min Date: 2020-12-05 00:00:00 Test times Max Date:2021-01-03 12:00:00
# Fold 1:
#   mse: 25877.22265625
#   PiggyCast: area weighted rmse: 115.03192565675418
#   graphcast: area weighted rmse: 122.85387708812033
#   pangu: area weighted rmse: 135.08533958019098
#   neuralgcm: area weighted rmse: 108.71967205337731
#   ifshres: area weighted rmse: 131.52903243672063
# Fold 2:
#   mse: 20881.48046875
#   PiggyCast: area weighted rmse: 107.9994745127202
#   graphcast: area weighted rmse: 121.55502280923785
#   pangu: area weighted rmse: 134.301915560045
#   neuralgcm: area weighted rmse: 110.53258883735597
#   ifshres: area weighted rmse: 130.6921929942073
# Fold 3:
#   mse: 16885.568359375
#   PiggyCast: area weighted rmse: 102.35013330448703
#   graphcast: area weighted rmse: 115.12777744553853
#   pangu: area weighted rmse: 124.96075061143948
#   neuralgcm: area weighted rmse: 106.80123183454789
#   ifshres: area weighted rmse: 126.64768147865912
# Fold 4:
#   mse: 21867.5078125
#   PiggyCast: area weighted rmse: 110.57140621198165
#   graphcast: area weighted rmse: 113.60324813116003
#   pangu: area weighted rmse: 129.28144312804812
#   neuralgcm: area weighted rmse: 110.34336069680998
#   ifshres: area weighted rmse: 125.42401589340629
# Fold 5:
#   mse: 18708.271484375
#   PiggyCast: area weighted rmse: 104.24449889316989
#   graphcast: area weighted rmse: 115.66416448280997
#   pangu: area weighted rmse: 125.03452254381654
#   neuralgcm: area weighted rmse: 108.10566962476716
#   ifshres: area weighted rmse: 122.3795501326147
# Fold 6:
#   mse: 17659.58203125
#   PiggyCast: area weighted rmse: 101.2720790290131
#   graphcast: area weighted rmse: 117.44068804253459
#   pangu: area weighted rmse: 132.0256062399261
#   neuralgcm: area weighted rmse: 104.11459238207713
#   ifshres: area weighted rmse: 127.61044134903098
# Fold 7:
#   mse: 15610.6513671875
#   PiggyCast: area weighted rmse: 97.68201533586064
#   graphcast: area weighted rmse: 116.53001874603304
#   pangu: area weighted rmse: 121.32061802132586
#   neuralgcm: area weighted rmse: 101.42341400176115
#   ifshres: area weighted rmse: 127.72751122938766
# Fold 8:
#   mse: 15285.712890625
#   PiggyCast: area weighted rmse: 98.67804953989219
#   graphcast: area weighted rmse: 112.3207310966977
#   pangu: area weighted rmse: 119.82630686565231
#   neuralgcm: area weighted rmse: 103.73943264669145
#   ifshres: area weighted rmse: 121.25760167335962
# Fold 9:
#   mse: 12898.6494140625
#   PiggyCast: area weighted rmse: 92.67367861933877
#   graphcast: area weighted rmse: 109.83704338844261
#   pangu: area weighted rmse: 118.85577805793842
#   neuralgcm: area weighted rmse: 101.02463450734321
#   ifshres: area weighted rmse: 120.57419944017212
# Fold 10:
#   mse: 11327.111328125
#   PiggyCast: area weighted rmse: 89.4399949907235
#   graphcast: area weighted rmse: 109.94350674268277
#   pangu: area weighted rmse: 117.66422571551385
#   neuralgcm: area weighted rmse: 96.27359312225816
#   ifshres: area weighted rmse: 116.08151803049746
# {48: {'PiggyCast': 64.1775584914425,
#       'graphcast': 69.63800331707469,
#       'ifshres': 74.18631782545808,
#       'neuralgcm': 60.76147382469113,
#       'pangu': 75.75723848328518},
#  72: {'PiggyCast': 101.99432560939412,
#       'graphcast': 115.48760779732575,
#       'ifshres': 124.99237446580557,
#       'neuralgcm': 105.10781897069894,
#       'pangu': 125.83565063238966}}

# %%
import pandas as pd

# Parameters
n_samples = 1_497_088
n_splits = 10
max_train_size = 32 * 64 * 2 * 60  # 245,760
test_size = 32 * 64 * 2 * 30        # 122,880
gap = 32 * 64 * 2 * 5              # 20,480

# Calculate fold boundaries
folds = []
for i in range(n_splits):
    test_end = n_samples - (n_splits - 1 - i) * test_size
    test_start = test_end - test_size
    train_end = test_start - gap
    train_start = max(0, train_end - max_train_size)

    folds.append({
        "Fold": i + 1,
        "Train Start": train_start,
        "Train End": train_end - 1,
        "Gap Start": train_end,
        "Gap End": test_start - 1,
        "Test Start": test_start,
        "Test End": test_end - 1,
        "Train Size": train_end - train_start,
        "Test Size": test_size,
    })

# Convert to DataFrame
folds_df = pd.DataFrame(folds)
folds_df
# Out:
#    Fold  Train Start  Train End  Gap Start  Gap End  Test Start  Test End  \
# 0     1         2048     247807     247808   268287      268288    391167
# 1     2       124928     370687     370688   391167      391168    514047
# 2     3       247808     493567     493568   514047      514048    636927
# 3     4       370688     616447     616448   636927      636928    759807
# 4     5       493568     739327     739328   759807      759808    882687
# 5     6       616448     862207     862208   882687      882688   1005567
# 6     7       739328     985087     985088  1005567     1005568   1128447
# 7     8       862208    1107967    1107968  1128447     1128448   1251327
# 8     9       985088    1230847    1230848  1251327     1251328   1374207
# 9    10      1107968    1353727    1353728  1374207     1374208   1497087
#
#    Train Size  Test Size
# 0      245760     122880
# 1      245760     122880
# 2      245760     122880
# 3      245760     122880
# 4      245760     122880
# 5      245760     122880
# 6      245760     122880
# 7      245760     122880
# 8      245760     122880
# 9      245760     122880

# %%
# @title Training and Evaluation Loop- Shorter Time series split: 2 Weeks Training, 1 Day Gap and 1 Week Testing

# Initialize xgb regressor
xgb = xgboost.XGBRegressor(random_state=42, device="cuda")

# Calculate Cross-Validation using 10 folds
cv_timeseries = TimeSeriesSplit(n_splits=50, max_train_size=32 * 64 * 2 * 14,
                                test_size= 32 * 64 * 2 * 7, gap=32 * 64 * 2 * 1)

# Lead Times
lead_times=[48,72]

nested_scores = {} # Nested scores for each lead time
rmse_results = {} # rmse results for each lead time, models

for lead_time in lead_times:
  print(f"======Lead time: {lead_time}========")

  df_filtered = data_per_lead_time(full_df,lead_time)

  X = df_filtered[[f"graphcast_lt{lead_time}", f"pangu_lt{lead_time}",
                   f"neuralgcm_lt{lead_time}",
                  #  f"keisler_lt{lead_time}",
                   f"ifshres_lt{lead_time}", "longitude", "latitude"]]
  y = df_filtered["era5"]
  area_weight = df_filtered["area_weight"]

  print(f"Shape of x :{X.shape}")
  print(f"Shape of y : {y.shape}")

  # Nested Scores
  nested_score = cross_validate(xgb, X=X, y=y, cv=cv_timeseries,
                              scoring=('neg_mean_squared_error', 'r2'),
                              params={'sample_weight': area_weight}
                              )
  nested_scores[lead_time] = nested_score

  # Cross validation plot
  cross_validation_plot(df_filtered, cv_timeseries, lead_time)

  # RMSE
  rmse_result = train_and_evaluate(xgb, cv_timeseries,X,y, area_weight, lead_time)
  rmse_results[lead_time] = rmse_result

  # RMSE plots per model
  rmse_per_fold_plot(rmse_result, lead_time)

  # print nicely average RMSE per Leadtime
  average_scores = rmse_mean_per_lead_time_and_model(rmse_results)
  pprint(average_scores)
# Out:
# ======Lead time: 48========
# Shape of x :(1497088, 6)
# Shape of y : (1497088,)
# Train times Min Date: 2020-01-04 00:00:00 Train times Max Date:2020-01-17 12:00:00
# Test times Min Date: 2020-01-19 00:00:00 Test times Max Date:2020-01-25 12:00:00
# Train times Min Date: 2020-01-11 00:00:00 Train times Max Date:2020-01-24 12:00:00
# Test times Min Date: 2020-01-26 00:00:00 Test times Max Date:2020-02-01 12:00:00
# Train times Min Date: 2020-01-18 00:00:00 Train times Max Date:2020-01-31 12:00:00
# Test times Min Date: 2020-02-02 00:00:00 Test times Max Date:2020-02-08 12:00:00
# Train times Min Date: 2020-01-25 00:00:00 Train times Max Date:2020-02-07 12:00:00
# Test times Min Date: 2020-02-09 00:00:00 Test times Max Date:2020-02-15 12:00:00
# Train times Min Date: 2020-02-01 00:00:00 Train times Max Date:2020-02-14 12:00:00
# Test times Min Date: 2020-02-16 00:00:00 Test times Max Date:2020-02-22 12:00:00
# Train times Min Date: 2020-02-08 00:00:00 Train times Max Date:2020-02-21 12:00:00
# Test times Min Date: 2020-02-23 00:00:00 Test times Max Date:2020-02-29 12:00:00
# Train times Min Date: 2020-02-15 00:00:00 Train times Max Date:2020-02-28 12:00:00
# Test times Min Date: 2020-03-01 00:00:00 Test times Max Date:2020-03-07 12:00:00
# Train times Min Date: 2020-02-22 00:00:00 Train times Max Date:2020-03-06 12:00:00
# Test times Min Date: 2020-03-08 00:00:00 Test times Max Date:2020-03-14 12:00:00
# Train times Min Date: 2020-02-29 00:00:00 Train times Max Date:2020-03-13 12:00:00
# Test times Min Date: 2020-03-15 00:00:00 Test times Max Date:2020-03-21 12:00:00
# Train times Min Date: 2020-03-07 00:00:00 Train times Max Date:2020-03-20 12:00:00
# Test times Min Date: 2020-03-22 00:00:00 Test times Max Date:2020-03-28 12:00:00
# Fold 1:
#   mse: 5451.60546875
#   PiggyCast: area weighted rmse: 60.38548613455776
#   graphcast: area weighted rmse: 66.20678638148297
#   pangu: area weighted rmse: 73.25187701683323
#   neuralgcm: area weighted rmse: 57.064416422694435
#   ifshres: area weighted rmse: 73.25612433115195
# Fold 2:
#   mse: 8756.2548828125
#   PiggyCast: area weighted rmse: 59.10154369781358
#   graphcast: area weighted rmse: 67.18696932095679
#   pangu: area weighted rmse: 75.6866919914812
#   neuralgcm: area weighted rmse: 56.083009122549115
#   ifshres: area weighted rmse: 76.64914821516122
# Fold 3:
#   mse: 8581.4501953125
#   PiggyCast: area weighted rmse: 64.29598027667701
#   graphcast: area weighted rmse: 72.90208568609224
#   pangu: area weighted rmse: 78.45860350690234
#   neuralgcm: area weighted rmse: 60.02047684968904
#   ifshres: area weighted rmse: 77.68003396303061
# Fold 4:
#   mse: 7139.53466796875
#   PiggyCast: area weighted rmse: 69.21239506587395
#   graphcast: area weighted rmse: 74.00325104166043
#   pangu: area weighted rmse: 79.42324814192085
#   neuralgcm: area weighted rmse: 60.66258868925265
#   ifshres: area weighted rmse: 81.2281537919591
# Fold 5:
#   mse: 6090.9287109375
#   PiggyCast: area weighted rmse: 57.406739041153195
#   graphcast: area weighted rmse: 64.39919174371511
#   pangu: area weighted rmse: 74.550773387076
#   neuralgcm: area weighted rmse: 56.89447718310362
#   ifshres: area weighted rmse: 76.5106855304369
# Fold 6:
#   mse: 5332.46337890625
#   PiggyCast: area weighted rmse: 56.881258334267294
#   graphcast: area weighted rmse: 66.21749042118111
#   pangu: area weighted rmse: 76.55772127750818
#   neuralgcm: area weighted rmse: 59.068154463257386
#   ifshres: area weighted rmse: 77.6373230342622
# Fold 7:
#   mse: 8227.1640625
#   PiggyCast: area weighted rmse: 64.14382147546952
#   graphcast: area weighted rmse: 69.39007363666185
#   pangu: area weighted rmse: 79.3285971637632
#   neuralgcm: area weighted rmse: 60.56658376450028
#   ifshres: area weighted rmse: 75.67671543598414
# Fold 8:
#   mse: 22211.04296875
#   PiggyCast: area weighted rmse: 78.72488085699145
#   graphcast: area weighted rmse: 67.14454393580866
#   pangu: area weighted rmse: 71.83729600602409
#   neuralgcm: area weighted rmse: 58.33544530858417
#   ifshres: area weighted rmse: 76.89570426870856
# Fold 9:
#   mse: 11541.0888671875
#   PiggyCast: area weighted rmse: 71.82562912289536
#   graphcast: area weighted rmse: 73.84589682417504
#   pangu: area weighted rmse: 86.22700254478103
#   neuralgcm: area weighted rmse: 62.36404144190721
#   ifshres: area weighted rmse: 78.9632666853088
# Fold 10:
#   mse: 6265.15380859375
#   PiggyCast: area weighted rmse: 60.59960004753302
#   graphcast: area weighted rmse: 74.57735971577287
#   pangu: area weighted rmse: 83.01794047581258
#   neuralgcm: area weighted rmse: 59.4057025517564
#   ifshres: area weighted rmse: 77.52018809321092
# Fold 11:
#   mse: 5274.9609375
#   PiggyCast: area weighted rmse: 60.81353491169298
#   graphcast: area weighted rmse: 74.67653030843756
#   pangu: area weighted rmse: 83.32490198780404
#   neuralgcm: area weighted rmse: 62.8803577283202
#   ifshres: area weighted rmse: 78.66876997832419
# Fold 12:
#   mse: 5705.4365234375
#   PiggyCast: area weighted rmse: 61.812926525513205
#   graphcast: area weighted rmse: 71.83526751159391
#   pangu: area weighted rmse: 77.88217343269964
#   neuralgcm: area weighted rmse: 64.14224874288915
#   ifshres: area weighted rmse: 76.49786523200481
# Fold 13:
#   mse: 12862.8828125
#   PiggyCast: area weighted rmse: 73.20952942475586
#   graphcast: area weighted rmse: 73.6557404852364
#   pangu: area weighted rmse: 83.8644184535021
#   neuralgcm: area weighted rmse: 62.670121019744016
#   ifshres: area weighted rmse: 78.97718889180375
# Fold 14:
#   mse: 11950.982421875
#   PiggyCast: area weighted rmse: 71.76604641093842
#   graphcast: area weighted rmse: 71.65757162468037
#   pangu: area weighted rmse: 79.63440167298405
#   neuralgcm: area weighted rmse: 59.12695242375497
#   ifshres: area weighted rmse: 73.9211740300101
# Fold 15:
#   mse: 6005.16259765625
#   PiggyCast: area weighted rmse: 60.78192897909004
#   graphcast: area weighted rmse: 69.13347368206266
#   pangu: area weighted rmse: 82.93100669482133
#   neuralgcm: area weighted rmse: 63.16794988251347
#   ifshres: area weighted rmse: 77.45780940736174
# Fold 16:
#   mse: 7548.97216796875
#   PiggyCast: area weighted rmse: 64.12302108981243
#   graphcast: area weighted rmse: 69.9690885418903
#   pangu: area weighted rmse: 74.6384921411598
#   neuralgcm: area weighted rmse: 61.9300213491186
#   ifshres: area weighted rmse: 74.64869910788599
# Fold 17:
#   mse: 6455.89111328125
#   PiggyCast: area weighted rmse: 60.96308584477366
#   graphcast: area weighted rmse: 70.70354190987261
#   pangu: area weighted rmse: 79.99265554672299
#   neuralgcm: area weighted rmse: 62.34462373331609
#   ifshres: area weighted rmse: 76.85539054112753
# Fold 18:
#   mse: 10913.732421875
#   PiggyCast: area weighted rmse: 75.21977391390905
#   graphcast: area weighted rmse: 69.801140060063
#   pangu: area weighted rmse: 72.84180108939732
#   neuralgcm: area weighted rmse: 60.950612942022325
#   ifshres: area weighted rmse: 78.50999438389537
# Fold 19:
#   mse: 7568.30419921875
#   PiggyCast: area weighted rmse: 68.4840955341839
#   graphcast: area weighted rmse: 70.93848149714479
#   pangu: area weighted rmse: 73.11501889950199
#   neuralgcm: area weighted rmse: 62.382405816170085
#   ifshres: area weighted rmse: 73.5842224992343
# Fold 20:
#   mse: 5418.4697265625
#   PiggyCast: area weighted rmse: 59.51080552939815
#   graphcast: area weighted rmse: 70.37276347476993
#   pangu: area weighted rmse: 72.66778894321779
#   neuralgcm: area weighted rmse: 60.29145593301373
#   ifshres: area weighted rmse: 71.45096959311739
# Fold 21:
#   mse: 6388.109375
#   PiggyCast: area weighted rmse: 62.93109381040261
#   graphcast: area weighted rmse: 67.87084438206156
#   pangu: area weighted rmse: 75.82972734591169
#   neuralgcm: area weighted rmse: 63.850793438019295
#   ifshres: area weighted rmse: 73.56494555336853
# Fold 22:
#   mse: 12413.1474609375
#   PiggyCast: area weighted rmse: 75.72534589759589
#   graphcast: area weighted rmse: 69.96457479497236
#   pangu: area weighted rmse: 78.35104898053655
#   neuralgcm: area weighted rmse: 62.77019063220203
#   ifshres: area weighted rmse: 75.35843385438864
# Fold 23:
#   mse: 9235.912109375
#   PiggyCast: area weighted rmse: 70.00119390980267
#   graphcast: area weighted rmse: 64.99853581395674
#   pangu: area weighted rmse: 75.87361278251751
#   neuralgcm: area weighted rmse: 60.4826236036958
#   ifshres: area weighted rmse: 71.21952544826665
# Fold 24:
#   mse: 6282.78173828125
#   PiggyCast: area weighted rmse: 60.07506267616247
#   graphcast: area weighted rmse: 69.19483515204078
#   pangu: area weighted rmse: 74.02332772354171
#   neuralgcm: area weighted rmse: 62.38177233513841
#   ifshres: area weighted rmse: 72.20352232983973
# Fold 25:
#   mse: 6569.38232421875
#   PiggyCast: area weighted rmse: 63.32178163730715
#   graphcast: area weighted rmse: 68.5353006728276
#   pangu: area weighted rmse: 75.39832100896746
#   neuralgcm: area weighted rmse: 62.83394925930707
#   ifshres: area weighted rmse: 75.96904069322166
# Fold 26:
#   mse: 8840.3505859375
#   PiggyCast: area weighted rmse: 68.0736975090297
#   graphcast: area weighted rmse: 72.00892284133367
#   pangu: area weighted rmse: 81.95555590338212
#   neuralgcm: area weighted rmse: 62.02951174836391
#   ifshres: area weighted rmse: 75.201942951334
# Fold 27:
#   mse: 14626.4287109375
#   PiggyCast: area weighted rmse: 79.54606173984155
#   graphcast: area weighted rmse: 66.67685582150068
#   pangu: area weighted rmse: 74.27483395153533
#   neuralgcm: area weighted rmse: 64.83312295543841
#   ifshres: area weighted rmse: 68.96418969773106
# Fold 28:
#   mse: 6793.62646484375
#   PiggyCast: area weighted rmse: 62.15385932110211
#   graphcast: area weighted rmse: 70.0072732558609
#   pangu: area weighted rmse: 72.54856571469618
#   neuralgcm: area weighted rmse: 60.95674700645925
#   ifshres: area weighted rmse: 71.46290430525787
# Fold 29:
#   mse: 10862.138671875
#   PiggyCast: area weighted rmse: 76.59084466788315
#   graphcast: area weighted rmse: 71.07734698341558
#   pangu: area weighted rmse: 76.21010420955628
#   neuralgcm: area weighted rmse: 61.0847538620234
#   ifshres: area weighted rmse: 73.39909676804561
# Fold 30:
#   mse: 5913.22021484375
#   PiggyCast: area weighted rmse: 60.5301328963337
#   graphcast: area weighted rmse: 69.40014789550864
#   pangu: area weighted rmse: 75.32707760813076
#   neuralgcm: area weighted rmse: 60.73944594014233
#   ifshres: area weighted rmse: 77.29124069818009
# Fold 31:
#   mse: 6127.47998046875
#   PiggyCast: area weighted rmse: 62.18381648296419
#   graphcast: area weighted rmse: 72.33931986675769
#   pangu: area weighted rmse: 77.87893775149341
#   neuralgcm: area weighted rmse: 61.04935534171192
#   ifshres: area weighted rmse: 75.61407151005736
# Fold 32:
#   mse: 13374.564453125
#   PiggyCast: area weighted rmse: 78.82662590866141
#   graphcast: area weighted rmse: 68.5957997996403
#   pangu: area weighted rmse: 77.40595815742452
#   neuralgcm: area weighted rmse: 62.08836726530366
#   ifshres: area weighted rmse: 73.65544636939208
# Fold 33:
#   mse: 7360.4892578125
#   PiggyCast: area weighted rmse: 66.41586030759616
#   graphcast: area weighted rmse: 72.8556992696679
#   pangu: area weighted rmse: 84.77304744939102
#   neuralgcm: area weighted rmse: 64.08373500029234
#   ifshres: area weighted rmse: 77.8242085682596
# Fold 34:
#   mse: 7208.3154296875
#   PiggyCast: area weighted rmse: 59.430170474866536
#   graphcast: area weighted rmse: 66.37963259691732
#   pangu: area weighted rmse: 72.51466440005107
#   neuralgcm: area weighted rmse: 58.00275911482397
#   ifshres: area weighted rmse: 72.31309205465031
# Fold 35:
#   mse: 7174.67919921875
#   PiggyCast: area weighted rmse: 64.46473634255001
#   graphcast: area weighted rmse: 70.69860478526155
#   pangu: area weighted rmse: 71.72694958035213
#   neuralgcm: area weighted rmse: 59.45657124159923
#   ifshres: area weighted rmse: 75.87354276251459
# Fold 36:
#   mse: 6113.76806640625
#   PiggyCast: area weighted rmse: 60.682080659814424
#   graphcast: area weighted rmse: 65.47352228127664
#   pangu: area weighted rmse: 70.17750818663806
#   neuralgcm: area weighted rmse: 58.83197512546123
#   ifshres: area weighted rmse: 72.09323046573591
# Fold 37:
#   mse: 5783.05859375
#   PiggyCast: area weighted rmse: 59.869487591491605
#   graphcast: area weighted rmse: 74.05762331279371
#   pangu: area weighted rmse: 76.90927013582306
#   neuralgcm: area weighted rmse: 60.08053516517397
#   ifshres: area weighted rmse: 76.35570081909316
# Fold 38:
#   mse: 6683.10595703125
#   PiggyCast: area weighted rmse: 65.3962092377667
#   graphcast: area weighted rmse: 71.24031120549722
#   pangu: area weighted rmse: 72.4471492017786
#   neuralgcm: area weighted rmse: 60.392784154856805
#   ifshres: area weighted rmse: 72.55926252608074
# Fold 39:
#   mse: 8835.3359375
#   PiggyCast: area weighted rmse: 66.19129476569732
#   graphcast: area weighted rmse: 66.89244327961339
#   pangu: area weighted rmse: 72.81660931411295
#   neuralgcm: area weighted rmse: 61.10431596120065
#   ifshres: area weighted rmse: 72.33080963318145
# Fold 40:
#   mse: 9962.875
#   PiggyCast: area weighted rmse: 67.32724690188125
#   graphcast: area weighted rmse: 68.68091791740216
#   pangu: area weighted rmse: 67.7130888407223
#   neuralgcm: area weighted rmse: 55.310433451113845
#   ifshres: area weighted rmse: 68.30274269904606
# Fold 41:
#   mse: 5417.91748046875
#   PiggyCast: area weighted rmse: 60.09387496518326
#   graphcast: area weighted rmse: 71.09379610324787
#   pangu: area weighted rmse: 74.42250253820265
#   neuralgcm: area weighted rmse: 62.01012456862443
#   ifshres: area weighted rmse: 73.77957242034078
# Fold 42:
#   mse: 5556.35498046875
#   PiggyCast: area weighted rmse: 58.568984265297395
#   graphcast: area weighted rmse: 69.20294994490088
#   pangu: area weighted rmse: 73.46758766756066
#   neuralgcm: area weighted rmse: 59.29053991895373
#   ifshres: area weighted rmse: 72.9105621052856
# Fold 43:
#   mse: 5621.54345703125
#   PiggyCast: area weighted rmse: 59.782470155202134
#   graphcast: area weighted rmse: 68.9896795914389
#   pangu: area weighted rmse: 73.98051472441293
#   neuralgcm: area weighted rmse: 60.66810804473785
#   ifshres: area weighted rmse: 71.16892890696909
# Fold 44:
#   mse: 4574.12744140625
#   PiggyCast: area weighted rmse: 55.16186194689194
#   graphcast: area weighted rmse: 67.21512881495151
#   pangu: area weighted rmse: 75.55058586019881
#   neuralgcm: area weighted rmse: 58.458152614537255
#   ifshres: area weighted rmse: 73.80552419219231
# Fold 45:
#   mse: 4342.330078125
#   PiggyCast: area weighted rmse: 55.76462902002305
#   graphcast: area weighted rmse: 64.68925791328384
#   pangu: area weighted rmse: 71.46294228145602
#   neuralgcm: area weighted rmse: 60.18565177784519
#   ifshres: area weighted rmse: 72.43567308940683
# Fold 46:
#   mse: 4503.2587890625
#   PiggyCast: area weighted rmse: 56.33833719264867
#   graphcast: area weighted rmse: 66.6184147384827
#   pangu: area weighted rmse: 74.4584094935832
#   neuralgcm: area weighted rmse: 59.351481672655254
#   ifshres: area weighted rmse: 74.7755603244467
# Fold 47:
#   mse: 4690.66943359375
#   PiggyCast: area weighted rmse: 57.026612689649326
#   graphcast: area weighted rmse: 67.40431472625734
#   pangu: area weighted rmse: 73.60452652691663
#   neuralgcm: area weighted rmse: 58.71159922714324
#   ifshres: area weighted rmse: 74.66322955396006
# Fold 48:
#   mse: 3910.642578125
#   PiggyCast: area weighted rmse: 53.647015999533025
#   graphcast: area weighted rmse: 65.46444935617437
#   pangu: area weighted rmse: 67.03228472712844
#   neuralgcm: area weighted rmse: 57.11274302766549
#   ifshres: area weighted rmse: 67.5595511750235
# Fold 49:
#   mse: 3933.99267578125
#   PiggyCast: area weighted rmse: 53.392426322941176
#   graphcast: area weighted rmse: 64.373500470157
#   pangu: area weighted rmse: 69.29924373138155
#   neuralgcm: area weighted rmse: 56.37334939468531
#   ifshres: area weighted rmse: 70.34009527447243
# Fold 50:
#   mse: 6191.3662109375
#   PiggyCast: area weighted rmse: 60.74628309390037
#   graphcast: area weighted rmse: 72.66075832449428
#   pangu: area weighted rmse: 74.77157159239104
#   neuralgcm: area weighted rmse: 56.697786393053036
#   ifshres: area weighted rmse: 73.85641840021128
# {48: {'PiggyCast': 63.99042361214641,
#       'graphcast': 69.46556019429909,
#       'ifshres': 74.58882984327866,
#       'neuralgcm': 60.4314984922077,
#       'pangu': 75.82875875527417}}
# ======Lead time: 72========
# Shape of x :(1497088, 6)
# Shape of y : (1497088,)
# Train times Min Date: 2020-01-05 00:00:00 Train times Max Date:2020-01-18 12:00:00
# Test times Min Date: 2020-01-20 00:00:00 Test times Max Date:2020-01-26 12:00:00
# Train times Min Date: 2020-01-12 00:00:00 Train times Max Date:2020-01-25 12:00:00
# Test times Min Date: 2020-01-27 00:00:00 Test times Max Date:2020-02-02 12:00:00
# Train times Min Date: 2020-01-19 00:00:00 Train times Max Date:2020-02-01 12:00:00
# Test times Min Date: 2020-02-03 00:00:00 Test times Max Date:2020-02-09 12:00:00
# Train times Min Date: 2020-01-26 00:00:00 Train times Max Date:2020-02-08 12:00:00
# Test times Min Date: 2020-02-10 00:00:00 Test times Max Date:2020-02-16 12:00:00
# Train times Min Date: 2020-02-02 00:00:00 Train times Max Date:2020-02-15 12:00:00
# Test times Min Date: 2020-02-17 00:00:00 Test times Max Date:2020-02-23 12:00:00
# Train times Min Date: 2020-02-09 00:00:00 Train times Max Date:2020-02-22 12:00:00
# Test times Min Date: 2020-02-24 00:00:00 Test times Max Date:2020-03-01 12:00:00
# Train times Min Date: 2020-02-16 00:00:00 Train times Max Date:2020-02-29 12:00:00
# Test times Min Date: 2020-03-02 00:00:00 Test times Max Date:2020-03-08 12:00:00
# Train times Min Date: 2020-02-23 00:00:00 Train times Max Date:2020-03-07 12:00:00
# Test times Min Date: 2020-03-09 00:00:00 Test times Max Date:2020-03-15 12:00:00
# Train times Min Date: 2020-03-01 00:00:00 Train times Max Date:2020-03-14 12:00:00
# Test times Min Date: 2020-03-16 00:00:00 Test times Max Date:2020-03-22 12:00:00
# Train times Min Date: 2020-03-08 00:00:00 Train times Max Date:2020-03-21 12:00:00
# Test times Min Date: 2020-03-23 00:00:00 Test times Max Date:2020-03-29 12:00:00
# Fold 1:
#   mse: 13016.232421875
#   PiggyCast: area weighted rmse: 96.33054892869822
#   graphcast: area weighted rmse: 112.36481517508207
#   pangu: area weighted rmse: 119.76187380838239
#   neuralgcm: area weighted rmse: 97.68319606121942
#   ifshres: area weighted rmse: 118.25210902630512
# Fold 2:
#   mse: 18178.048828125
#   PiggyCast: area weighted rmse: 96.14603791465345
#   graphcast: area weighted rmse: 110.70637183928743
#   pangu: area weighted rmse: 124.28262076397449
#   neuralgcm: area weighted rmse: 97.10167278518675
#   ifshres: area weighted rmse: 118.81238470397493
# Fold 3:
#   mse: 17498.583984375
#   PiggyCast: area weighted rmse: 102.8934797979744
#   graphcast: area weighted rmse: 121.9414270569667
#   pangu: area weighted rmse: 130.6952533994007
#   neuralgcm: area weighted rmse: 104.8456933216301
#   ifshres: area weighted rmse: 126.06484559304855
# Fold 4:
#   mse: 15714.1650390625
#   PiggyCast: area weighted rmse: 99.45221016873195
#   graphcast: area weighted rmse: 119.86029705088232
#   pangu: area weighted rmse: 122.80342738313325
#   neuralgcm: area weighted rmse: 100.84632523012215
#   ifshres: area weighted rmse: 126.5470260470347
# Fold 5:
#   mse: 13982.236328125
#   PiggyCast: area weighted rmse: 92.79869714398048
#   graphcast: area weighted rmse: 103.71146566101426
#   pangu: area weighted rmse: 117.06457755364866
#   neuralgcm: area weighted rmse: 95.59215076953633
#   ifshres: area weighted rmse: 119.808998399036
# Fold 6:
#   mse: 15813.5888671875
#   PiggyCast: area weighted rmse: 98.98101637701787
#   graphcast: area weighted rmse: 109.34396764402956
#   pangu: area weighted rmse: 121.81283282333439
#   neuralgcm: area weighted rmse: 101.74969115954897
#   ifshres: area weighted rmse: 130.25296096910418
# Fold 7:
#   mse: 20452.083984375
#   PiggyCast: area weighted rmse: 107.48221399297275
#   graphcast: area weighted rmse: 115.69170831091617
#   pangu: area weighted rmse: 134.9170666334175
#   neuralgcm: area weighted rmse: 104.86028537480225
#   ifshres: area weighted rmse: 124.41708494515164
# Fold 8:
#   mse: 40189.3125
#   PiggyCast: area weighted rmse: 115.66730206721287
#   graphcast: area weighted rmse: 109.28335859289622
#   pangu: area weighted rmse: 116.0473108903989
#   neuralgcm: area weighted rmse: 101.70408989337751
#   ifshres: area weighted rmse: 128.93048856694742
# Fold 9:
#   mse: 22392.44140625
#   PiggyCast: area weighted rmse: 111.38929692567885
#   graphcast: area weighted rmse: 123.72162956952872
#   pangu: area weighted rmse: 138.5308401312618
#   neuralgcm: area weighted rmse: 106.98571820725081
#   ifshres: area weighted rmse: 134.2504270354584
# Fold 10:
#   mse: 17318.041015625
#   PiggyCast: area weighted rmse: 103.22054068531035
#   graphcast: area weighted rmse: 128.70762876350125
#   pangu: area weighted rmse: 139.99550497910354
#   neuralgcm: area weighted rmse: 104.5546149741894
#   ifshres: area weighted rmse: 132.89228511181008
# Fold 11:
#   mse: 17239.193359375
#   PiggyCast: area weighted rmse: 108.50338628462272
#   graphcast: area weighted rmse: 125.79245110207782
#   pangu: area weighted rmse: 139.45471597983672
#   neuralgcm: area weighted rmse: 114.2353744252658
#   ifshres: area weighted rmse: 132.1995121650541
# Fold 12:
#   mse: 19019.49609375
#   PiggyCast: area weighted rmse: 113.86432902969376
#   graphcast: area weighted rmse: 122.67443764358275
#   pangu: area weighted rmse: 137.0718024914255
#   neuralgcm: area weighted rmse: 122.5916191760077
#   ifshres: area weighted rmse: 128.17075072308245
# Fold 13:
#   mse: 28392.001953125
#   PiggyCast: area weighted rmse: 115.7909802629532
#   graphcast: area weighted rmse: 123.52625108076855
#   pangu: area weighted rmse: 141.38661055312159
#   neuralgcm: area weighted rmse: 106.31595371720535
#   ifshres: area weighted rmse: 134.2915300289041
# Fold 14:
#   mse: 22076.28515625
#   PiggyCast: area weighted rmse: 108.20588309852245
#   graphcast: area weighted rmse: 125.72421553654699
#   pangu: area weighted rmse: 131.88809360984612
#   neuralgcm: area weighted rmse: 104.04201304432392
#   ifshres: area weighted rmse: 128.35592156081873
# Fold 15:
#   mse: 19772.296875
#   PiggyCast: area weighted rmse: 108.15697544983972
#   graphcast: area weighted rmse: 121.80003487606226
#   pangu: area weighted rmse: 140.87449483826808
#   neuralgcm: area weighted rmse: 114.0155340768967
#   ifshres: area weighted rmse: 132.38074201673928
# Fold 16:
#   mse: 19169.52734375
#   PiggyCast: area weighted rmse: 106.80169241380624
#   graphcast: area weighted rmse: 116.54607628539252
#   pangu: area weighted rmse: 121.1729064255376
#   neuralgcm: area weighted rmse: 111.2418472622752
#   ifshres: area weighted rmse: 128.74187124594812
# Fold 17:
#   mse: 18566.552734375
#   PiggyCast: area weighted rmse: 106.30155487580296
#   graphcast: area weighted rmse: 116.57611366232696
#   pangu: area weighted rmse: 136.7779047161893
#   neuralgcm: area weighted rmse: 108.98960118751178
#   ifshres: area weighted rmse: 130.11109100485052
# Fold 18:
#   mse: 24433.560546875
#   PiggyCast: area weighted rmse: 113.94306992719673
#   graphcast: area weighted rmse: 116.11441690279031
#   pangu: area weighted rmse: 122.16377086867567
#   neuralgcm: area weighted rmse: 103.80297163142751
#   ifshres: area weighted rmse: 133.71995966480404
# Fold 19:
#   mse: 16841.541015625
#   PiggyCast: area weighted rmse: 105.11421969902393
#   graphcast: area weighted rmse: 113.07630334503892
#   pangu: area weighted rmse: 122.6866422181686
#   neuralgcm: area weighted rmse: 108.01553929490059
#   ifshres: area weighted rmse: 122.8383967860079
# Fold 20:
#   mse: 14851.142578125
#   PiggyCast: area weighted rmse: 96.3348651077873
#   graphcast: area weighted rmse: 111.5705213782873
#   pangu: area weighted rmse: 114.93573369198597
#   neuralgcm: area weighted rmse: 102.08373743662277
#   ifshres: area weighted rmse: 119.13443368977276
# Fold 21:
#   mse: 19343.029296875
#   PiggyCast: area weighted rmse: 109.82894108021459
#   graphcast: area weighted rmse: 118.21192784799125
#   pangu: area weighted rmse: 130.3116578111673
#   neuralgcm: area weighted rmse: 115.23427444592495
#   ifshres: area weighted rmse: 129.15479577283205
# Fold 22:
#   mse: 28489.353515625
#   PiggyCast: area weighted rmse: 120.23552005466914
#   graphcast: area weighted rmse: 114.98731055877613
#   pangu: area weighted rmse: 133.0073991301169
#   neuralgcm: area weighted rmse: 111.90953081965665
#   ifshres: area weighted rmse: 127.21997752201743
# Fold 23:
#   mse: 18702.64453125
#   PiggyCast: area weighted rmse: 101.72436693508584
#   graphcast: area weighted rmse: 107.59253176918278
#   pangu: area weighted rmse: 128.78784930894622
#   neuralgcm: area weighted rmse: 104.18905010303803
#   ifshres: area weighted rmse: 122.0392964773036
# Fold 24:
#   mse: 18344.265625
#   PiggyCast: area weighted rmse: 103.49010579377833
#   graphcast: area weighted rmse: 114.1448894680766
#   pangu: area weighted rmse: 123.68076088973665
#   neuralgcm: area weighted rmse: 112.20099144547675
#   ifshres: area weighted rmse: 122.0873693213987
# Fold 25:
#   mse: 18749.572265625
#   PiggyCast: area weighted rmse: 106.66239752281696
#   graphcast: area weighted rmse: 118.83753851420217
#   pangu: area weighted rmse: 132.10135833049208
#   neuralgcm: area weighted rmse: 109.78698139963913
#   ifshres: area weighted rmse: 127.50700676729956
# Fold 26:
#   mse: 22414.466796875
#   PiggyCast: area weighted rmse: 108.48130691433911
#   graphcast: area weighted rmse: 112.71629949007901
#   pangu: area weighted rmse: 127.76554362622215
#   neuralgcm: area weighted rmse: 104.05580735404818
#   ifshres: area weighted rmse: 123.29093071663216
# Fold 27:
#   mse: 27567.650390625
#   PiggyCast: area weighted rmse: 117.39087009787808
#   graphcast: area weighted rmse: 113.70186428261262
#   pangu: area weighted rmse: 124.46780116557848
#   neuralgcm: area weighted rmse: 114.65361803350822
#   ifshres: area weighted rmse: 120.8363379681734
# Fold 28:
#   mse: 18177.08984375
#   PiggyCast: area weighted rmse: 104.39313397846685
#   graphcast: area weighted rmse: 118.77773966055393
#   pangu: area weighted rmse: 120.42212916093203
#   neuralgcm: area weighted rmse: 104.4374402743696
#   ifshres: area weighted rmse: 120.97852432337453
# Fold 29:
#   mse: 22459.255859375
#   PiggyCast: area weighted rmse: 111.91603196383528
#   graphcast: area weighted rmse: 116.89497340530667
#   pangu: area weighted rmse: 123.56985805731298
#   neuralgcm: area weighted rmse: 105.05041448402916
#   ifshres: area weighted rmse: 123.6415960150693
# Fold 30:
#   mse: 17509.595703125
#   PiggyCast: area weighted rmse: 101.42499809752096
#   graphcast: area weighted rmse: 116.12467946126449
#   pangu: area weighted rmse: 128.1156233958429
#   neuralgcm: area weighted rmse: 101.0872294170439
#   ifshres: area weighted rmse: 128.9737956163738
# Fold 31:
#   mse: 18079.529296875
#   PiggyCast: area weighted rmse: 103.07631557130068
#   graphcast: area weighted rmse: 115.46927854108515
#   pangu: area weighted rmse: 128.41727780223326
#   neuralgcm: area weighted rmse: 100.49181894672415
#   ifshres: area weighted rmse: 123.32911472009228
# Fold 32:
#   mse: 25693.955078125
#   PiggyCast: area weighted rmse: 109.46947838413396
#   graphcast: area weighted rmse: 113.20362528078877
#   pangu: area weighted rmse: 127.18449132441775
#   neuralgcm: area weighted rmse: 101.6048589534745
#   ifshres: area weighted rmse: 122.97208904083034
# Fold 33:
#   mse: 22268.11328125
#   PiggyCast: area weighted rmse: 113.82981652806406
#   graphcast: area weighted rmse: 120.53657914786027
#   pangu: area weighted rmse: 144.10822715102773
#   neuralgcm: area weighted rmse: 110.94334005100127
#   ifshres: area weighted rmse: 134.49625379646935
# Fold 34:
#   mse: 18228.580078125
#   PiggyCast: area weighted rmse: 99.67992586376134
#   graphcast: area weighted rmse: 110.55704282204341
#   pangu: area weighted rmse: 118.468774182798
#   neuralgcm: area weighted rmse: 98.48156821145129
#   ifshres: area weighted rmse: 120.75965445288513
# Fold 35:
#   mse: 17696.66796875
#   PiggyCast: area weighted rmse: 104.18162783557018
#   graphcast: area weighted rmse: 119.78377560987654
#   pangu: area weighted rmse: 120.66792592027565
#   neuralgcm: area weighted rmse: 102.48303890234624
#   ifshres: area weighted rmse: 133.36114358079394
# Fold 36:
#   mse: 16341.2578125
#   PiggyCast: area weighted rmse: 98.66932925735145
#   graphcast: area weighted rmse: 112.4682462666493
#   pangu: area weighted rmse: 115.2256228237179
#   neuralgcm: area weighted rmse: 98.93838973934155
#   ifshres: area weighted rmse: 119.78088093385878
# Fold 37:
#   mse: 17306.41015625
#   PiggyCast: area weighted rmse: 103.41580345418588
#   graphcast: area weighted rmse: 121.23455998982443
#   pangu: area weighted rmse: 129.61373276528883
#   neuralgcm: area weighted rmse: 105.99879737864579
#   ifshres: area weighted rmse: 134.38224855857763
# Fold 38:
#   mse: 16487.544921875
#   PiggyCast: area weighted rmse: 104.117026422818
#   graphcast: area weighted rmse: 113.55860555779213
#   pangu: area weighted rmse: 118.95311390757873
#   neuralgcm: area weighted rmse: 104.30918315115977
#   ifshres: area weighted rmse: 125.31386485093375
# Fold 39:
#   mse: 22497.517578125
#   PiggyCast: area weighted rmse: 111.97647139756158
#   graphcast: area weighted rmse: 118.41905497586367
#   pangu: area weighted rmse: 124.9801746437583
#   neuralgcm: area weighted rmse: 108.93495205660166
#   ifshres: area weighted rmse: 121.76920147407877
# Fold 40:
#   mse: 16003.8330078125
#   PiggyCast: area weighted rmse: 97.93212090922668
#   graphcast: area weighted rmse: 107.60106255842535
#   pangu: area weighted rmse: 111.69381981227521
#   neuralgcm: area weighted rmse: 94.37092779072043
#   ifshres: area weighted rmse: 114.28263349901304
# Fold 41:
#   mse: 15452.6875
#   PiggyCast: area weighted rmse: 103.13378272942352
#   graphcast: area weighted rmse: 114.59092838688257
#   pangu: area weighted rmse: 124.61939955060073
#   neuralgcm: area weighted rmse: 106.7940679278517
#   ifshres: area weighted rmse: 127.48832881269666
# Fold 42:
#   mse: 13447.2607421875
#   PiggyCast: area weighted rmse: 92.91834571929449
#   graphcast: area weighted rmse: 108.55000519778072
#   pangu: area weighted rmse: 116.15199053027659
#   neuralgcm: area weighted rmse: 97.46560096069506
#   ifshres: area weighted rmse: 116.74674209969916
# Fold 43:
#   mse: 16305.5771484375
#   PiggyCast: area weighted rmse: 99.917013615535
#   graphcast: area weighted rmse: 114.07934437196278
#   pangu: area weighted rmse: 120.51650869239897
#   neuralgcm: area weighted rmse: 106.39626117179372
#   ifshres: area weighted rmse: 121.55008332003325
# Fold 44:
#   mse: 13334.533203125
#   PiggyCast: area weighted rmse: 93.57498595666051
#   graphcast: area weighted rmse: 110.6138116739036
#   pangu: area weighted rmse: 124.22202602697624
#   neuralgcm: area weighted rmse: 99.45830330147065
#   ifshres: area weighted rmse: 118.09662661672036
# Fold 45:
#   mse: 11872.5087890625
#   PiggyCast: area weighted rmse: 92.09654954142152
#   graphcast: area weighted rmse: 105.19007162948161
#   pangu: area weighted rmse: 115.46972373642289
#   neuralgcm: area weighted rmse: 98.73804525537972
#   ifshres: area weighted rmse: 119.14751925555616
# Fold 46:
#   mse: 13865.3955078125
#   PiggyCast: area weighted rmse: 97.70329427830968
#   graphcast: area weighted rmse: 111.64034483005383
#   pangu: area weighted rmse: 125.84289851881805
#   neuralgcm: area weighted rmse: 105.89638899096649
#   ifshres: area weighted rmse: 128.46778442362708
# Fold 47:
#   mse: 13048.4541015625
#   PiggyCast: area weighted rmse: 96.5072427224732
#   graphcast: area weighted rmse: 109.81550213788007
#   pangu: area weighted rmse: 118.3320495528233
#   neuralgcm: area weighted rmse: 100.6314340483918
#   ifshres: area weighted rmse: 120.49618186506098
# Fold 48:
#   mse: 11033.0517578125
#   PiggyCast: area weighted rmse: 88.87818075660826
#   graphcast: area weighted rmse: 105.2287871524704
#   pangu: area weighted rmse: 106.59108695235513
#   neuralgcm: area weighted rmse: 94.94356694981977
#   ifshres: area weighted rmse: 109.29082174129898
# Fold 49:
#   mse: 11001.4365234375
#   PiggyCast: area weighted rmse: 87.42319986305199
#   graphcast: area weighted rmse: 108.61703320630694
#   pangu: area weighted rmse: 115.56762551895287
#   neuralgcm: area weighted rmse: 90.04509996819289
#   ifshres: area weighted rmse: 112.21916129118664
# Fold 50:
#   mse: 15350.0791015625
#   PiggyCast: area weighted rmse: 96.49582080160734
#   graphcast: area weighted rmse: 114.01419188554092
#   pangu: area weighted rmse: 120.84541657927147
#   neuralgcm: area weighted rmse: 94.98249754890665
#   ifshres: area weighted rmse: 118.12671605174803
# {48: {'PiggyCast': 63.99042361214641,
#       'graphcast': 69.46556019429909,
#       'ifshres': 74.58882984327866,
#       'neuralgcm': 60.4314984922077,
#       'pangu': 75.82875875527417},
#  72: {'PiggyCast': 103.75844608396888,
#       'graphcast': 115.11790194314993,
#       'ifshres': 124.75959000338975,
#       'neuralgcm': 104.3154221622194,
#       'pangu': 125.48051701255454}}

# %%
import pandas as pd

# Parameters
n_samples = 1_497_088
n_splits = 50
max_train_size = 32 * 64 * 2 * 14  # 57344
test_size = 32 * 64 * 2 * 7        # 28672
gap = 32 * 64 * 2 * 1              # 4096

# Calculate fold boundaries
folds = []
for i in range(n_splits):
    test_end = n_samples - (n_splits - 1 - i) * test_size
    test_start = test_end - test_size
    train_end = test_start - gap
    train_start = max(0, train_end - max_train_size)

    folds.append({
        "Fold": i + 1,
        "Train Start": train_start,
        "Train End": train_end - 1,
        "Gap Start": train_end,
        "Gap End": test_start - 1,
        "Test Start": test_start,
        "Test End": test_end - 1,
        "Train Size": train_end - train_start,
        "Test Size": test_size,
    })

# Convert to DataFrame
folds_df = pd.DataFrame(folds)
folds_df
# Out:
#     Fold  Train Start  Train End  Gap Start  Gap End  Test Start  Test End  \
# 0      1         2048      59391      59392    63487       63488     92159
# 1      2        30720      88063      88064    92159       92160    120831
# 2      3        59392     116735     116736   120831      120832    149503
# 3      4        88064     145407     145408   149503      149504    178175
# 4      5       116736     174079     174080   178175      178176    206847
# 5      6       145408     202751     202752   206847      206848    235519
# 6      7       174080     231423     231424   235519      235520    264191
# 7      8       202752     260095     260096   264191      264192    292863
# 8      9       231424     288767     288768   292863      292864    321535
# 9     10       260096     317439     317440   321535      321536    350207
# 10    11       288768     346111     346112   350207      350208    378879
# 11    12       317440     374783     374784   378879      378880    407551
# 12    13       346112     403455     403456   407551      407552    436223
# 13    14       374784     432127     432128   436223      436224    464895
# 14    15       403456     460799     460800   464895      464896    493567
# 15    16       432128     489471     489472   493567      493568    522239
# 16    17       460800     518143     518144   522239      522240    550911
# 17    18       489472     546815     546816   550911      550912    579583
# 18    19       518144     575487     575488   579583      579584    608255
# 19    20       546816     604159     604160   608255      608256    636927
# 20    21       575488     632831     632832   636927      636928    665599
# 21    22       604160     661503     661504   665599      665600    694271
# 22    23       632832     690175     690176   694271      694272    722943
# 23    24       661504     718847     718848   722943      722944    751615
# 24    25       690176     747519     747520   751615      751616    780287
# 25    26       718848     776191     776192   780287      780288    808959
# 26    27       747520     804863     804864   808959      808960    837631
# 27    28       776192     833535     833536   837631      837632    866303
# 28    29       804864     862207     862208   866303      866304    894975
# 29    30       833536     890879     890880   894975      894976    923647
# 30    31       862208     919551     919552   923647      923648    952319
# 31    32       890880     948223     948224   952319      952320    980991
# 32    33       919552     976895     976896   980991      980992   1009663
# 33    34       948224    1005567    1005568  1009663     1009664   1038335
# 34    35       976896    1034239    1034240  1038335     1038336   1067007
# 35    36      1005568    1062911    1062912  1067007     1067008   1095679
# 36    37      1034240    1091583    1091584  1095679     1095680   1124351
# 37    38      1062912    1120255    1120256  1124351     1124352   1153023
# 38    39      1091584    1148927    1148928  1153023     1153024   1181695
# 39    40      1120256    1177599    1177600  1181695     1181696   1210367
# 40    41      1148928    1206271    1206272  1210367     1210368   1239039
# 41    42      1177600    1234943    1234944  1239039     1239040   1267711
# 42    43      1206272    1263615    1263616  1267711     1267712   1296383
# 43    44      1234944    1292287    1292288  1296383     1296384   1325055
# 44    45      1263616    1320959    1320960  1325055     1325056   1353727
# 45    46      1292288    1349631    1349632  1353727     1353728   1382399
# 46    47      1320960    1378303    1378304  1382399     1382400   1411071
# 47    48      1349632    1406975    1406976  1411071     1411072   1439743
# 48    49      1378304    1435647    1435648  1439743     1439744   1468415
# 49    50      1406976    1464319    1464320  1468415     1468416   1497087
#
#     Train Size  Test Size
# 0        57344      28672
# 1        57344      28672
# 2        57344      28672
# 3        57344      28672
# 4        57344      28672
# 5        57344      28672
# 6        57344      28672
# 7        57344      28672
# 8        57344      28672
# 9        57344      28672
# 10       57344      28672
# 11       57344      28672
# 12       57344      28672
# 13       57344      28672
# 14       57344      28672
# 15       57344      28672
# 16       57344      28672
# 17       57344      28672
# 18       57344      28672
# 19       57344      28672
# 20       57344      28672
# 21       57344      28672
# 22       57344      28672
# 23       57344      28672
# 24       57344      28672
# 25       57344      28672
# 26       57344      28672
# 27       57344      28672
# 28       57344      28672
# 29       57344      28672
# 30       57344      28672
# 31       57344      28672
# 32       57344      28672
# 33       57344      28672
# 34       57344      28672
# 35       57344      28672
# 36       57344      28672
# 37       57344      28672
# 38       57344      28672
# 39       57344      28672
# 40       57344      28672
# 41       57344      28672
# 42       57344      28672
# 43       57344      28672
# 44       57344      28672
# 45       57344      28672
# 46       57344      28672
# 47       57344      28672
# 48       57344      28672
# 49       57344      28672

# %%
# @title Training and Evaluation Loop- Shorter Time series split : 1 Weeks Training, 1 Day Gap and 3 Days Testing

# Initialize xgb regressor
xgb = xgboost.XGBRegressor(random_state=42, device="cuda")

# Calculate Cross-Validation using 10 folds
cv_timeseries = TimeSeriesSplit(n_splits=100, max_train_size=32 * 64 * 2 * 7,
                                test_size= 32 * 64 * 2 * 3, gap=32 * 64 * 2 * 1)

# Lead Times
lead_times=[48, 72]

nested_scores = {} # Nested scores for each lead time
rmse_results = {} # rmse results for each lead time, models

for lead_time in lead_times:
  print(f"======Lead time: {lead_time}========")

  df_filtered = data_per_lead_time(full_df,lead_time)

  X = df_filtered[[f"graphcast_lt{lead_time}", f"pangu_lt{lead_time}",
                   f"neuralgcm_lt{lead_time}",
                  #  f"keisler_lt{lead_time}",
                   f"ifshres_lt{lead_time}", "longitude", "latitude"]]
  y = df_filtered["era5"]
  area_weight = df_filtered["area_weight"]

  print(f"Shape of x :{X.shape}")
  print(f"Shape of y : {y.shape}")

  # Nested Scores
  nested_score = cross_validate(xgb, X=X, y=y, cv=cv_timeseries,
                              scoring=('neg_mean_squared_error', 'r2'),
                              params={'sample_weight': area_weight}
                              )
  nested_scores[lead_time] = nested_score

  # Cross validation plot
  cross_validation_plot(df_filtered, cv_timeseries, lead_time)

  # RMSE
  rmse_result = train_and_evaluate(xgb, cv_timeseries,X,y, area_weight, lead_time)
  rmse_results[lead_time] = rmse_result

  # RMSE plots per model
  rmse_per_fold_plot(rmse_result, lead_time)

  # print nicely average RMSE per Leadtime
  average_scores = rmse_mean_per_lead_time_and_model(rmse_results)
  pprint(average_scores)
# Out:
# ======Lead time: 48========
# Shape of x :(1497088, 6)
# Shape of y : (1497088,)
# Train times Min Date: 2020-03-01 00:00:00 Train times Max Date:2020-03-07 12:00:00
# Test times Min Date: 2020-03-09 00:00:00 Test times Max Date:2020-03-11 12:00:00
# Train times Min Date: 2020-03-04 00:00:00 Train times Max Date:2020-03-10 12:00:00
# Test times Min Date: 2020-03-12 00:00:00 Test times Max Date:2020-03-14 12:00:00
# Train times Min Date: 2020-03-07 00:00:00 Train times Max Date:2020-03-13 12:00:00
# Test times Min Date: 2020-03-15 00:00:00 Test times Max Date:2020-03-17 12:00:00
# Train times Min Date: 2020-03-10 00:00:00 Train times Max Date:2020-03-16 12:00:00
# Test times Min Date: 2020-03-18 00:00:00 Test times Max Date:2020-03-20 12:00:00
# Train times Min Date: 2020-03-13 00:00:00 Train times Max Date:2020-03-19 12:00:00
# Test times Min Date: 2020-03-21 00:00:00 Test times Max Date:2020-03-23 12:00:00
# Train times Min Date: 2020-03-16 00:00:00 Train times Max Date:2020-03-22 12:00:00
# Test times Min Date: 2020-03-24 00:00:00 Test times Max Date:2020-03-26 12:00:00
# Train times Min Date: 2020-03-19 00:00:00 Train times Max Date:2020-03-25 12:00:00
# Test times Min Date: 2020-03-27 00:00:00 Test times Max Date:2020-03-29 12:00:00
# Train times Min Date: 2020-03-22 00:00:00 Train times Max Date:2020-03-28 12:00:00
# Test times Min Date: 2020-03-30 00:00:00 Test times Max Date:2020-04-01 12:00:00
# Train times Min Date: 2020-03-25 00:00:00 Train times Max Date:2020-03-31 12:00:00
# Test times Min Date: 2020-04-02 00:00:00 Test times Max Date:2020-04-04 12:00:00
# Train times Min Date: 2020-03-28 00:00:00 Train times Max Date:2020-04-03 12:00:00
# Test times Min Date: 2020-04-05 00:00:00 Test times Max Date:2020-04-07 12:00:00
# Fold 1:
#   mse: 16026.4345703125
#   PiggyCast: area weighted rmse: 67.07485118521454
#   graphcast: area weighted rmse: 63.528116632048985
#   pangu: area weighted rmse: 69.82623541730545
#   neuralgcm: area weighted rmse: 57.39974159529101
#   ifshres: area weighted rmse: 74.39076084663702
# Fold 2:
#   mse: 14905.6396484375
#   PiggyCast: area weighted rmse: 72.55741444657635
#   graphcast: area weighted rmse: 69.80057844348728
#   pangu: area weighted rmse: 74.25513535024929
#   neuralgcm: area weighted rmse: 60.208830053653486
#   ifshres: area weighted rmse: 75.74934514322473
# Fold 3:
#   mse: 8128.06884765625
#   PiggyCast: area weighted rmse: 65.56141705181754
#   graphcast: area weighted rmse: 73.86376538360258
#   pangu: area weighted rmse: 87.67624380260702
#   neuralgcm: area weighted rmse: 62.76349023693254
#   ifshres: area weighted rmse: 78.28435169632229
# Fold 4:
#   mse: 10371.9794921875
#   PiggyCast: area weighted rmse: 72.74297567405281
#   graphcast: area weighted rmse: 73.29789206148082
#   pangu: area weighted rmse: 85.99544694242607
#   neuralgcm: area weighted rmse: 62.67720632991744
#   ifshres: area weighted rmse: 79.3888277177181
# Fold 5:
#   mse: 6776.36865234375
#   PiggyCast: area weighted rmse: 60.89426955667031
#   graphcast: area weighted rmse: 71.96241106772962
#   pangu: area weighted rmse: 80.76694262535608
#   neuralgcm: area weighted rmse: 57.75209590466545
#   ifshres: area weighted rmse: 75.90610520625265
# Fold 6:
#   mse: 5428.39404296875
#   PiggyCast: area weighted rmse: 59.16739481845546
#   graphcast: area weighted rmse: 72.57425515310322
#   pangu: area weighted rmse: 83.97789642510301
#   neuralgcm: area weighted rmse: 59.31334307943147
#   ifshres: area weighted rmse: 76.5772444020775
# Fold 7:
#   mse: 6049.22802734375
#   PiggyCast: area weighted rmse: 63.125920230601544
#   graphcast: area weighted rmse: 79.68567456502754
#   pangu: area weighted rmse: 84.31515038858446
#   neuralgcm: area weighted rmse: 63.9309081959343
#   ifshres: area weighted rmse: 83.37296139172727
# Fold 8:
#   mse: 5445.14306640625
#   PiggyCast: area weighted rmse: 61.37534009051485
#   graphcast: area weighted rmse: 74.06071057087333
#   pangu: area weighted rmse: 82.59888987374369
#   neuralgcm: area weighted rmse: 61.62929007754433
#   ifshres: area weighted rmse: 79.07182128406363
# Fold 9:
#   mse: 5220.18896484375
#   PiggyCast: area weighted rmse: 61.127031015226656
#   graphcast: area weighted rmse: 74.86555087506518
#   pangu: area weighted rmse: 83.90898268561646
#   neuralgcm: area weighted rmse: 62.68058481972805
#   ifshres: area weighted rmse: 75.83478867762405
# Fold 10:
#   mse: 7015.21484375
#   PiggyCast: area weighted rmse: 67.31684936285697
#   graphcast: area weighted rmse: 74.26634799075957
#   pangu: area weighted rmse: 80.3785575335109
#   neuralgcm: area weighted rmse: 64.47441088312269
#   ifshres: area weighted rmse: 77.96919387231321
# Fold 11:
#   mse: 10014.6044921875
#   PiggyCast: area weighted rmse: 73.95103115784663
#   graphcast: area weighted rmse: 70.0197776955706
#   pangu: area weighted rmse: 76.30119341134022
#   neuralgcm: area weighted rmse: 64.32253922025681
#   ifshres: area weighted rmse: 76.6785988756065
# Fold 12:
#   mse: 7820.83251953125
#   PiggyCast: area weighted rmse: 67.50058419079186
#   graphcast: area weighted rmse: 67.19139696185968
#   pangu: area weighted rmse: 75.25767147867792
#   neuralgcm: area weighted rmse: 61.64871605194827
#   ifshres: area weighted rmse: 74.87286791751032
# Fold 13:
#   mse: 12531.4453125
#   PiggyCast: area weighted rmse: 72.89568022245562
#   graphcast: area weighted rmse: 80.7406719621238
#   pangu: area weighted rmse: 86.93618210871571
#   neuralgcm: area weighted rmse: 65.00507101905104
#   ifshres: area weighted rmse: 80.67402823398214
# Fold 14:
#   mse: 13866.671875
#   PiggyCast: area weighted rmse: 78.83990306046712
#   graphcast: area weighted rmse: 70.83029308796681
#   pangu: area weighted rmse: 85.64224125709266
#   neuralgcm: area weighted rmse: 60.88117919042858
#   ifshres: area weighted rmse: 78.41027450295596
# Fold 15:
#   mse: 10089.951171875
#   PiggyCast: area weighted rmse: 70.08093399455699
#   graphcast: area weighted rmse: 76.37664742745503
#   pangu: area weighted rmse: 81.81271203574661
#   neuralgcm: area weighted rmse: 59.720218659143804
#   ifshres: area weighted rmse: 75.65486168476284
# Fold 16:
#   mse: 8813.9091796875
#   PiggyCast: area weighted rmse: 63.8713147972778
#   graphcast: area weighted rmse: 66.16898149861926
#   pangu: area weighted rmse: 76.34840389640169
#   neuralgcm: area weighted rmse: 57.68774147638164
#   ifshres: area weighted rmse: 70.80721857859707
# Fold 17:
#   mse: 6197.77734375
#   PiggyCast: area weighted rmse: 61.35732637640518
#   graphcast: area weighted rmse: 67.90899602894001
#   pangu: area weighted rmse: 84.38893569553065
#   neuralgcm: area weighted rmse: 63.916450449255905
#   ifshres: area weighted rmse: 76.831358777655
# Fold 18:
#   mse: 7393.93798828125
#   PiggyCast: area weighted rmse: 65.53546289795257
#   graphcast: area weighted rmse: 69.90963484568798
#   pangu: area weighted rmse: 82.03479061060195
#   neuralgcm: area weighted rmse: 63.32994644075201
#   ifshres: area weighted rmse: 77.11640835391765
# Fold 19:
#   mse: 7254.98388671875
#   PiggyCast: area weighted rmse: 62.713857841888505
#   graphcast: area weighted rmse: 72.21596951927314
#   pangu: area weighted rmse: 81.50037635979997
#   neuralgcm: area weighted rmse: 63.4227342795184
#   ifshres: area weighted rmse: 80.50045661366846
# Fold 20:
#   mse: 6562.08984375
#   PiggyCast: area weighted rmse: 63.6978453701714
#   graphcast: area weighted rmse: 66.20469110074787
#   pangu: area weighted rmse: 69.00132622190321
#   neuralgcm: area weighted rmse: 60.084959399268925
#   ifshres: area weighted rmse: 71.84556369809538
# Fold 21:
#   mse: 7922.04541015625
#   PiggyCast: area weighted rmse: 67.45646763687208
#   graphcast: area weighted rmse: 73.00514804281215
#   pangu: area weighted rmse: 76.9949103292413
#   neuralgcm: area weighted rmse: 62.85255598232444
#   ifshres: area weighted rmse: 75.25445217589865
# Fold 22:
#   mse: 7664.580078125
#   PiggyCast: area weighted rmse: 65.24845502607612
#   graphcast: area weighted rmse: 71.3548912696147
#   pangu: area weighted rmse: 82.62772331780472
#   neuralgcm: area weighted rmse: 63.12107048051377
#   ifshres: area weighted rmse: 79.8991194147559
# Fold 23:
#   mse: 5210.9755859375
#   PiggyCast: area weighted rmse: 59.607230071536165
#   graphcast: area weighted rmse: 68.71027258705597
#   pangu: area weighted rmse: 77.24467080892684
#   neuralgcm: area weighted rmse: 60.54344403884735
#   ifshres: area weighted rmse: 72.42148722435739
# Fold 24:
#   mse: 7713.01171875
#   PiggyCast: area weighted rmse: 64.03045872027937
#   graphcast: area weighted rmse: 64.84138041751675
#   pangu: area weighted rmse: 67.10960873811024
#   neuralgcm: area weighted rmse: 57.03551915945879
#   ifshres: area weighted rmse: 72.06877814543164
# Fold 25:
#   mse: 9321.9443359375
#   PiggyCast: area weighted rmse: 73.99455164003881
#   graphcast: area weighted rmse: 72.32710170885196
#   pangu: area weighted rmse: 76.09989876298143
#   neuralgcm: area weighted rmse: 64.07608113689432
#   ifshres: area weighted rmse: 83.67853635230006
# Fold 26:
#   mse: 10266.8876953125
#   PiggyCast: area weighted rmse: 76.74803217864117
#   graphcast: area weighted rmse: 72.03161760241102
#   pangu: area weighted rmse: 74.93632713619554
#   neuralgcm: area weighted rmse: 63.08734464677965
#   ifshres: area weighted rmse: 76.82832164086096
# Fold 27:
#   mse: 6237.728515625
#   PiggyCast: area weighted rmse: 64.48696240977365
#   graphcast: area weighted rmse: 71.75107803119546
#   pangu: area weighted rmse: 73.72536697679594
#   neuralgcm: area weighted rmse: 63.56519726928368
#   ifshres: area weighted rmse: 73.15794729647838
# Fold 28:
#   mse: 6185.28662109375
#   PiggyCast: area weighted rmse: 63.81330734965503
#   graphcast: area weighted rmse: 72.33497239753495
#   pangu: area weighted rmse: 74.28972589259303
#   neuralgcm: area weighted rmse: 62.67560964514059
#   ifshres: area weighted rmse: 75.389247164498
# Fold 29:
#   mse: 5460.79052734375
#   PiggyCast: area weighted rmse: 59.702827607446935
#   graphcast: area weighted rmse: 70.58031593024079
#   pangu: area weighted rmse: 72.29273386320338
#   neuralgcm: area weighted rmse: 61.44121601050109
#   ifshres: area weighted rmse: 70.53919668633408
# Fold 30:
#   mse: 6678.11376953125
#   PiggyCast: area weighted rmse: 64.8032194237207
#   graphcast: area weighted rmse: 68.40713460875976
#   pangu: area weighted rmse: 71.30556624381771
#   neuralgcm: area weighted rmse: 56.10531431021855
#   ifshres: area weighted rmse: 69.41634890808247
# Fold 31:
#   mse: 8063.08056640625
#   PiggyCast: area weighted rmse: 67.58862790495351
#   graphcast: area weighted rmse: 69.33993559442062
#   pangu: area weighted rmse: 73.26804178975604
#   neuralgcm: area weighted rmse: 62.649117825367334
#   ifshres: area weighted rmse: 71.5516567310338
# Fold 32:
#   mse: 6501.22119140625
#   PiggyCast: area weighted rmse: 64.13468839589154
#   graphcast: area weighted rmse: 66.7129251122143
#   pangu: area weighted rmse: 77.28051746638755
#   neuralgcm: area weighted rmse: 62.43428795512077
#   ifshres: area weighted rmse: 72.34406426960886
# Fold 33:
#   mse: 7076.35546875
#   PiggyCast: area weighted rmse: 65.7879925755303
#   graphcast: area weighted rmse: 68.76536612111552
#   pangu: area weighted rmse: 76.84556681309449
#   neuralgcm: area weighted rmse: 64.4416172539067
#   ifshres: area weighted rmse: 74.47326061861912
# Fold 34:
#   mse: 12333.8232421875
#   PiggyCast: area weighted rmse: 72.51443583837664
#   graphcast: area weighted rmse: 70.70848441709553
#   pangu: area weighted rmse: 76.27656429089113
#   neuralgcm: area weighted rmse: 61.505236344923546
#   ifshres: area weighted rmse: 74.66641636771813
# Fold 35:
#   mse: 21858.466796875
#   PiggyCast: area weighted rmse: 101.5595364632352
#   graphcast: area weighted rmse: 67.81625827502015
#   pangu: area weighted rmse: 79.50556443369689
#   neuralgcm: area weighted rmse: 64.76589476497763
#   ifshres: area weighted rmse: 77.8046919444655
# Fold 36:
#   mse: 8270.2041015625
#   PiggyCast: area weighted rmse: 66.74514760196352
#   graphcast: area weighted rmse: 65.56320470444227
#   pangu: area weighted rmse: 75.7914872887839
#   neuralgcm: area weighted rmse: 60.79041036408328
#   ifshres: area weighted rmse: 71.65602307421175
# Fold 37:
#   mse: 6288.54150390625
#   PiggyCast: area weighted rmse: 59.960946133547274
#   graphcast: area weighted rmse: 64.3696746455245
#   pangu: area weighted rmse: 77.74510628384988
#   neuralgcm: area weighted rmse: 59.94494226938943
#   ifshres: area weighted rmse: 71.06806906778753
# Fold 38:
#   mse: 6640.06005859375
#   PiggyCast: area weighted rmse: 61.3263241706495
#   graphcast: area weighted rmse: 71.89161990855035
#   pangu: area weighted rmse: 73.69500020627441
#   neuralgcm: area weighted rmse: 60.84451559058827
#   ifshres: area weighted rmse: 71.61073020391144
# Fold 39:
#   mse: 6622.23291015625
#   PiggyCast: area weighted rmse: 62.57867537644857
#   graphcast: area weighted rmse: 67.74205679548095
#   pangu: area weighted rmse: 73.35793455017114
#   neuralgcm: area weighted rmse: 64.3540372690372
#   ifshres: area weighted rmse: 72.4221758754096
# Fold 40:
#   mse: 16319.0390625
#   PiggyCast: area weighted rmse: 89.41021137911365
#   graphcast: area weighted rmse: 65.90493352992786
#   pangu: area weighted rmse: 77.6195865197293
#   neuralgcm: area weighted rmse: 60.547936691666386
#   ifshres: area weighted rmse: 76.40693597457825
# Fold 41:
#   mse: 7121.24560546875
#   PiggyCast: area weighted rmse: 67.64359662812386
#   graphcast: area weighted rmse: 67.55252512182598
#   pangu: area weighted rmse: 73.32739045481335
#   neuralgcm: area weighted rmse: 63.05333099993925
#   ifshres: area weighted rmse: 73.96539952521415
# Fold 42:
#   mse: 8788.0087890625
#   PiggyCast: area weighted rmse: 73.82156530321402
#   graphcast: area weighted rmse: 74.37603302981535
#   pangu: area weighted rmse: 81.22521253497167
#   neuralgcm: area weighted rmse: 64.34973556351218
#   ifshres: area weighted rmse: 77.91015608876722
# Fold 43:
#   mse: 8023.70361328125
#   PiggyCast: area weighted rmse: 68.45012422150177
#   graphcast: area weighted rmse: 70.36600334770792
#   pangu: area weighted rmse: 85.9057973650009
#   neuralgcm: area weighted rmse: 62.67442115404485
#   ifshres: area weighted rmse: 73.60560792703828
# Fold 44:
#   mse: 8377.0576171875
#   PiggyCast: area weighted rmse: 65.9815066117731
#   graphcast: area weighted rmse: 71.29747920938743
#   pangu: area weighted rmse: 74.37147624607397
#   neuralgcm: area weighted rmse: 60.959072204294294
#   ifshres: area weighted rmse: 75.2121287153458
# Fold 45:
#   mse: 15716.9873046875
#   PiggyCast: area weighted rmse: 75.75994213373399
#   graphcast: area weighted rmse: 69.05450657478238
#   pangu: area weighted rmse: 75.50631835087835
#   neuralgcm: area weighted rmse: 61.935020484495496
#   ifshres: area weighted rmse: 70.5561513995734
# Fold 46:
#   mse: 9027.9248046875
#   PiggyCast: area weighted rmse: 72.51857047702536
#   graphcast: area weighted rmse: 64.87583796201831
#   pangu: area weighted rmse: 74.35512649964922
#   neuralgcm: area weighted rmse: 69.23433667375755
#   ifshres: area weighted rmse: 67.32365490528751
# Fold 47:
#   mse: 8194.3583984375
#   PiggyCast: area weighted rmse: 66.05909000778611
#   graphcast: area weighted rmse: 72.45966626982182
#   pangu: area weighted rmse: 73.73033203613696
#   neuralgcm: area weighted rmse: 61.236888586235445
#   ifshres: area weighted rmse: 72.91511200856678
# Fold 48:
#   mse: 6266.53369140625
#   PiggyCast: area weighted rmse: 61.28563125450478
#   graphcast: area weighted rmse: 68.48085955563457
#   pangu: area weighted rmse: 73.5037474232463
#   neuralgcm: area weighted rmse: 60.51478027063799
#   ifshres: area weighted rmse: 68.7338339401658
# Fold 49:
#   mse: 7486.43896484375
#   PiggyCast: area weighted rmse: 64.44126900907972
#   graphcast: area weighted rmse: 67.79929792844935
#   pangu: area weighted rmse: 69.31561376790101
#   neuralgcm: area weighted rmse: 60.96542234474056
#   ifshres: area weighted rmse: 72.08249295467161
# Fold 50:
#   mse: 14160.9345703125
#   PiggyCast: area weighted rmse: 83.69050846804693
#   graphcast: area weighted rmse: 68.60421966630216
#   pangu: area weighted rmse: 75.98493025934394
#   neuralgcm: area weighted rmse: 60.821666265156026
#   ifshres: area weighted rmse: 72.13057008046952
# Fold 51:
#   mse: 9988.4501953125
#   PiggyCast: area weighted rmse: 77.36023515265475
#   graphcast: area weighted rmse: 73.32469255846777
#   pangu: area weighted rmse: 77.83429065438173
#   neuralgcm: area weighted rmse: 61.04823951112015
#   ifshres: area weighted rmse: 75.06025274612588
# Fold 52:
#   mse: 7391.45068359375
#   PiggyCast: area weighted rmse: 65.42531174092913
#   graphcast: area weighted rmse: 71.46288535547073
#   pangu: area weighted rmse: 75.05016416240152
#   neuralgcm: area weighted rmse: 61.56782716603222
#   ifshres: area weighted rmse: 80.95544167372574
# Fold 53:
#   mse: 7277.87255859375
#   PiggyCast: area weighted rmse: 63.77732131364991
#   graphcast: area weighted rmse: 67.76234763670017
#   pangu: area weighted rmse: 75.73167135195013
#   neuralgcm: area weighted rmse: 58.8015848307788
#   ifshres: area weighted rmse: 76.28262175262837
# Fold 54:
#   mse: 5977.53564453125
#   PiggyCast: area weighted rmse: 59.98918367029049
#   graphcast: area weighted rmse: 68.03209913403693
#   pangu: area weighted rmse: 76.7267400389618
#   neuralgcm: area weighted rmse: 61.28562250317245
#   ifshres: area weighted rmse: 71.99135895448734
# Fold 55:
#   mse: 11895.8125
#   PiggyCast: area weighted rmse: 81.14237906874736
#   graphcast: area weighted rmse: 72.57315844651598
#   pangu: area weighted rmse: 79.68674797011371
#   neuralgcm: area weighted rmse: 61.54922139898993
#   ifshres: area weighted rmse: 77.8007728017087
# Fold 56:
#   mse: 27134.625
#   PiggyCast: area weighted rmse: 114.13636416921835
#   graphcast: area weighted rmse: 75.78438526689882
#   pangu: area weighted rmse: 74.71593106812195
#   neuralgcm: area weighted rmse: 62.972998339547374
#   ifshres: area weighted rmse: 74.09515569909411
# Fold 57:
#   mse: 12394.1650390625
#   PiggyCast: area weighted rmse: 76.982692670318
#   graphcast: area weighted rmse: 65.83064726473964
#   pangu: area weighted rmse: 74.89297753196256
#   neuralgcm: area weighted rmse: 58.76737956615603
#   ifshres: area weighted rmse: 72.01201617636981
# Fold 58:
#   mse: 7682.40087890625
#   PiggyCast: area weighted rmse: 64.59543893485413
#   graphcast: area weighted rmse: 68.9700903510697
#   pangu: area weighted rmse: 81.09299862514797
#   neuralgcm: area weighted rmse: 63.93721411718045
#   ifshres: area weighted rmse: 75.19476454379539
# Fold 59:
#   mse: 9427.9296875
#   PiggyCast: area weighted rmse: 72.78019654191894
#   graphcast: area weighted rmse: 75.83881758464881
#   pangu: area weighted rmse: 93.44149366792959
#   neuralgcm: area weighted rmse: 65.97933947575868
#   ifshres: area weighted rmse: 83.54443156836027
# Fold 60:
#   mse: 6750.23681640625
#   PiggyCast: area weighted rmse: 67.88400032768328
#   graphcast: area weighted rmse: 71.2439191407096
#   pangu: area weighted rmse: 80.5072263072276
#   neuralgcm: area weighted rmse: 64.42429965299424
#   ifshres: area weighted rmse: 73.68549553560085
# Fold 61:
#   mse: 6596.30419921875
#   PiggyCast: area weighted rmse: 60.8225719078478
#   graphcast: area weighted rmse: 68.23632111260132
#   pangu: area weighted rmse: 70.44922072049296
#   neuralgcm: area weighted rmse: 57.525555969586755
#   ifshres: area weighted rmse: 73.0896447200193
# Fold 62:
#   mse: 7685.48583984375
#   PiggyCast: area weighted rmse: 62.70409059458553
#   graphcast: area weighted rmse: 67.89871463119776
#   pangu: area weighted rmse: 74.33934649117775
#   neuralgcm: area weighted rmse: 59.198802788367686
#   ifshres: area weighted rmse: 75.61699863031332
# Fold 63:
#   mse: 11661.0107421875
#   PiggyCast: area weighted rmse: 66.70329214170171
#   graphcast: area weighted rmse: 62.49833878623749
#   pangu: area weighted rmse: 68.77988558368357
#   neuralgcm: area weighted rmse: 55.26308983346356
#   ifshres: area weighted rmse: 66.31365843010413
# Fold 64:
#   mse: 7696.95556640625
#   PiggyCast: area weighted rmse: 67.77995524956172
#   graphcast: area weighted rmse: 71.2977654532686
#   pangu: area weighted rmse: 73.26074175827523
#   neuralgcm: area weighted rmse: 60.545128921851166
#   ifshres: area weighted rmse: 76.47058753812185
# Fold 65:
#   mse: 5841.81982421875
#   PiggyCast: area weighted rmse: 61.35488807566754
#   graphcast: area weighted rmse: 72.42998452607202
#   pangu: area weighted rmse: 72.40467535349471
#   neuralgcm: area weighted rmse: 60.36385106477054
#   ifshres: area weighted rmse: 77.79157515800149
# Fold 66:
#   mse: 7396.708984375
#   PiggyCast: area weighted rmse: 65.30947494373036
#   graphcast: area weighted rmse: 66.16290063042487
#   pangu: area weighted rmse: 72.15633119175595
#   neuralgcm: area weighted rmse: 61.564149041131934
#   ifshres: area weighted rmse: 72.16857227656088
# Fold 67:
#   mse: 5681.80859375
#   PiggyCast: area weighted rmse: 57.88192163238991
#   graphcast: area weighted rmse: 64.87813111047019
#   pangu: area weighted rmse: 68.43923408547805
#   neuralgcm: area weighted rmse: 57.05350783844874
#   ifshres: area weighted rmse: 73.66258320810877
# Fold 68:
#   mse: 5597.20703125
#   PiggyCast: area weighted rmse: 57.89470821026119
#   graphcast: area weighted rmse: 68.27320734496364
#   pangu: area weighted rmse: 71.31199465410761
#   neuralgcm: area weighted rmse: 55.26985611874308
#   ifshres: area weighted rmse: 67.43645298391635
# Fold 69:
#   mse: 6144.203125
#   PiggyCast: area weighted rmse: 62.058865150270236
#   graphcast: area weighted rmse: 73.41459293021033
#   pangu: area weighted rmse: 78.13600298283035
#   neuralgcm: area weighted rmse: 62.27362460895516
#   ifshres: area weighted rmse: 76.99911593996256
# Fold 70:
#   mse: 6430.76318359375
#   PiggyCast: area weighted rmse: 66.16638513097425
#   graphcast: area weighted rmse: 79.99647005050018
#   pangu: area weighted rmse: 77.92046411468718
#   neuralgcm: area weighted rmse: 59.737564734449904
#   ifshres: area weighted rmse: 82.31245093091802
# Fold 71:
#   mse: 7283.66552734375
#   PiggyCast: area weighted rmse: 67.94760687957772
#   graphcast: area weighted rmse: 71.59561212962049
#   pangu: area weighted rmse: 74.85555767957912
#   neuralgcm: area weighted rmse: 64.32390162823026
#   ifshres: area weighted rmse: 75.14801884346862
# Fold 72:
#   mse: 10566.521484375
#   PiggyCast: area weighted rmse: 78.09912455203758
#   graphcast: area weighted rmse: 66.92399891278144
#   pangu: area weighted rmse: 69.16500648954431
#   neuralgcm: area weighted rmse: 57.66187134030229
#   ifshres: area weighted rmse: 66.94915355057687
# Fold 73:
#   mse: 5800.13037109375
#   PiggyCast: area weighted rmse: 59.468407290886205
#   graphcast: area weighted rmse: 64.99969750662562
#   pangu: area weighted rmse: 67.07042141532952
#   neuralgcm: area weighted rmse: 57.17618862919713
#   ifshres: area weighted rmse: 68.59468336832802
# Fold 74:
#   mse: 6636.76318359375
#   PiggyCast: area weighted rmse: 63.16079070238436
#   graphcast: area weighted rmse: 67.22551022334953
#   pangu: area weighted rmse: 76.52616714364824
#   neuralgcm: area weighted rmse: 63.88009431360945
#   ifshres: area weighted rmse: 73.36445540498853
# Fold 75:
#   mse: 9058.0283203125
#   PiggyCast: area weighted rmse: 65.55011958136261
#   graphcast: area weighted rmse: 69.04248922471318
#   pangu: area weighted rmse: 70.83556339753423
#   neuralgcm: area weighted rmse: 56.10736791712454
#   ifshres: area weighted rmse: 72.01409443113812
# Fold 76:
#   mse: 8530.3076171875
#   PiggyCast: area weighted rmse: 66.9412973657278
#   graphcast: area weighted rmse: 69.27713913134738
#   pangu: area weighted rmse: 68.33872617130288
#   neuralgcm: area weighted rmse: 58.188285722406334
#   ifshres: area weighted rmse: 67.4802789297171
# Fold 77:
#   mse: 5271.0205078125
#   PiggyCast: area weighted rmse: 58.264841522002904
#   graphcast: area weighted rmse: 70.80987778115595
#   pangu: area weighted rmse: 68.94252599224843
#   neuralgcm: area weighted rmse: 58.13404526080306
#   ifshres: area weighted rmse: 68.92377902724603
# Fold 78:
#   mse: 5937.107421875
#   PiggyCast: area weighted rmse: 63.48356299463958
#   graphcast: area weighted rmse: 71.32066494725831
#   pangu: area weighted rmse: 76.3471668083151
#   neuralgcm: area weighted rmse: 63.60059194110402
#   ifshres: area weighted rmse: 75.99036759199673
# Fold 79:
#   mse: 5202.20361328125
#   PiggyCast: area weighted rmse: 59.70246203565609
#   graphcast: area weighted rmse: 69.49505328248497
#   pangu: area weighted rmse: 73.27723874895985
#   neuralgcm: area weighted rmse: 59.28114559426511
#   ifshres: area weighted rmse: 73.77083173068291
# Fold 80:
#   mse: 7842.55859375
#   PiggyCast: area weighted rmse: 63.9720105454758
#   graphcast: area weighted rmse: 67.96221287055702
#   pangu: area weighted rmse: 73.84365659763809
#   neuralgcm: area weighted rmse: 60.60193247752602
#   ifshres: area weighted rmse: 73.4461790247724
# Fold 81:
#   mse: 8504.44140625
#   PiggyCast: area weighted rmse: 66.57996141716634
#   graphcast: area weighted rmse: 69.52465286528769
#   pangu: area weighted rmse: 73.34868181678394
#   neuralgcm: area weighted rmse: 58.568603969477515
#   ifshres: area weighted rmse: 74.30716472697756
# Fold 82:
#   mse: 4695.54052734375
#   PiggyCast: area weighted rmse: 55.55539118635149
#   graphcast: area weighted rmse: 69.35992370069748
#   pangu: area weighted rmse: 70.64385527900986
#   neuralgcm: area weighted rmse: 57.94404522502867
#   ifshres: area weighted rmse: 65.42889208446081
# Fold 83:
#   mse: 6188.61181640625
#   PiggyCast: area weighted rmse: 62.90338629278965
#   graphcast: area weighted rmse: 69.32034998857236
#   pangu: area weighted rmse: 74.37934881879875
#   neuralgcm: area weighted rmse: 63.83277254958075
#   ifshres: area weighted rmse: 72.50609706909326
# Fold 84:
#   mse: 5383.419921875
#   PiggyCast: area weighted rmse: 60.38007767898381
#   graphcast: area weighted rmse: 70.41434024607959
#   pangu: area weighted rmse: 78.68842569345792
#   neuralgcm: area weighted rmse: 58.64261309644124
#   ifshres: area weighted rmse: 76.73703669870716
# Fold 85:
#   mse: 4655.85986328125
#   PiggyCast: area weighted rmse: 55.84307088758859
#   graphcast: area weighted rmse: 65.01674973199358
#   pangu: area weighted rmse: 74.11260507129431
#   neuralgcm: area weighted rmse: 57.42787773452857
#   ifshres: area weighted rmse: 72.96900558777894
# Fold 86:
#   mse: 5208.30615234375
#   PiggyCast: area weighted rmse: 59.67504378514373
#   graphcast: area weighted rmse: 67.58565872995399
#   pangu: area weighted rmse: 75.11890296280995
#   neuralgcm: area weighted rmse: 59.09770824470816
#   ifshres: area weighted rmse: 72.56375980134459
# Fold 87:
#   mse: 4729.30126953125
#   PiggyCast: area weighted rmse: 58.5097879197183
#   graphcast: area weighted rmse: 65.48524110959589
#   pangu: area weighted rmse: 70.41805470431713
#   neuralgcm: area weighted rmse: 60.09363720200548
#   ifshres: area weighted rmse: 68.09463259364902
# Fold 88:
#   mse: 5626.78125
#   PiggyCast: area weighted rmse: 61.446184897226445
#   graphcast: area weighted rmse: 64.8933015515048
#   pangu: area weighted rmse: 72.30412799596166
#   neuralgcm: area weighted rmse: 61.487145197574264
#   ifshres: area weighted rmse: 76.46093585359174
# Fold 89:
#   mse: 4660.59423828125
#   PiggyCast: area weighted rmse: 56.90681344250185
#   graphcast: area weighted rmse: 64.03785505901803
#   pangu: area weighted rmse: 70.83478203668723
#   neuralgcm: area weighted rmse: 56.55511888748977
#   ifshres: area weighted rmse: 70.96231358057865
# Fold 90:
#   mse: 4186.71337890625
#   PiggyCast: area weighted rmse: 55.0685306870987
#   graphcast: area weighted rmse: 65.75870257259616
#   pangu: area weighted rmse: 70.01856813416633
#   neuralgcm: area weighted rmse: 57.08772321724233
#   ifshres: area weighted rmse: 76.44586042100859
# Fold 91:
#   mse: 5846.47216796875
#   PiggyCast: area weighted rmse: 61.27450755141793
#   graphcast: area weighted rmse: 70.44874467244081
#   pangu: area weighted rmse: 81.71326402096831
#   neuralgcm: area weighted rmse: 63.08018731012238
#   ifshres: area weighted rmse: 76.71133264881449
# Fold 92:
#   mse: 5676.12060546875
#   PiggyCast: area weighted rmse: 61.87754542345218
#   graphcast: area weighted rmse: 66.45157393344768
#   pangu: area weighted rmse: 73.73399214981049
#   neuralgcm: area weighted rmse: 60.03102656142231
#   ifshres: area weighted rmse: 75.83934965976458
# Fold 93:
#   mse: 5317.56591796875
#   PiggyCast: area weighted rmse: 60.52048683998803
#   graphcast: area weighted rmse: 66.46387187273366
#   pangu: area weighted rmse: 72.61516881862228
#   neuralgcm: area weighted rmse: 57.29172839177175
#   ifshres: area weighted rmse: 72.7858430004564
# Fold 94:
#   mse: 3907.001220703125
#   PiggyCast: area weighted rmse: 55.354525232784056
#   graphcast: area weighted rmse: 64.79197272252297
#   pangu: area weighted rmse: 66.1674761114394
#   neuralgcm: area weighted rmse: 57.744947582799604
#   ifshres: area weighted rmse: 68.65099916929752
# Fold 95:
#   mse: 4150.00390625
#   PiggyCast: area weighted rmse: 53.98111929316222
#   graphcast: area weighted rmse: 67.02590580826411
#   pangu: area weighted rmse: 68.4814820778376
#   neuralgcm: area weighted rmse: 56.20742494347932
#   ifshres: area weighted rmse: 67.17807380552044
# Fold 96:
#   mse: 4227.00634765625
#   PiggyCast: area weighted rmse: 55.04378311288258
#   graphcast: area weighted rmse: 61.681604102450756
#   pangu: area weighted rmse: 64.90623587052977
#   neuralgcm: area weighted rmse: 55.81326946605661
#   ifshres: area weighted rmse: 65.83321441585367
# Fold 97:
#   mse: 4596.9892578125
#   PiggyCast: area weighted rmse: 57.75523876542025
#   graphcast: area weighted rmse: 61.92425584284546
#   pangu: area weighted rmse: 64.80676293602282
#   neuralgcm: area weighted rmse: 54.16063807336266
#   ifshres: area weighted rmse: 69.61885670378497
# Fold 98:
#   mse: 4321.09912109375
#   PiggyCast: area weighted rmse: 56.47600776857475
#   graphcast: area weighted rmse: 72.6528198519015
#   pangu: area weighted rmse: 77.88233381649916
#   neuralgcm: area weighted rmse: 58.98469939604857
#   ifshres: area weighted rmse: 74.03140986791682
# Fold 99:
#   mse: 5103.3935546875
#   PiggyCast: area weighted rmse: 56.53839056046998
#   graphcast: area weighted rmse: 74.1828382770977
#   pangu: area weighted rmse: 73.72712797024603
#   neuralgcm: area weighted rmse: 55.084814307400066
#   ifshres: area weighted rmse: 72.19589880259477
# Fold 100:
#   mse: 6724.95068359375
#   PiggyCast: area weighted rmse: 64.96300412645394
#   graphcast: area weighted rmse: 69.83360864967516
#   pangu: area weighted rmse: 75.85008752755174
#   neuralgcm: area weighted rmse: 58.91765378958519
#   ifshres: area weighted rmse: 76.3083728000464
# {48: {'PiggyCast': 65.98529662326521,
#       'graphcast': 69.5591285985073,
#       'ifshres': 74.10824446618233,
#       'neuralgcm': 60.71513398370254,
#       'pangu': 75.6399261334173}}
# ======Lead time: 72========
# Shape of x :(1497088, 6)
# Shape of y : (1497088,)
# Train times Min Date: 2020-03-02 00:00:00 Train times Max Date:2020-03-08 12:00:00
# Test times Min Date: 2020-03-10 00:00:00 Test times Max Date:2020-03-12 12:00:00
# Train times Min Date: 2020-03-05 00:00:00 Train times Max Date:2020-03-11 12:00:00
# Test times Min Date: 2020-03-13 00:00:00 Test times Max Date:2020-03-15 12:00:00
# Train times Min Date: 2020-03-08 00:00:00 Train times Max Date:2020-03-14 12:00:00
# Test times Min Date: 2020-03-16 00:00:00 Test times Max Date:2020-03-18 12:00:00
# Train times Min Date: 2020-03-11 00:00:00 Train times Max Date:2020-03-17 12:00:00
# Test times Min Date: 2020-03-19 00:00:00 Test times Max Date:2020-03-21 12:00:00
# Train times Min Date: 2020-03-14 00:00:00 Train times Max Date:2020-03-20 12:00:00
# Test times Min Date: 2020-03-22 00:00:00 Test times Max Date:2020-03-24 12:00:00
# Train times Min Date: 2020-03-17 00:00:00 Train times Max Date:2020-03-23 12:00:00
# Test times Min Date: 2020-03-25 00:00:00 Test times Max Date:2020-03-27 12:00:00
# Train times Min Date: 2020-03-20 00:00:00 Train times Max Date:2020-03-26 12:00:00
# Test times Min Date: 2020-03-28 00:00:00 Test times Max Date:2020-03-30 12:00:00
# Train times Min Date: 2020-03-23 00:00:00 Train times Max Date:2020-03-29 12:00:00
# Test times Min Date: 2020-03-31 00:00:00 Test times Max Date:2020-04-02 12:00:00
# Train times Min Date: 2020-03-26 00:00:00 Train times Max Date:2020-04-01 12:00:00
# Test times Min Date: 2020-04-03 00:00:00 Test times Max Date:2020-04-05 12:00:00
# Train times Min Date: 2020-03-29 00:00:00 Train times Max Date:2020-04-04 12:00:00
# Test times Min Date: 2020-04-06 00:00:00 Test times Max Date:2020-04-08 12:00:00
# Fold 1:
#   mse: 27935.09375
#   PiggyCast: area weighted rmse: 104.92545247266249
#   graphcast: area weighted rmse: 102.3768425748744
#   pangu: area weighted rmse: 111.85332065676496
#   neuralgcm: area weighted rmse: 94.53941177586162
#   ifshres: area weighted rmse: 119.20425523289474
# Fold 2:
#   mse: 24427.0
#   PiggyCast: area weighted rmse: 108.5597913356762
#   graphcast: area weighted rmse: 116.18889892256601
#   pangu: area weighted rmse: 120.60965236675537
#   neuralgcm: area weighted rmse: 111.9551915082939
#   ifshres: area weighted rmse: 134.10029250653756
# Fold 3:
#   mse: 18510.287109375
#   PiggyCast: area weighted rmse: 105.7651830212297
#   graphcast: area weighted rmse: 115.53644171872448
#   pangu: area weighted rmse: 134.10771035214867
#   neuralgcm: area weighted rmse: 107.55901759636853
#   ifshres: area weighted rmse: 130.0567107445908
# Fold 4:
#   mse: 20507.740234375
#   PiggyCast: area weighted rmse: 113.25733133790311
#   graphcast: area weighted rmse: 129.4140278689898
#   pangu: area weighted rmse: 143.7403645916613
#   neuralgcm: area weighted rmse: 110.16750736569035
#   ifshres: area weighted rmse: 138.26805577771438
# Fold 5:
#   mse: 19167.185546875
#   PiggyCast: area weighted rmse: 101.7699716158704
#   graphcast: area weighted rmse: 123.37844177827313
#   pangu: area weighted rmse: 134.26405649164306
#   neuralgcm: area weighted rmse: 98.04413203205601
#   ifshres: area weighted rmse: 124.46198406271732
# Fold 6:
#   mse: 14894.4052734375
#   PiggyCast: area weighted rmse: 100.99842297995504
#   graphcast: area weighted rmse: 123.37493018346098
#   pangu: area weighted rmse: 137.76019058912223
#   neuralgcm: area weighted rmse: 101.10826495285248
#   ifshres: area weighted rmse: 130.215609962425
# Fold 7:
#   mse: 19618.8984375
#   PiggyCast: area weighted rmse: 112.38655382309103
#   graphcast: area weighted rmse: 138.64720179576204
#   pangu: area weighted rmse: 146.86430450970502
#   neuralgcm: area weighted rmse: 113.10613004775476
#   ifshres: area weighted rmse: 143.8509403788487
# Fold 8:
#   mse: 16916.056640625
#   PiggyCast: area weighted rmse: 110.15374021331922
#   graphcast: area weighted rmse: 127.50807907591611
#   pangu: area weighted rmse: 135.7547043663289
#   neuralgcm: area weighted rmse: 112.06389941918572
#   ifshres: area weighted rmse: 135.0171906085506
# Fold 9:
#   mse: 17763.505859375
#   PiggyCast: area weighted rmse: 110.30656550572635
#   graphcast: area weighted rmse: 123.57206044426206
#   pangu: area weighted rmse: 142.25803673728302
#   neuralgcm: area weighted rmse: 117.35035523011032
#   ifshres: area weighted rmse: 128.98894973966725
# Fold 10:
#   mse: 21848.677734375
#   PiggyCast: area weighted rmse: 119.5215464957434
#   graphcast: area weighted rmse: 125.13268494608928
#   pangu: area weighted rmse: 139.77104861287853
#   neuralgcm: area weighted rmse: 118.59270861291407
#   ifshres: area weighted rmse: 129.48259746320394
# Fold 11:
#   mse: 22628.2265625
#   PiggyCast: area weighted rmse: 122.68118996138651
#   graphcast: area weighted rmse: 121.37279045231418
#   pangu: area weighted rmse: 138.16874570758912
#   neuralgcm: area weighted rmse: 129.9830071521657
#   ifshres: area weighted rmse: 129.84055807877502
# Fold 12:
#   mse: 21519.537109375
#   PiggyCast: area weighted rmse: 112.59022847828825
#   graphcast: area weighted rmse: 117.24448877134573
#   pangu: area weighted rmse: 129.19729016615744
#   neuralgcm: area weighted rmse: 109.23806139533816
#   ifshres: area weighted rmse: 127.72849882360018
# Fold 13:
#   mse: 27207.373046875
#   PiggyCast: area weighted rmse: 120.06170093169008
#   graphcast: area weighted rmse: 133.67014538678708
#   pangu: area weighted rmse: 143.52023852693753
#   neuralgcm: area weighted rmse: 106.77198272819979
#   ifshres: area weighted rmse: 139.73221879408055
# Fold 14:
#   mse: 29046.994140625
#   PiggyCast: area weighted rmse: 118.01325861930138
#   graphcast: area weighted rmse: 121.9690682172243
#   pangu: area weighted rmse: 145.34438499925292
#   neuralgcm: area weighted rmse: 107.8854781134828
#   ifshres: area weighted rmse: 135.05954040864452
# Fold 15:
#   mse: 19134.00390625
#   PiggyCast: area weighted rmse: 108.52093956377415
#   graphcast: area weighted rmse: 131.84253081554945
#   pangu: area weighted rmse: 131.23474550384134
#   neuralgcm: area weighted rmse: 103.69525970807017
#   ifshres: area weighted rmse: 124.84549003365345
# Fold 16:
#   mse: 23128.353515625
#   PiggyCast: area weighted rmse: 105.93721304805695
#   graphcast: area weighted rmse: 115.48886302556815
#   pangu: area weighted rmse: 129.64177113560567
#   neuralgcm: area weighted rmse: 100.06776731012403
#   ifshres: area weighted rmse: 124.74779555703067
# Fold 17:
#   mse: 25688.544921875
#   PiggyCast: area weighted rmse: 119.27544289309924
#   graphcast: area weighted rmse: 123.66528888942787
#   pangu: area weighted rmse: 142.35986374122774
#   neuralgcm: area weighted rmse: 122.78045204027755
#   ifshres: area weighted rmse: 132.73268050213977
# Fold 18:
#   mse: 18976.412109375
#   PiggyCast: area weighted rmse: 106.72565861224628
#   graphcast: area weighted rmse: 118.24526851459306
#   pangu: area weighted rmse: 139.30521488316285
#   neuralgcm: area weighted rmse: 104.23119890054771
#   ifshres: area weighted rmse: 128.50283985181252
# Fold 19:
#   mse: 21141.9921875
#   PiggyCast: area weighted rmse: 110.10177796522419
#   graphcast: area weighted rmse: 121.62424973719337
#   pangu: area weighted rmse: 130.68590334026484
#   neuralgcm: area weighted rmse: 112.49682180860084
#   ifshres: area weighted rmse: 139.42939759533286
# Fold 20:
#   mse: 20166.869140625
#   PiggyCast: area weighted rmse: 109.86875459677773
#   graphcast: area weighted rmse: 108.3827208621764
#   pangu: area weighted rmse: 109.92646522146917
#   neuralgcm: area weighted rmse: 104.62065272597334
#   ifshres: area weighted rmse: 123.06612296956109
# Fold 21:
#   mse: 23370.306640625
#   PiggyCast: area weighted rmse: 116.5524869400482
#   graphcast: area weighted rmse: 123.95339342084439
#   pangu: area weighted rmse: 135.00552191649788
#   neuralgcm: area weighted rmse: 117.24691709514396
#   ifshres: area weighted rmse: 132.02765685358364
# Fold 22:
#   mse: 23300.595703125
#   PiggyCast: area weighted rmse: 117.26730165939448
#   graphcast: area weighted rmse: 121.36013973175267
#   pangu: area weighted rmse: 145.37014145551902
#   neuralgcm: area weighted rmse: 116.95931990027306
#   ifshres: area weighted rmse: 141.37041608369307
# Fold 23:
#   mse: 15755.55859375
#   PiggyCast: area weighted rmse: 100.68203957370376
#   graphcast: area weighted rmse: 110.05520796004167
#   pangu: area weighted rmse: 126.59017218361531
#   neuralgcm: area weighted rmse: 99.78578007873995
#   ifshres: area weighted rmse: 113.71774731874477
# Fold 24:
#   mse: 19807.04296875
#   PiggyCast: area weighted rmse: 104.8433487323742
#   graphcast: area weighted rmse: 105.57954828760207
#   pangu: area weighted rmse: 108.56280413172676
#   neuralgcm: area weighted rmse: 95.76937699048959
#   ifshres: area weighted rmse: 120.59116331156302
# Fold 25:
#   mse: 25604.990234375
#   PiggyCast: area weighted rmse: 120.25897736575467
#   graphcast: area weighted rmse: 122.4503903426125
#   pangu: area weighted rmse: 130.77573444592554
#   neuralgcm: area weighted rmse: 109.20631024056614
#   ifshres: area weighted rmse: 144.73087834228022
# Fold 26:
#   mse: 17873.181640625
#   PiggyCast: area weighted rmse: 109.07685151862326
#   graphcast: area weighted rmse: 115.49095685530399
#   pangu: area weighted rmse: 121.3484039559923
#   neuralgcm: area weighted rmse: 110.52536923196438
#   ifshres: area weighted rmse: 127.52376172758527
# Fold 27:
#   mse: 16730.509765625
#   PiggyCast: area weighted rmse: 106.89634340649881
#   graphcast: area weighted rmse: 113.41105765916706
#   pangu: area weighted rmse: 129.34705947309493
#   neuralgcm: area weighted rmse: 106.64864742577542
#   ifshres: area weighted rmse: 126.61903835195889
# Fold 28:
#   mse: 17440.611328125
#   PiggyCast: area weighted rmse: 105.82242084811028
#   graphcast: area weighted rmse: 118.46772685471893
#   pangu: area weighted rmse: 120.55977116384979
#   neuralgcm: area weighted rmse: 109.00187305796265
#   ifshres: area weighted rmse: 127.77075400970229
# Fold 29:
#   mse: 14819.8671875
#   PiggyCast: area weighted rmse: 97.97322615845198
#   graphcast: area weighted rmse: 106.44375909355001
#   pangu: area weighted rmse: 110.98485223775758
#   neuralgcm: area weighted rmse: 106.64475232788055
#   ifshres: area weighted rmse: 111.82804405747167
# Fold 30:
#   mse: 17903.833984375
#   PiggyCast: area weighted rmse: 102.64910178957733
#   graphcast: area weighted rmse: 112.3963120285822
#   pangu: area weighted rmse: 116.49585107800229
#   neuralgcm: area weighted rmse: 93.48482599685327
#   ifshres: area weighted rmse: 115.90041395613947
# Fold 31:
#   mse: 21408.017578125
#   PiggyCast: area weighted rmse: 113.97933737923903
#   graphcast: area weighted rmse: 119.81977673672243
#   pangu: area weighted rmse: 132.756796470274
#   neuralgcm: area weighted rmse: 115.27388030391535
#   ifshres: area weighted rmse: 127.59727693972064
# Fold 32:
#   mse: 23222.244140625
#   PiggyCast: area weighted rmse: 112.27267204743809
#   graphcast: area weighted rmse: 118.16744936665532
#   pangu: area weighted rmse: 128.925979994372
#   neuralgcm: area weighted rmse: 111.66901605848159
#   ifshres: area weighted rmse: 129.18029922652565
# Fold 33:
#   mse: 21929.419921875
#   PiggyCast: area weighted rmse: 115.41709534370054
#   graphcast: area weighted rmse: 114.7383679093296
#   pangu: area weighted rmse: 127.9719841289949
#   neuralgcm: area weighted rmse: 118.95660168537269
#   ifshres: area weighted rmse: 127.33779165539411
# Fold 34:
#   mse: 30041.072265625
#   PiggyCast: area weighted rmse: 119.87212068182747
#   graphcast: area weighted rmse: 117.53101468253303
#   pangu: area weighted rmse: 132.69349811058862
#   neuralgcm: area weighted rmse: 107.60423638487543
#   ifshres: area weighted rmse: 125.29794726932569
# Fold 35:
#   mse: 35854.1171875
#   PiggyCast: area weighted rmse: 134.9982290842255
#   graphcast: area weighted rmse: 109.91302426366282
#   pangu: area weighted rmse: 131.92521746427263
#   neuralgcm: area weighted rmse: 111.31646421377317
#   ifshres: area weighted rmse: 130.41063759368777
# Fold 36:
#   mse: 21855.134765625
#   PiggyCast: area weighted rmse: 105.6817379959423
#   graphcast: area weighted rmse: 108.56349663477896
#   pangu: area weighted rmse: 128.34818399811107
#   neuralgcm: area weighted rmse: 105.3369874359609
#   ifshres: area weighted rmse: 122.19781074925949
# Fold 37:
#   mse: 21090.943359375
#   PiggyCast: area weighted rmse: 105.01369610198337
#   graphcast: area weighted rmse: 106.31567938679115
#   pangu: area weighted rmse: 132.2677614004076
#   neuralgcm: area weighted rmse: 102.76578907851318
#   ifshres: area weighted rmse: 120.89842584333508
# Fold 38:
#   mse: 19597.203125
#   PiggyCast: area weighted rmse: 105.86228883215807
#   graphcast: area weighted rmse: 123.02021006787412
#   pangu: area weighted rmse: 122.60296213879433
#   neuralgcm: area weighted rmse: 112.32610625882246
#   ifshres: area weighted rmse: 124.4231718275457
# Fold 39:
#   mse: 21477.224609375
#   PiggyCast: area weighted rmse: 109.85310469790356
#   graphcast: area weighted rmse: 105.42086112216734
#   pangu: area weighted rmse: 123.42422176092832
#   neuralgcm: area weighted rmse: 114.9271465421272
#   ifshres: area weighted rmse: 119.37719747604339
# Fold 40:
#   mse: 21265.7890625
#   PiggyCast: area weighted rmse: 112.42418023491851
#   graphcast: area weighted rmse: 111.0889866590082
#   pangu: area weighted rmse: 131.41134652848947
#   neuralgcm: area weighted rmse: 101.95952337429969
#   ifshres: area weighted rmse: 127.04733125204538
# Fold 41:
#   mse: 23152.525390625
#   PiggyCast: area weighted rmse: 119.39523621637571
#   graphcast: area weighted rmse: 122.81774242789385
#   pangu: area weighted rmse: 134.62748991161192
#   neuralgcm: area weighted rmse: 115.43302355222615
#   ifshres: area weighted rmse: 128.06010857123061
# Fold 42:
#   mse: 21083.015625
#   PiggyCast: area weighted rmse: 112.79038845335582
#   graphcast: area weighted rmse: 121.52578534071802
#   pangu: area weighted rmse: 134.99835226486042
#   neuralgcm: area weighted rmse: 108.18019965343561
#   ifshres: area weighted rmse: 131.86691633441225
# Fold 43:
#   mse: 20100.841796875
#   PiggyCast: area weighted rmse: 109.55404034142295
#   graphcast: area weighted rmse: 111.12168805406635
#   pangu: area weighted rmse: 126.79315555298952
#   neuralgcm: area weighted rmse: 107.25399250428381
#   ifshres: area weighted rmse: 117.68230525293924
# Fold 44:
#   mse: 23049.484375
#   PiggyCast: area weighted rmse: 106.61321377477276
#   graphcast: area weighted rmse: 110.4951777394958
#   pangu: area weighted rmse: 120.58658509066088
#   neuralgcm: area weighted rmse: 100.05343352170813
#   ifshres: area weighted rmse: 121.12901772635514
# Fold 45:
#   mse: 25120.818359375
#   PiggyCast: area weighted rmse: 116.71900704100224
#   graphcast: area weighted rmse: 116.65982247294286
#   pangu: area weighted rmse: 126.0414879332587
#   neuralgcm: area weighted rmse: 107.84318619991895
#   ifshres: area weighted rmse: 121.75436415734654
# Fold 46:
#   mse: 22258.875
#   PiggyCast: area weighted rmse: 110.4322166770607
#   graphcast: area weighted rmse: 108.37665385500378
#   pangu: area weighted rmse: 122.31692007003754
#   neuralgcm: area weighted rmse: 124.07931504776207
#   ifshres: area weighted rmse: 116.3105740765782
# Fold 47:
#   mse: 24151.638671875
#   PiggyCast: area weighted rmse: 113.82356335546326
#   graphcast: area weighted rmse: 128.88261994734003
#   pangu: area weighted rmse: 122.4124013136989
#   neuralgcm: area weighted rmse: 106.28158832553986
#   ifshres: area weighted rmse: 129.10595326310911
# Fold 48:
#   mse: 17415.099609375
#   PiggyCast: area weighted rmse: 102.93872024398226
#   graphcast: area weighted rmse: 112.9282797723122
#   pangu: area weighted rmse: 123.36447891866253
#   neuralgcm: area weighted rmse: 101.28254897889855
#   ifshres: area weighted rmse: 111.8864017079987
# Fold 49:
#   mse: 24382.716796875
#   PiggyCast: area weighted rmse: 113.12604059356269
#   graphcast: area weighted rmse: 112.00136486107151
#   pangu: area weighted rmse: 113.69345747853957
#   neuralgcm: area weighted rmse: 105.87051707287343
#   ifshres: area weighted rmse: 123.16396620305031
# Fold 50:
#   mse: 24960.833984375
#   PiggyCast: area weighted rmse: 120.31688678838822
#   graphcast: area weighted rmse: 110.04188352550861
#   pangu: area weighted rmse: 124.064075303965
#   neuralgcm: area weighted rmse: 102.65566081187599
#   ifshres: area weighted rmse: 121.446912317287
# Fold 51:
#   mse: 21670.556640625
#   PiggyCast: area weighted rmse: 112.22689864117613
#   graphcast: area weighted rmse: 124.88490381223313
#   pangu: area weighted rmse: 127.45444650144685
#   neuralgcm: area weighted rmse: 107.45233256365583
#   ifshres: area weighted rmse: 128.18939814566042
# Fold 52:
#   mse: 20388.087890625
#   PiggyCast: area weighted rmse: 109.2516989516055
#   graphcast: area weighted rmse: 123.03207048471137
#   pangu: area weighted rmse: 129.13054848356697
#   neuralgcm: area weighted rmse: 107.1689223395687
#   ifshres: area weighted rmse: 131.38246878176136
# Fold 53:
#   mse: 20421.330078125
#   PiggyCast: area weighted rmse: 108.18923413895213
#   graphcast: area weighted rmse: 111.56581598531896
#   pangu: area weighted rmse: 130.58050122108244
#   neuralgcm: area weighted rmse: 95.71118700818221
#   ifshres: area weighted rmse: 131.23550223899443
# Fold 54:
#   mse: 16920.173828125
#   PiggyCast: area weighted rmse: 102.7981446026976
#   graphcast: area weighted rmse: 110.46257932797532
#   pangu: area weighted rmse: 127.87743528392494
#   neuralgcm: area weighted rmse: 99.50362589621304
#   ifshres: area weighted rmse: 124.83639581706983
# Fold 55:
#   mse: 29834.2109375
#   PiggyCast: area weighted rmse: 123.61365813041414
#   graphcast: area weighted rmse: 117.58346247614857
#   pangu: area weighted rmse: 129.40272096177688
#   neuralgcm: area weighted rmse: 101.58187971735937
#   ifshres: area weighted rmse: 119.95171625383713
# Fold 56:
#   mse: 45143.00390625
#   PiggyCast: area weighted rmse: 145.6529626457559
#   graphcast: area weighted rmse: 118.36015785653429
#   pangu: area weighted rmse: 121.11884196406606
#   neuralgcm: area weighted rmse: 102.16729882266665
#   ifshres: area weighted rmse: 120.74181976514107
# Fold 57:
#   mse: 21179.548828125
#   PiggyCast: area weighted rmse: 101.66783321809075
#   graphcast: area weighted rmse: 105.31873260237055
#   pangu: area weighted rmse: 120.99938214926127
#   neuralgcm: area weighted rmse: 94.19321893202232
#   ifshres: area weighted rmse: 118.4470948362669
# Fold 58:
#   mse: 22810.572265625
#   PiggyCast: area weighted rmse: 110.46696041702309
#   graphcast: area weighted rmse: 117.322327028847
#   pangu: area weighted rmse: 135.5982505251233
#   neuralgcm: area weighted rmse: 106.39068151426784
#   ifshres: area weighted rmse: 128.54345825040082
# Fold 59:
#   mse: 28783.3515625
#   PiggyCast: area weighted rmse: 130.97204340299328
#   graphcast: area weighted rmse: 132.51303561640282
#   pangu: area weighted rmse: 164.01762339710854
#   neuralgcm: area weighted rmse: 121.42611870071276
#   ifshres: area weighted rmse: 151.55514256074463
# Fold 60:
#   mse: 17802.150390625
#   PiggyCast: area weighted rmse: 103.9398821240567
#   graphcast: area weighted rmse: 110.85956748257367
#   pangu: area weighted rmse: 128.9961701360118
#   neuralgcm: area weighted rmse: 103.01952121253058
#   ifshres: area weighted rmse: 117.70468257941017
# Fold 61:
#   mse: 20710.423828125
#   PiggyCast: area weighted rmse: 105.75011485867464
#   graphcast: area weighted rmse: 114.46132808063565
#   pangu: area weighted rmse: 120.88480795038971
#   neuralgcm: area weighted rmse: 99.89166304266439
#   ifshres: area weighted rmse: 126.99200429078417
# Fold 62:
#   mse: 23287.025390625
#   PiggyCast: area weighted rmse: 109.8911940473955
#   graphcast: area weighted rmse: 113.48095122389505
#   pangu: area weighted rmse: 120.80424588846236
#   neuralgcm: area weighted rmse: 102.53563540230596
#   ifshres: area weighted rmse: 124.7984964612553
# Fold 63:
#   mse: 15990.140625
#   PiggyCast: area weighted rmse: 94.34854359712362
#   graphcast: area weighted rmse: 101.10076180947632
#   pangu: area weighted rmse: 110.06726211107602
#   neuralgcm: area weighted rmse: 91.17785421192747
#   ifshres: area weighted rmse: 112.81431577827144
# Fold 64:
#   mse: 18240.35546875
#   PiggyCast: area weighted rmse: 108.57181826840835
#   graphcast: area weighted rmse: 119.93206270598249
#   pangu: area weighted rmse: 118.9886516800004
#   neuralgcm: area weighted rmse: 105.36939494790046
#   ifshres: area weighted rmse: 130.87874945795608
# Fold 65:
#   mse: 19686.841796875
#   PiggyCast: area weighted rmse: 104.87681784375214
#   graphcast: area weighted rmse: 124.3633854407853
#   pangu: area weighted rmse: 127.11460623524819
#   neuralgcm: area weighted rmse: 102.91212180271219
#   ifshres: area weighted rmse: 139.113148645475
# Fold 66:
#   mse: 19686.162109375
#   PiggyCast: area weighted rmse: 106.09614495664759
#   graphcast: area weighted rmse: 110.3165795622655
#   pangu: area weighted rmse: 118.88015564294496
#   neuralgcm: area weighted rmse: 103.68115208902036
#   ifshres: area weighted rmse: 115.01311825068593
# Fold 67:
#   mse: 15224.2373046875
#   PiggyCast: area weighted rmse: 98.54749039193209
#   graphcast: area weighted rmse: 111.93117835330584
#   pangu: area weighted rmse: 112.0796951080038
#   neuralgcm: area weighted rmse: 95.78846140677628
#   ifshres: area weighted rmse: 124.48504527643537
# Fold 68:
#   mse: 16202.734375
#   PiggyCast: area weighted rmse: 95.40151694849983
#   graphcast: area weighted rmse: 114.81518240323636
#   pangu: area weighted rmse: 118.07761823785637
#   neuralgcm: area weighted rmse: 90.96051711585503
#   ifshres: area weighted rmse: 112.81748714398287
# Fold 69:
#   mse: 20712.458984375
#   PiggyCast: area weighted rmse: 112.66084009015236
#   graphcast: area weighted rmse: 126.26933100573146
#   pangu: area weighted rmse: 134.53361014247037
#   neuralgcm: area weighted rmse: 117.93031252732723
#   ifshres: area weighted rmse: 142.2817222919639
# Fold 70:
#   mse: 18398.8671875
#   PiggyCast: area weighted rmse: 110.21797694076405
#   graphcast: area weighted rmse: 126.1626289928322
#   pangu: area weighted rmse: 129.6646858994454
#   neuralgcm: area weighted rmse: 101.29949642849816
#   ifshres: area weighted rmse: 143.30504029664937
# Fold 71:
#   mse: 19845.814453125
#   PiggyCast: area weighted rmse: 111.57199590210904
#   graphcast: area weighted rmse: 113.61276280802603
#   pangu: area weighted rmse: 121.24210560254194
#   neuralgcm: area weighted rmse: 113.89905517315385
#   ifshres: area weighted rmse: 128.7423274490626
# Fold 72:
#   mse: 18373.291015625
#   PiggyCast: area weighted rmse: 105.28171887636061
#   graphcast: area weighted rmse: 106.06341977168869
#   pangu: area weighted rmse: 113.78329773264785
#   neuralgcm: area weighted rmse: 95.41346321365543
#   ifshres: area weighted rmse: 115.96734102655057
# Fold 73:
#   mse: 17295.275390625
#   PiggyCast: area weighted rmse: 102.49503540318555
#   graphcast: area weighted rmse: 112.61018487523698
#   pangu: area weighted rmse: 117.94228549533202
#   neuralgcm: area weighted rmse: 96.44331453402022
#   ifshres: area weighted rmse: 116.05243518961731
# Fold 74:
#   mse: 20616.166015625
#   PiggyCast: area weighted rmse: 114.41727475653754
#   graphcast: area weighted rmse: 123.585965807399
#   pangu: area weighted rmse: 129.47858307627436
#   neuralgcm: area weighted rmse: 121.41631534207592
#   ifshres: area weighted rmse: 125.8805549335796
# Fold 75:
#   mse: 16983.6796875
#   PiggyCast: area weighted rmse: 100.5508670910791
#   graphcast: area weighted rmse: 111.33617049376981
#   pangu: area weighted rmse: 117.5055526892607
#   neuralgcm: area weighted rmse: 95.48235514783633
#   ifshres: area weighted rmse: 117.40793227976815
# Fold 76:
#   mse: 17900.314453125
#   PiggyCast: area weighted rmse: 104.50330658745403
#   graphcast: area weighted rmse: 105.9024487345256
#   pangu: area weighted rmse: 113.2806807029172
#   neuralgcm: area weighted rmse: 95.37447806212604
#   ifshres: area weighted rmse: 115.12188338433229
# Fold 77:
#   mse: 14242.1533203125
#   PiggyCast: area weighted rmse: 98.58250091849303
#   graphcast: area weighted rmse: 114.50751270658591
#   pangu: area weighted rmse: 117.0723341747755
#   neuralgcm: area weighted rmse: 101.50678602132336
#   ifshres: area weighted rmse: 115.79427037590916
# Fold 78:
#   mse: 15199.0537109375
#   PiggyCast: area weighted rmse: 102.93823614125411
#   graphcast: area weighted rmse: 113.81317056940799
#   pangu: area weighted rmse: 120.07035683277645
#   neuralgcm: area weighted rmse: 108.27041473862758
#   ifshres: area weighted rmse: 133.49064405263033
# Fold 79:
#   mse: 14125.3359375
#   PiggyCast: area weighted rmse: 101.27155282788164
#   graphcast: area weighted rmse: 112.88921035021764
#   pangu: area weighted rmse: 127.88655137924984
#   neuralgcm: area weighted rmse: 103.91684644659307
#   ifshres: area weighted rmse: 124.1655837306347
# Fold 80:
#   mse: 18897.435546875
#   PiggyCast: area weighted rmse: 102.90666986337699
#   graphcast: area weighted rmse: 107.82930579973818
#   pangu: area weighted rmse: 118.92941350807781
#   neuralgcm: area weighted rmse: 102.27779854690256
#   ifshres: area weighted rmse: 118.38132821245209
# Fold 81:
#   mse: 14182.54296875
#   PiggyCast: area weighted rmse: 95.25304455400014
#   graphcast: area weighted rmse: 107.3902084725396
#   pangu: area weighted rmse: 113.88305656494089
#   neuralgcm: area weighted rmse: 93.91025597830159
#   ifshres: area weighted rmse: 117.91716350328524
# Fold 82:
#   mse: 13620.4375
#   PiggyCast: area weighted rmse: 92.0788233211557
#   graphcast: area weighted rmse: 107.61023372978924
#   pangu: area weighted rmse: 107.58834040007812
#   neuralgcm: area weighted rmse: 100.0699509293601
#   ifshres: area weighted rmse: 100.07982835659848
# Fold 83:
#   mse: 17754.634765625
#   PiggyCast: area weighted rmse: 106.32822297063645
#   graphcast: area weighted rmse: 118.57442194907662
#   pangu: area weighted rmse: 127.92335605344125
#   neuralgcm: area weighted rmse: 109.72564036345864
#   ifshres: area weighted rmse: 131.8239584239481
# Fold 84:
#   mse: 15462.0869140625
#   PiggyCast: area weighted rmse: 99.72351790022753
#   graphcast: area weighted rmse: 119.0635774942509
#   pangu: area weighted rmse: 125.48929068520647
#   neuralgcm: area weighted rmse: 102.34483925235944
#   ifshres: area weighted rmse: 130.47663886054843
# Fold 85:
#   mse: 13165.9189453125
#   PiggyCast: area weighted rmse: 92.30224365666581
#   graphcast: area weighted rmse: 102.82590566089321
#   pangu: area weighted rmse: 124.34095820957239
#   neuralgcm: area weighted rmse: 96.65514935836981
#   ifshres: area weighted rmse: 113.13322594198536
# Fold 86:
#   mse: 15001.2939453125
#   PiggyCast: area weighted rmse: 101.48719330848088
#   graphcast: area weighted rmse: 113.4039789243124
#   pangu: area weighted rmse: 122.93913779485366
#   neuralgcm: area weighted rmse: 102.51958266385572
#   ifshres: area weighted rmse: 116.97727830543272
# Fold 87:
#   mse: 12307.5654296875
#   PiggyCast: area weighted rmse: 93.76221455103443
#   graphcast: area weighted rmse: 105.91701376454503
#   pangu: area weighted rmse: 113.16518453139592
#   neuralgcm: area weighted rmse: 96.35286783288436
#   ifshres: area weighted rmse: 112.46542978912656
# Fold 88:
#   mse: 14600.77734375
#   PiggyCast: area weighted rmse: 100.3891702443298
#   graphcast: area weighted rmse: 106.58899510614832
#   pangu: area weighted rmse: 119.35774261688384
#   neuralgcm: area weighted rmse: 103.89973266411546
#   ifshres: area weighted rmse: 127.22268505186211
# Fold 89:
#   mse: 13060.33203125
#   PiggyCast: area weighted rmse: 95.53744403015112
#   graphcast: area weighted rmse: 106.47546687030018
#   pangu: area weighted rmse: 113.9573555930361
#   neuralgcm: area weighted rmse: 101.16329494071422
#   ifshres: area weighted rmse: 119.03004491361592
# Fold 90:
#   mse: 13632.9443359375
#   PiggyCast: area weighted rmse: 96.74205365838061
#   graphcast: area weighted rmse: 109.2832588234318
#   pangu: area weighted rmse: 118.30805981721309
#   neuralgcm: area weighted rmse: 102.69824576947742
#   ifshres: area weighted rmse: 132.56768225155741
# Fold 91:
#   mse: 15776.734375
#   PiggyCast: area weighted rmse: 103.27067674815613
#   graphcast: area weighted rmse: 116.6527709563778
#   pangu: area weighted rmse: 136.77820476035774
#   neuralgcm: area weighted rmse: 107.60899578893493
#   ifshres: area weighted rmse: 127.33146708474564
# Fold 92:
#   mse: 12576.3017578125
#   PiggyCast: area weighted rmse: 96.13657800349397
#   graphcast: area weighted rmse: 105.82645717130248
#   pangu: area weighted rmse: 117.94009487351325
#   neuralgcm: area weighted rmse: 99.0595782331719
#   ifshres: area weighted rmse: 121.4470498176089
# Fold 93:
#   mse: 14021.7080078125
#   PiggyCast: area weighted rmse: 102.72187866232024
#   graphcast: area weighted rmse: 111.22943513690986
#   pangu: area weighted rmse: 118.66425523338951
#   neuralgcm: area weighted rmse: 101.44312613206628
#   ifshres: area weighted rmse: 118.2070008208559
# Fold 94:
#   mse: 12132.3828125
#   PiggyCast: area weighted rmse: 95.60075482381889
#   graphcast: area weighted rmse: 108.38762573014876
#   pangu: area weighted rmse: 109.76629464657016
#   neuralgcm: area weighted rmse: 99.63994681664775
#   ifshres: area weighted rmse: 114.52304648589876
# Fold 95:
#   mse: 10693.388671875
#   PiggyCast: area weighted rmse: 88.12679408740588
#   graphcast: area weighted rmse: 103.7146613631233
#   pangu: area weighted rmse: 105.51069061727159
#   neuralgcm: area weighted rmse: 92.70091071500265
#   ifshres: area weighted rmse: 106.30357197968767
# Fold 96:
#   mse: 11512.3046875
#   PiggyCast: area weighted rmse: 87.38612520331955
#   graphcast: area weighted rmse: 98.77020183678921
#   pangu: area weighted rmse: 103.15201353778042
#   neuralgcm: area weighted rmse: 89.1382478306395
#   ifshres: area weighted rmse: 102.65227180026085
# Fold 97:
#   mse: 10797.34765625
#   PiggyCast: area weighted rmse: 89.42517721253542
#   graphcast: area weighted rmse: 103.51684751205913
#   pangu: area weighted rmse: 107.80850234570647
#   neuralgcm: area weighted rmse: 83.89264006954393
#   ifshres: area weighted rmse: 115.13271212576647
# Fold 98:
#   mse: 12009.6640625
#   PiggyCast: area weighted rmse: 92.71143243122079
#   graphcast: area weighted rmse: 125.40530533877691
#   pangu: area weighted rmse: 130.62666030733928
#   neuralgcm: area weighted rmse: 97.34868024061205
#   ifshres: area weighted rmse: 116.28929371302458
# Fold 99:
#   mse: 13105.9658203125
#   PiggyCast: area weighted rmse: 91.05926544035329
#   graphcast: area weighted rmse: 113.20806800070652
#   pangu: area weighted rmse: 119.26361168690549
#   neuralgcm: area weighted rmse: 90.34379037819585
#   ifshres: area weighted rmse: 117.38983211229531
# Fold 100:
#   mse: 14527.1923828125
#   PiggyCast: area weighted rmse: 97.51151192496016
#   graphcast: area weighted rmse: 110.35486100897894
#   pangu: area weighted rmse: 122.5482010493479
#   neuralgcm: area weighted rmse: 99.29198021572408
#   ifshres: area weighted rmse: 119.58689060830463
# {48: {'PiggyCast': 65.98529662326521,
#       'graphcast': 69.5591285985073,
#       'ifshres': 74.10824446618233,
#       'neuralgcm': 60.71513398370254,
#       'pangu': 75.6399261334173},
#  72: {'PiggyCast': 107.21741652664775,
#       'graphcast': 115.28758890059464,
#       'ifshres': 124.74234192251387,
#       'neuralgcm': 104.86569368856097,
#       'pangu': 125.55108112413224}}

# %%
# @title Training and Evaluation Loop- Shorter Time series split : 2 Days Training, 1 Day Gap and 1 Day Testing

# Initialize xgb regressor
xgb = xgboost.XGBRegressor(random_state=42, device="cuda")

# Calculate Cross-Validation using 10 folds
cv_timeseries = TimeSeriesSplit(n_splits=100, max_train_size=32 * 64 * 2 * 2,
                                test_size= 32 * 64 * 2 * 1, gap=32 * 64 * 2 * 1)

# Lead Times
lead_times=[48, 72]

nested_scores = {} # Nested scores for each lead time
rmse_results = {} # rmse results for each lead time, models

for lead_time in lead_times:
  print(f"======Lead time: {lead_time}========")

  df_filtered = data_per_lead_time(full_df,lead_time)

  X = df_filtered[[f"graphcast_lt{lead_time}", f"pangu_lt{lead_time}",
                   f"neuralgcm_lt{lead_time}",
                  #  f"keisler_lt{lead_time}",
                   f"ifshres_lt{lead_time}", "longitude", "latitude"]]
  y = df_filtered["era5"]
  area_weight = df_filtered["area_weight"]

  print(f"Shape of x :{X.shape}")
  print(f"Shape of y : {y.shape}")

  # Nested Scores
  nested_score = cross_validate(xgb, X=X, y=y, cv=cv_timeseries,
                              scoring=('neg_mean_squared_error', 'r2'),
                              params={'sample_weight': area_weight}
                              )
  nested_scores[lead_time] = nested_score

  # Cross validation plot
  cross_validation_plot(df_filtered, cv_timeseries, lead_time)

  # RMSE
  rmse_result = train_and_evaluate(xgb, cv_timeseries,X,y, area_weight, lead_time)
  rmse_results[lead_time] = rmse_result

  # RMSE plots per model
  rmse_per_fold_plot(rmse_result, lead_time)

  # print nicely average RMSE per Leadtime
  average_scores = rmse_mean_per_lead_time_and_model(rmse_results)
  pprint(average_scores)
# Out:
# ======Lead time: 48========
# Shape of x :(1497088, 6)
# Shape of y : (1497088,)
# Train times Min Date: 2020-09-22 00:00:00 Train times Max Date:2020-09-23 12:00:00
# Test times Min Date: 2020-09-25 00:00:00 Test times Max Date:2020-09-25 12:00:00
# Train times Min Date: 2020-09-23 00:00:00 Train times Max Date:2020-09-24 12:00:00
# Test times Min Date: 2020-09-26 00:00:00 Test times Max Date:2020-09-26 12:00:00
# Train times Min Date: 2020-09-24 00:00:00 Train times Max Date:2020-09-25 12:00:00
# Test times Min Date: 2020-09-27 00:00:00 Test times Max Date:2020-09-27 12:00:00
# Train times Min Date: 2020-09-25 00:00:00 Train times Max Date:2020-09-26 12:00:00
# Test times Min Date: 2020-09-28 00:00:00 Test times Max Date:2020-09-28 12:00:00
# Train times Min Date: 2020-09-26 00:00:00 Train times Max Date:2020-09-27 12:00:00
# Test times Min Date: 2020-09-29 00:00:00 Test times Max Date:2020-09-29 12:00:00
# Train times Min Date: 2020-09-27 00:00:00 Train times Max Date:2020-09-28 12:00:00
# Test times Min Date: 2020-09-30 00:00:00 Test times Max Date:2020-09-30 12:00:00
# Train times Min Date: 2020-09-28 00:00:00 Train times Max Date:2020-09-29 12:00:00
# Test times Min Date: 2020-10-01 00:00:00 Test times Max Date:2020-10-01 12:00:00
# Train times Min Date: 2020-09-29 00:00:00 Train times Max Date:2020-09-30 12:00:00
# Test times Min Date: 2020-10-02 00:00:00 Test times Max Date:2020-10-02 12:00:00
# Train times Min Date: 2020-09-30 00:00:00 Train times Max Date:2020-10-01 12:00:00
# Test times Min Date: 2020-10-03 00:00:00 Test times Max Date:2020-10-03 12:00:00
# Train times Min Date: 2020-10-01 00:00:00 Train times Max Date:2020-10-02 12:00:00
# Test times Min Date: 2020-10-04 00:00:00 Test times Max Date:2020-10-04 12:00:00
# Fold 1:
#   mse: 6579.8681640625
#   PiggyCast: area weighted rmse: 64.27715679022232
#   graphcast: area weighted rmse: 64.7010507857331
#   pangu: area weighted rmse: 71.67007657862156
#   neuralgcm: area weighted rmse: 54.47844189779927
#   ifshres: area weighted rmse: 67.13785716861318
# Fold 2:
#   mse: 6050.3388671875
#   PiggyCast: area weighted rmse: 61.815750069569944
#   graphcast: area weighted rmse: 65.17185658519556
#   pangu: area weighted rmse: 69.3021205102403
#   neuralgcm: area weighted rmse: 55.61175656862767
#   ifshres: area weighted rmse: 66.92234443677067
# Fold 3:
#   mse: 6642.29345703125
#   PiggyCast: area weighted rmse: 63.148121163809755
#   graphcast: area weighted rmse: 73.20989381522514
#   pangu: area weighted rmse: 72.29347322768889
#   neuralgcm: area weighted rmse: 57.49600666149801
#   ifshres: area weighted rmse: 67.07044365455289
# Fold 4:
#   mse: 5614.4189453125
#   PiggyCast: area weighted rmse: 56.68667754955649
#   graphcast: area weighted rmse: 66.15612655157008
#   pangu: area weighted rmse: 72.29848937636233
#   neuralgcm: area weighted rmse: 52.590994813678485
#   ifshres: area weighted rmse: 68.30798618187744
# Fold 5:
#   mse: 8527.087890625
#   PiggyCast: area weighted rmse: 68.19012737835098
#   graphcast: area weighted rmse: 70.19700213196087
#   pangu: area weighted rmse: 75.64603760156777
#   neuralgcm: area weighted rmse: 58.31622380832294
#   ifshres: area weighted rmse: 74.03396079355791
# Fold 6:
#   mse: 5781.23779296875
#   PiggyCast: area weighted rmse: 64.76702409124485
#   graphcast: area weighted rmse: 70.63720521999922
#   pangu: area weighted rmse: 77.14612293724218
#   neuralgcm: area weighted rmse: 65.12838195414145
#   ifshres: area weighted rmse: 78.95648877699786
# Fold 7:
#   mse: 6890.81103515625
#   PiggyCast: area weighted rmse: 68.33567781699523
#   graphcast: area weighted rmse: 79.06878964369356
#   pangu: area weighted rmse: 81.4975925861171
#   neuralgcm: area weighted rmse: 63.17851589412534
#   ifshres: area weighted rmse: 77.91942694754071
# Fold 8:
#   mse: 8059.880859375
#   PiggyCast: area weighted rmse: 74.141413671061
#   graphcast: area weighted rmse: 84.5684150153887
#   pangu: area weighted rmse: 82.87916660452464
#   neuralgcm: area weighted rmse: 64.99144157102174
#   ifshres: area weighted rmse: 82.03967725367697
# Fold 9:
#   mse: 9420.875
#   PiggyCast: area weighted rmse: 76.95869607563853
#   graphcast: area weighted rmse: 73.03749159776189
#   pangu: area weighted rmse: 75.94189784887736
#   neuralgcm: area weighted rmse: 57.77708005198805
#   ifshres: area weighted rmse: 84.43829542504423
# Fold 10:
#   mse: 6629.2802734375
#   PiggyCast: area weighted rmse: 66.7441474508306
#   graphcast: area weighted rmse: 81.9268799876668
#   pangu: area weighted rmse: 74.69048184069291
#   neuralgcm: area weighted rmse: 56.06827502602886
#   ifshres: area weighted rmse: 80.4094792707292
# Fold 11:
#   mse: 7488.4990234375
#   PiggyCast: area weighted rmse: 70.68772441591675
#   graphcast: area weighted rmse: 80.35712122289523
#   pangu: area weighted rmse: 78.93905280077519
#   neuralgcm: area weighted rmse: 66.23584861865285
#   ifshres: area weighted rmse: 80.59610570216459
# Fold 12:
#   mse: 9256.0400390625
#   PiggyCast: area weighted rmse: 80.15959929889914
#   graphcast: area weighted rmse: 68.20008951058036
#   pangu: area weighted rmse: 73.94219579338638
#   neuralgcm: area weighted rmse: 67.5160486221709
#   ifshres: area weighted rmse: 74.20463865199594
# Fold 13:
#   mse: 7667.10205078125
#   PiggyCast: area weighted rmse: 71.95373601922365
#   graphcast: area weighted rmse: 65.33969611318169
#   pangu: area weighted rmse: 71.49294490179666
#   neuralgcm: area weighted rmse: 58.88198789316042
#   ifshres: area weighted rmse: 70.2823843965696
# Fold 14:
#   mse: 8226.544921875
#   PiggyCast: area weighted rmse: 72.61743286180811
#   graphcast: area weighted rmse: 67.82955501940108
#   pangu: area weighted rmse: 71.72630761511391
#   neuralgcm: area weighted rmse: 58.5887734517916
#   ifshres: area weighted rmse: 68.25004376171472
# Fold 15:
#   mse: 12776.0712890625
#   PiggyCast: area weighted rmse: 87.9877336685069
#   graphcast: area weighted rmse: 68.11476359793409
#   pangu: area weighted rmse: 70.93469660945787
#   neuralgcm: area weighted rmse: 59.80330238892172
#   ifshres: area weighted rmse: 67.09353917753124
# Fold 16:
#   mse: 6821.3779296875
#   PiggyCast: area weighted rmse: 67.18046547091991
#   graphcast: area weighted rmse: 64.77650297215426
#   pangu: area weighted rmse: 64.61423976897302
#   neuralgcm: area weighted rmse: 54.45727562218435
#   ifshres: area weighted rmse: 65.4748502142102
# Fold 17:
#   mse: 6490.88232421875
#   PiggyCast: area weighted rmse: 63.57410956149513
#   graphcast: area weighted rmse: 68.28503828172938
#   pangu: area weighted rmse: 66.94570087397682
#   neuralgcm: area weighted rmse: 58.0000377558942
#   ifshres: area weighted rmse: 70.74004144944786
# Fold 18:
#   mse: 5476.96484375
#   PiggyCast: area weighted rmse: 59.24828460364338
#   graphcast: area weighted rmse: 62.483145364664374
#   pangu: area weighted rmse: 64.99620334898387
#   neuralgcm: area weighted rmse: 55.790548454866446
#   ifshres: area weighted rmse: 67.67852592903324
# Fold 19:
#   mse: 5754.9384765625
#   PiggyCast: area weighted rmse: 60.84958044100002
#   graphcast: area weighted rmse: 64.09283985016948
#   pangu: area weighted rmse: 69.20325838570923
#   neuralgcm: area weighted rmse: 57.71273656572386
#   ifshres: area weighted rmse: 67.31385758524839
# Fold 20:
#   mse: 7759.646484375
#   PiggyCast: area weighted rmse: 69.5606304047728
#   graphcast: area weighted rmse: 65.34450995414228
#   pangu: area weighted rmse: 77.06438794443235
#   neuralgcm: area weighted rmse: 67.85121237465835
#   ifshres: area weighted rmse: 73.50746477215733
# Fold 21:
#   mse: 6917.3076171875
#   PiggyCast: area weighted rmse: 64.70748389017666
#   graphcast: area weighted rmse: 66.32618688992548
#   pangu: area weighted rmse: 73.71274248142817
#   neuralgcm: area weighted rmse: 62.77233857365828
#   ifshres: area weighted rmse: 74.3149627051852
# Fold 22:
#   mse: 9619.712890625
#   PiggyCast: area weighted rmse: 70.4280728120276
#   graphcast: area weighted rmse: 69.91952249454151
#   pangu: area weighted rmse: 78.71641810772037
#   neuralgcm: area weighted rmse: 60.80991562097366
#   ifshres: area weighted rmse: 72.25627233333198
# Fold 23:
#   mse: 11195.8359375
#   PiggyCast: area weighted rmse: 76.9280084000404
#   graphcast: area weighted rmse: 71.34075324235468
#   pangu: area weighted rmse: 77.79282154830675
#   neuralgcm: area weighted rmse: 63.92818640140027
#   ifshres: area weighted rmse: 79.74647606963936
# Fold 24:
#   mse: 9693.259765625
#   PiggyCast: area weighted rmse: 67.97644648012393
#   graphcast: area weighted rmse: 68.37855131053466
#   pangu: area weighted rmse: 68.5641737628187
#   neuralgcm: area weighted rmse: 51.90766842741797
#   ifshres: area weighted rmse: 74.00516052205899
# Fold 25:
#   mse: 6302.73828125
#   PiggyCast: area weighted rmse: 59.70389119009662
#   graphcast: area weighted rmse: 67.34587294348441
#   pangu: area weighted rmse: 65.57638383834214
#   neuralgcm: area weighted rmse: 51.60320867562197
#   ifshres: area weighted rmse: 61.00676323809807
# Fold 26:
#   mse: 5989.95458984375
#   PiggyCast: area weighted rmse: 63.16479180590332
#   graphcast: area weighted rmse: 70.84867463926675
#   pangu: area weighted rmse: 66.39756836656092
#   neuralgcm: area weighted rmse: 58.78977913807128
#   ifshres: area weighted rmse: 66.13516315354266
# Fold 27:
#   mse: 6200.3134765625
#   PiggyCast: area weighted rmse: 62.61440623830468
#   graphcast: area weighted rmse: 69.2122704151255
#   pangu: area weighted rmse: 71.08868363120631
#   neuralgcm: area weighted rmse: 58.82639402107828
#   ifshres: area weighted rmse: 66.19377947968152
# Fold 28:
#   mse: 13995.232421875
#   PiggyCast: area weighted rmse: 80.60307789268711
#   graphcast: area weighted rmse: 67.73546297557176
#   pangu: area weighted rmse: 67.44113328480682
#   neuralgcm: area weighted rmse: 56.92843772062286
#   ifshres: area weighted rmse: 70.03776043069088
# Fold 29:
#   mse: 5286.3486328125
#   PiggyCast: area weighted rmse: 59.57075845363431
#   graphcast: area weighted rmse: 68.69581860311354
#   pangu: area weighted rmse: 68.24749514151505
#   neuralgcm: area weighted rmse: 53.42630186954705
#   ifshres: area weighted rmse: 73.33745603085343
# Fold 30:
#   mse: 5212.4677734375
#   PiggyCast: area weighted rmse: 58.250009841768005
#   graphcast: area weighted rmse: 68.49310189914816
#   pangu: area weighted rmse: 66.5271650089587
#   neuralgcm: area weighted rmse: 55.185248348330774
#   ifshres: area weighted rmse: 66.47644008537864
# Fold 31:
#   mse: 6746.6826171875
#   PiggyCast: area weighted rmse: 65.3789474170175
#   graphcast: area weighted rmse: 75.0446258757265
#   pangu: area weighted rmse: 71.94186120302432
#   neuralgcm: area weighted rmse: 65.10699108722801
#   ifshres: area weighted rmse: 66.73801317605746
# Fold 32:
#   mse: 7119.828125
#   PiggyCast: area weighted rmse: 68.98097904690694
#   graphcast: area weighted rmse: 72.42742678302204
#   pangu: area weighted rmse: 80.43305365096555
#   neuralgcm: area weighted rmse: 63.69316877447582
#   ifshres: area weighted rmse: 76.12203232657006
# Fold 33:
#   mse: 7767.85693359375
#   PiggyCast: area weighted rmse: 72.64899151262607
#   graphcast: area weighted rmse: 72.99797527813615
#   pangu: area weighted rmse: 74.67141354087377
#   neuralgcm: area weighted rmse: 65.00038798954377
#   ifshres: area weighted rmse: 75.97804335606165
# Fold 34:
#   mse: 6694.265625
#   PiggyCast: area weighted rmse: 68.95761378924257
#   graphcast: area weighted rmse: 68.450531045711
#   pangu: area weighted rmse: 73.76566626255591
#   neuralgcm: area weighted rmse: 62.074436755007206
#   ifshres: area weighted rmse: 75.87081799056475
# Fold 35:
#   mse: 6063.84765625
#   PiggyCast: area weighted rmse: 62.89601757006075
#   graphcast: area weighted rmse: 67.35233115629069
#   pangu: area weighted rmse: 72.88467971399774
#   neuralgcm: area weighted rmse: 58.004175800734075
#   ifshres: area weighted rmse: 75.56575350241089
# Fold 36:
#   mse: 6987.3349609375
#   PiggyCast: area weighted rmse: 66.78114113029662
#   graphcast: area weighted rmse: 72.75339437623768
#   pangu: area weighted rmse: 75.03560505331859
#   neuralgcm: area weighted rmse: 58.958842967276574
#   ifshres: area weighted rmse: 73.72066793656823
# Fold 37:
#   mse: 7098.748046875
#   PiggyCast: area weighted rmse: 66.57069244130864
#   graphcast: area weighted rmse: 68.25902421478979
#   pangu: area weighted rmse: 71.87588325221849
#   neuralgcm: area weighted rmse: 60.84515670571431
#   ifshres: area weighted rmse: 71.9825455184055
# Fold 38:
#   mse: 6734.5498046875
#   PiggyCast: area weighted rmse: 67.12589013648598
#   graphcast: area weighted rmse: 66.01790144533861
#   pangu: area weighted rmse: 70.38336103877147
#   neuralgcm: area weighted rmse: 62.29229603041227
#   ifshres: area weighted rmse: 71.86858330511464
# Fold 39:
#   mse: 7572.865234375
#   PiggyCast: area weighted rmse: 67.50356834864161
#   graphcast: area weighted rmse: 70.0118438889954
#   pangu: area weighted rmse: 73.60968758366734
#   neuralgcm: area weighted rmse: 60.509150509196104
#   ifshres: area weighted rmse: 76.44146315175553
# Fold 40:
#   mse: 25241.427734375
#   PiggyCast: area weighted rmse: 92.54770310402571
#   graphcast: area weighted rmse: 67.79797591967782
#   pangu: area weighted rmse: 77.37217356291946
#   neuralgcm: area weighted rmse: 58.95841941526932
#   ifshres: area weighted rmse: 71.93492256860608
# Fold 41:
#   mse: 21298.98046875
#   PiggyCast: area weighted rmse: 94.2803874473113
#   graphcast: area weighted rmse: 68.54482357571574
#   pangu: area weighted rmse: 76.61731492458908
#   neuralgcm: area weighted rmse: 57.78705166460871
#   ifshres: area weighted rmse: 74.1915770082853
# Fold 42:
#   mse: 8733.06640625
#   PiggyCast: area weighted rmse: 71.11692420340135
#   graphcast: area weighted rmse: 71.75389196627451
#   pangu: area weighted rmse: 74.56784099941046
#   neuralgcm: area weighted rmse: 59.1754259375849
#   ifshres: area weighted rmse: 78.30196609983197
# Fold 43:
#   mse: 6300.9501953125
#   PiggyCast: area weighted rmse: 65.34455014545254
#   graphcast: area weighted rmse: 68.220365117628
#   pangu: area weighted rmse: 68.62588079735234
#   neuralgcm: area weighted rmse: 58.73474046778227
#   ifshres: area weighted rmse: 70.2073799198558
# Fold 44:
#   mse: 5455.53515625
#   PiggyCast: area weighted rmse: 60.35367877601998
#   graphcast: area weighted rmse: 71.87293485471577
#   pangu: area weighted rmse: 72.68879440412978
#   neuralgcm: area weighted rmse: 57.436487482566
#   ifshres: area weighted rmse: 66.81289273978247
# Fold 45:
#   mse: 6405.3876953125
#   PiggyCast: area weighted rmse: 62.904118065150584
#   graphcast: area weighted rmse: 67.34916661842357
#   pangu: area weighted rmse: 71.13124273270115
#   neuralgcm: area weighted rmse: 55.438456310926476
#   ifshres: area weighted rmse: 64.30284804733864
# Fold 46:
#   mse: 10652.130859375
#   PiggyCast: area weighted rmse: 72.79161217769551
#   graphcast: area weighted rmse: 68.78057893383375
#   pangu: area weighted rmse: 68.03196558545672
#   neuralgcm: area weighted rmse: 60.828978280479426
#   ifshres: area weighted rmse: 65.14599646135788
# Fold 47:
#   mse: 7200.88330078125
#   PiggyCast: area weighted rmse: 66.37063000185071
#   graphcast: area weighted rmse: 63.88084197618146
#   pangu: area weighted rmse: 69.15716681655856
#   neuralgcm: area weighted rmse: 66.30075695866186
#   ifshres: area weighted rmse: 69.1992239711219
# Fold 48:
#   mse: 6104.29248046875
#   PiggyCast: area weighted rmse: 66.18405932742183
#   graphcast: area weighted rmse: 65.69229037198458
#   pangu: area weighted rmse: 70.94430001973757
#   neuralgcm: area weighted rmse: 61.3624478267179
#   ifshres: area weighted rmse: 69.79764340925493
# Fold 49:
#   mse: 9206.212890625
#   PiggyCast: area weighted rmse: 75.98617886945453
#   graphcast: area weighted rmse: 77.58668559560644
#   pangu: area weighted rmse: 82.34716245713491
#   neuralgcm: area weighted rmse: 63.739533866520425
#   ifshres: area weighted rmse: 78.17390045844792
# Fold 50:
#   mse: 6351.4287109375
#   PiggyCast: area weighted rmse: 63.62976612570499
#   graphcast: area weighted rmse: 71.48235233310754
#   pangu: area weighted rmse: 75.91376108107208
#   neuralgcm: area weighted rmse: 55.967928448523345
#   ifshres: area weighted rmse: 75.91579438017307
# Fold 51:
#   mse: 6865.744140625
#   PiggyCast: area weighted rmse: 65.33162695373903
#   graphcast: area weighted rmse: 67.26584189280081
#   pangu: area weighted rmse: 79.14576529735893
#   neuralgcm: area weighted rmse: 60.28657172531705
#   ifshres: area weighted rmse: 74.44224470999734
# Fold 52:
#   mse: 6004.46923828125
#   PiggyCast: area weighted rmse: 64.7503820280535
#   graphcast: area weighted rmse: 72.38865764918006
#   pangu: area weighted rmse: 80.92375255983762
#   neuralgcm: area weighted rmse: 59.581779657256625
#   ifshres: area weighted rmse: 79.7550172093289
# Fold 53:
#   mse: 5646.615234375
#   PiggyCast: area weighted rmse: 61.619672653995615
#   graphcast: area weighted rmse: 68.19580830057947
#   pangu: area weighted rmse: 76.94252000249926
#   neuralgcm: area weighted rmse: 60.911534441497196
#   ifshres: area weighted rmse: 79.08546032051333
# Fold 54:
#   mse: 4946.7373046875
#   PiggyCast: area weighted rmse: 57.56558057181044
#   graphcast: area weighted rmse: 62.53395595099651
#   pangu: area weighted rmse: 66.3340801576231
#   neuralgcm: area weighted rmse: 56.2409456004878
#   ifshres: area weighted rmse: 70.62596769582896
# Fold 55:
#   mse: 6221.18505859375
#   PiggyCast: area weighted rmse: 62.881024419135585
#   graphcast: area weighted rmse: 64.19010297925611
#   pangu: area weighted rmse: 78.47084246182114
#   neuralgcm: area weighted rmse: 54.960207725418584
#   ifshres: area weighted rmse: 68.78146539823196
# Fold 56:
#   mse: 9422.361328125
#   PiggyCast: area weighted rmse: 75.33137660782575
#   graphcast: area weighted rmse: 66.07070047587021
#   pangu: area weighted rmse: 77.28869075314527
#   neuralgcm: area weighted rmse: 57.53403242621801
#   ifshres: area weighted rmse: 67.9395654294876
# Fold 57:
#   mse: 15319.5966796875
#   PiggyCast: area weighted rmse: 97.24660594927097
#   graphcast: area weighted rmse: 69.26758215040849
#   pangu: area weighted rmse: 70.06884090220724
#   neuralgcm: area weighted rmse: 59.2280069459056
#   ifshres: area weighted rmse: 75.12870650665054
# Fold 58:
#   mse: 6515.1640625
#   PiggyCast: area weighted rmse: 65.9151870785369
#   graphcast: area weighted rmse: 67.38047491335804
#   pangu: area weighted rmse: 77.75194250495622
#   neuralgcm: area weighted rmse: 60.49376550789836
#   ifshres: area weighted rmse: 74.40692586991908
# Fold 59:
#   mse: 5687.7392578125
#   PiggyCast: area weighted rmse: 62.067435807337894
#   graphcast: area weighted rmse: 65.2519219447887
#   pangu: area weighted rmse: 71.96728818789828
#   neuralgcm: area weighted rmse: 61.325070685219956
#   ifshres: area weighted rmse: 69.05436037414748
# Fold 60:
#   mse: 5425.01953125
#   PiggyCast: area weighted rmse: 62.94272161612136
#   graphcast: area weighted rmse: 70.81764806171869
#   pangu: area weighted rmse: 71.74852721096713
#   neuralgcm: area weighted rmse: 62.54230980192203
#   ifshres: area weighted rmse: 66.83198016820278
# Fold 61:
#   mse: 5312.89208984375
#   PiggyCast: area weighted rmse: 60.75716849091092
#   graphcast: area weighted rmse: 59.933278027014964
#   pangu: area weighted rmse: 67.44601959313619
#   neuralgcm: area weighted rmse: 56.22660301487149
#   ifshres: area weighted rmse: 68.3784959201829
# Fold 62:
#   mse: 6588.8818359375
#   PiggyCast: area weighted rmse: 65.21886465243965
#   graphcast: area weighted rmse: 64.89259679014344
#   pangu: area weighted rmse: 68.14302298202959
#   neuralgcm: area weighted rmse: 60.42533313103018
#   ifshres: area weighted rmse: 75.1636284217382
# Fold 63:
#   mse: 11715.921875
#   PiggyCast: area weighted rmse: 73.78989935098626
#   graphcast: area weighted rmse: 65.328452851907
#   pangu: area weighted rmse: 71.72144889980798
#   neuralgcm: area weighted rmse: 63.47103669289252
#   ifshres: area weighted rmse: 77.76896018980413
# Fold 64:
#   mse: 12688.40625
#   PiggyCast: area weighted rmse: 76.98722718500656
#   graphcast: area weighted rmse: 64.45592205974278
#   pangu: area weighted rmse: 76.78686712161165
#   neuralgcm: area weighted rmse: 60.51622667331678
#   ifshres: area weighted rmse: 76.42801795347528
# Fold 65:
#   mse: 6546.82275390625
#   PiggyCast: area weighted rmse: 63.141044498397996
#   graphcast: area weighted rmse: 61.599743970979
#   pangu: area weighted rmse: 72.03399736144858
#   neuralgcm: area weighted rmse: 56.39544298369116
#   ifshres: area weighted rmse: 72.65690643286824
# Fold 66:
#   mse: 4931.03857421875
#   PiggyCast: area weighted rmse: 58.55161777014041
#   graphcast: area weighted rmse: 60.55395181112729
#   pangu: area weighted rmse: 69.92163859833576
#   neuralgcm: area weighted rmse: 55.717369689019066
#   ifshres: area weighted rmse: 70.6202255693586
# Fold 67:
#   mse: 4517.6728515625
#   PiggyCast: area weighted rmse: 59.465964496274864
#   graphcast: area weighted rmse: 69.57895590223322
#   pangu: area weighted rmse: 70.5320261895935
#   neuralgcm: area weighted rmse: 57.53758026494272
#   ifshres: area weighted rmse: 69.57519338286794
# Fold 68:
#   mse: 5640.2421875
#   PiggyCast: area weighted rmse: 61.94700210045403
#   graphcast: area weighted rmse: 69.84757762147296
#   pangu: area weighted rmse: 75.00777599587124
#   neuralgcm: area weighted rmse: 56.61217514355405
#   ifshres: area weighted rmse: 79.47194442726041
# Fold 69:
#   mse: 4310.75390625
#   PiggyCast: area weighted rmse: 57.29105669926068
#   graphcast: area weighted rmse: 63.58564963511097
#   pangu: area weighted rmse: 62.79519623125233
#   neuralgcm: area weighted rmse: 56.684712583598916
#   ifshres: area weighted rmse: 75.51309758375393
# Fold 70:
#   mse: 4841.7646484375
#   PiggyCast: area weighted rmse: 59.19207543455484
#   graphcast: area weighted rmse: 63.645910732636345
#   pangu: area weighted rmse: 71.68260961424603
#   neuralgcm: area weighted rmse: 57.95627154342962
#   ifshres: area weighted rmse: 74.25557803143055
# Fold 71:
#   mse: 6651.0478515625
#   PiggyCast: area weighted rmse: 66.11390572774386
#   graphcast: area weighted rmse: 69.66709291568554
#   pangu: area weighted rmse: 82.84680467579788
#   neuralgcm: area weighted rmse: 62.871526779488356
#   ifshres: area weighted rmse: 76.94083770487161
# Fold 72:
#   mse: 7821.2392578125
#   PiggyCast: area weighted rmse: 71.57441643011329
#   graphcast: area weighted rmse: 68.78920964856272
#   pangu: area weighted rmse: 85.86727113310738
#   neuralgcm: area weighted rmse: 67.18137318781045
#   ifshres: area weighted rmse: 76.55041427622612
# Fold 73:
#   mse: 7504.75537109375
#   PiggyCast: area weighted rmse: 69.78393906795013
#   graphcast: area weighted rmse: 72.82594097141208
#   pangu: area weighted rmse: 76.12089893087865
#   neuralgcm: area weighted rmse: 58.916587734326555
#   ifshres: area weighted rmse: 76.64220271940248
# Fold 74:
#   mse: 15750.791015625
#   PiggyCast: area weighted rmse: 96.21292302143384
#   graphcast: area weighted rmse: 65.86842836446672
#   pangu: area weighted rmse: 75.39454190580291
#   neuralgcm: area weighted rmse: 59.40917186603913
#   ifshres: area weighted rmse: 75.649332110388
# Fold 75:
#   mse: 7257.375
#   PiggyCast: area weighted rmse: 66.63103174225432
#   graphcast: area weighted rmse: 66.5251295283256
#   pangu: area weighted rmse: 76.72416974887216
#   neuralgcm: area weighted rmse: 60.549564103931445
#   ifshres: area weighted rmse: 74.47730455743194
# Fold 76:
#   mse: 6001.09375
#   PiggyCast: area weighted rmse: 65.33113658723973
#   graphcast: area weighted rmse: 66.95664508271008
#   pangu: area weighted rmse: 68.84162710312215
#   neuralgcm: area weighted rmse: 60.12880370562759
#   ifshres: area weighted rmse: 77.36362535171068
# Fold 77:
#   mse: 5743.2705078125
#   PiggyCast: area weighted rmse: 64.52919634859971
#   graphcast: area weighted rmse: 67.4236271818905
#   pangu: area weighted rmse: 70.46211705153596
#   neuralgcm: area weighted rmse: 61.51706306337658
#   ifshres: area weighted rmse: 74.58004674123707
# Fold 78:
#   mse: 5635.02587890625
#   PiggyCast: area weighted rmse: 63.59090815489776
#   graphcast: area weighted rmse: 67.34320214286417
#   pangu: area weighted rmse: 72.93367039620497
#   neuralgcm: area weighted rmse: 56.33071465770929
#   ifshres: area weighted rmse: 69.6743141393286
# Fold 79:
#   mse: 5502.94580078125
#   PiggyCast: area weighted rmse: 61.765754334057796
#   graphcast: area weighted rmse: 64.58549694574042
#   pangu: area weighted rmse: 74.39528218122722
#   neuralgcm: area weighted rmse: 53.75432972847788
#   ifshres: area weighted rmse: 74.00434717738082
# Fold 80:
#   mse: 4666.62939453125
#   PiggyCast: area weighted rmse: 59.89669291453076
#   graphcast: area weighted rmse: 63.89198660461966
#   pangu: area weighted rmse: 66.68727942850262
#   neuralgcm: area weighted rmse: 53.30843288249649
#   ifshres: area weighted rmse: 69.88854817225096
# Fold 81:
#   mse: 4963.1484375
#   PiggyCast: area weighted rmse: 60.61155696504991
#   graphcast: area weighted rmse: 62.03267721168619
#   pangu: area weighted rmse: 62.10756986352995
#   neuralgcm: area weighted rmse: 60.75066253864496
#   ifshres: area weighted rmse: 68.2292074165636
# Fold 82:
#   mse: 4738.16259765625
#   PiggyCast: area weighted rmse: 60.80407359211875
#   graphcast: area weighted rmse: 68.29172858768719
#   pangu: area weighted rmse: 69.49720291454378
#   neuralgcm: area weighted rmse: 58.91523486118738
#   ifshres: area weighted rmse: 67.81773477867841
# Fold 83:
#   mse: 5817.4619140625
#   PiggyCast: area weighted rmse: 63.701972095125775
#   graphcast: area weighted rmse: 71.4450424783458
#   pangu: area weighted rmse: 67.46550261811545
#   neuralgcm: area weighted rmse: 54.8612689811241
#   ifshres: area weighted rmse: 67.79704524266077
# Fold 84:
#   mse: 5072.037109375
#   PiggyCast: area weighted rmse: 60.38895562627468
#   graphcast: area weighted rmse: 63.81584575632564
#   pangu: area weighted rmse: 66.31703229655496
#   neuralgcm: area weighted rmse: 55.01668042503871
#   ifshres: area weighted rmse: 62.36217013091288
# Fold 85:
#   mse: 5529.0947265625
#   PiggyCast: area weighted rmse: 62.919392161978145
#   graphcast: area weighted rmse: 65.57865417898648
#   pangu: area weighted rmse: 71.5513615984652
#   neuralgcm: area weighted rmse: 58.66199704340532
#   ifshres: area weighted rmse: 71.08587196896119
# Fold 86:
#   mse: 4774.6201171875
#   PiggyCast: area weighted rmse: 58.35462438406356
#   graphcast: area weighted rmse: 62.67171268177121
#   pangu: area weighted rmse: 65.19007226998932
#   neuralgcm: area weighted rmse: 57.89470738036137
#   ifshres: area weighted rmse: 65.36429318294367
# Fold 87:
#   mse: 4968.53662109375
#   PiggyCast: area weighted rmse: 58.69655428970177
#   graphcast: area weighted rmse: 59.577721198774505
#   pangu: area weighted rmse: 64.13759915641205
#   neuralgcm: area weighted rmse: 53.96052981793556
#   ifshres: area weighted rmse: 67.62794733793798
# Fold 88:
#   mse: 4801.212890625
#   PiggyCast: area weighted rmse: 59.62842332475837
#   graphcast: area weighted rmse: 62.742429186707625
#   pangu: area weighted rmse: 65.3841052284691
#   neuralgcm: area weighted rmse: 55.51420741199465
#   ifshres: area weighted rmse: 64.46709452521159
# Fold 89:
#   mse: 4375.05078125
#   PiggyCast: area weighted rmse: 59.35002649522984
#   graphcast: area weighted rmse: 63.37140709707658
#   pangu: area weighted rmse: 64.81450057974605
#   neuralgcm: area weighted rmse: 56.11000411235413
#   ifshres: area weighted rmse: 68.00243159802432
# Fold 90:
#   mse: 5576.60693359375
#   PiggyCast: area weighted rmse: 62.52925823858482
#   graphcast: area weighted rmse: 59.23164217497702
#   pangu: area weighted rmse: 65.26991620473102
#   neuralgcm: area weighted rmse: 54.062243823677974
#   ifshres: area weighted rmse: 66.40752935441738
# Fold 91:
#   mse: 4293.33984375
#   PiggyCast: area weighted rmse: 56.196924669266146
#   graphcast: area weighted rmse: 63.083418684014084
#   pangu: area weighted rmse: 64.33248106487942
#   neuralgcm: area weighted rmse: 52.240457318080026
#   ifshres: area weighted rmse: 74.2028636106765
# Fold 92:
#   mse: 5017.19970703125
#   PiggyCast: area weighted rmse: 60.4710348969845
#   graphcast: area weighted rmse: 68.46041310280312
#   pangu: area weighted rmse: 74.54495454477772
#   neuralgcm: area weighted rmse: 60.114366035783206
#   ifshres: area weighted rmse: 78.54278335383486
# Fold 93:
#   mse: 5455.83544921875
#   PiggyCast: area weighted rmse: 62.655899078580724
#   graphcast: area weighted rmse: 73.01265033337859
#   pangu: area weighted rmse: 84.09092469044036
#   neuralgcm: area weighted rmse: 61.95364797642772
#   ifshres: area weighted rmse: 72.07796502186824
# Fold 94:
#   mse: 4665.20068359375
#   PiggyCast: area weighted rmse: 58.60088316521974
#   graphcast: area weighted rmse: 76.27333365199067
#   pangu: area weighted rmse: 74.62399010196076
#   neuralgcm: area weighted rmse: 54.64057820938011
#   ifshres: area weighted rmse: 71.25831237430039
# Fold 95:
#   mse: 5069.66796875
#   PiggyCast: area weighted rmse: 58.23655646266535
#   graphcast: area weighted rmse: 74.99332155830584
#   pangu: area weighted rmse: 78.29068685516559
#   neuralgcm: area weighted rmse: 54.34427494642919
#   ifshres: area weighted rmse: 74.83026571347855
# Fold 96:
#   mse: 7473.70947265625
#   PiggyCast: area weighted rmse: 60.92231588983296
#   graphcast: area weighted rmse: 71.62936273211632
#   pangu: area weighted rmse: 66.93224767583627
#   neuralgcm: area weighted rmse: 54.54391872077912
#   ifshres: area weighted rmse: 68.32694008033468
# Fold 97:
#   mse: 20138.451171875
#   PiggyCast: area weighted rmse: 78.41357028497652
#   graphcast: area weighted rmse: 75.85853017809892
#   pangu: area weighted rmse: 75.4831820277207
#   neuralgcm: area weighted rmse: 56.34421898447252
#   ifshres: area weighted rmse: 73.27075817986373
# Fold 98:
#   mse: 6473.46142578125
#   PiggyCast: area weighted rmse: 63.484570244859704
#   graphcast: area weighted rmse: 70.78828653461707
#   pangu: area weighted rmse: 73.21256705163327
#   neuralgcm: area weighted rmse: 56.109070767840855
#   ifshres: area weighted rmse: 73.38178211755877
# Fold 99:
#   mse: 8723.416015625
#   PiggyCast: area weighted rmse: 76.96192904729867
#   graphcast: area weighted rmse: 68.652961859522
#   pangu: area weighted rmse: 76.20739341188592
#   neuralgcm: area weighted rmse: 56.92006845797425
#   ifshres: area weighted rmse: 78.44100315869099
# Fold 100:
#   mse: 6991.92822265625
#   PiggyCast: area weighted rmse: 68.26674634517715
#   graphcast: area weighted rmse: 70.04275843023265
#   pangu: area weighted rmse: 78.05165308235262
#   neuralgcm: area weighted rmse: 63.44878067005872
#   ifshres: area weighted rmse: 77.01315702451073
# {48: {'PiggyCast': 66.79803191395125,
#       'graphcast': 68.30286540686531,
#       'ifshres': 72.26321581642165,
#       'neuralgcm': 58.8188866450093,
#       'pangu': 72.53779305424568}}
# ======Lead time: 72========
# Shape of x :(1497088, 6)
# Shape of y : (1497088,)
# Train times Min Date: 2020-09-23 00:00:00 Train times Max Date:2020-09-24 12:00:00
# Test times Min Date: 2020-09-26 00:00:00 Test times Max Date:2020-09-26 12:00:00
# Train times Min Date: 2020-09-24 00:00:00 Train times Max Date:2020-09-25 12:00:00
# Test times Min Date: 2020-09-27 00:00:00 Test times Max Date:2020-09-27 12:00:00
# Train times Min Date: 2020-09-25 00:00:00 Train times Max Date:2020-09-26 12:00:00
# Test times Min Date: 2020-09-28 00:00:00 Test times Max Date:2020-09-28 12:00:00
# Train times Min Date: 2020-09-26 00:00:00 Train times Max Date:2020-09-27 12:00:00
# Test times Min Date: 2020-09-29 00:00:00 Test times Max Date:2020-09-29 12:00:00
# Train times Min Date: 2020-09-27 00:00:00 Train times Max Date:2020-09-28 12:00:00
# Test times Min Date: 2020-09-30 00:00:00 Test times Max Date:2020-09-30 12:00:00
# Train times Min Date: 2020-09-28 00:00:00 Train times Max Date:2020-09-29 12:00:00
# Test times Min Date: 2020-10-01 00:00:00 Test times Max Date:2020-10-01 12:00:00
# Train times Min Date: 2020-09-29 00:00:00 Train times Max Date:2020-09-30 12:00:00
# Test times Min Date: 2020-10-02 00:00:00 Test times Max Date:2020-10-02 12:00:00
# Train times Min Date: 2020-09-30 00:00:00 Train times Max Date:2020-10-01 12:00:00
# Test times Min Date: 2020-10-03 00:00:00 Test times Max Date:2020-10-03 12:00:00
# Train times Min Date: 2020-10-01 00:00:00 Train times Max Date:2020-10-02 12:00:00
# Test times Min Date: 2020-10-04 00:00:00 Test times Max Date:2020-10-04 12:00:00
# Train times Min Date: 2020-10-02 00:00:00 Train times Max Date:2020-10-03 12:00:00
# Test times Min Date: 2020-10-05 00:00:00 Test times Max Date:2020-10-05 12:00:00
# Fold 1:
#   mse: 15203.7177734375
#   PiggyCast: area weighted rmse: 102.50044061264526
#   graphcast: area weighted rmse: 108.7601001129764
#   pangu: area weighted rmse: 112.44280801177455
#   neuralgcm: area weighted rmse: 94.7277400650581
#   ifshres: area weighted rmse: 119.57172113688648
# Fold 2:
#   mse: 16697.625
#   PiggyCast: area weighted rmse: 103.58549890534623
#   graphcast: area weighted rmse: 120.20289383553995
#   pangu: area weighted rmse: 113.38236504066295
#   neuralgcm: area weighted rmse: 93.52006649882571
#   ifshres: area weighted rmse: 119.40931479315795
# Fold 3:
#   mse: 14977.623046875
#   PiggyCast: area weighted rmse: 96.26460875840236
#   graphcast: area weighted rmse: 117.55231146795376
#   pangu: area weighted rmse: 113.50826041142932
#   neuralgcm: area weighted rmse: 91.19467353444057
#   ifshres: area weighted rmse: 106.09490251424012
# Fold 4:
#   mse: 18255.123046875
#   PiggyCast: area weighted rmse: 100.90601141997594
#   graphcast: area weighted rmse: 106.20874122673901
#   pangu: area weighted rmse: 126.83566494614931
#   neuralgcm: area weighted rmse: 88.08504812369283
#   ifshres: area weighted rmse: 112.55506837797498
# Fold 5:
#   mse: 17943.86328125
#   PiggyCast: area weighted rmse: 106.90538495338883
#   graphcast: area weighted rmse: 106.86969554036006
#   pangu: area weighted rmse: 122.04859056548648
#   neuralgcm: area weighted rmse: 104.62663338099986
#   ifshres: area weighted rmse: 134.4076164899243
# Fold 6:
#   mse: 22364.212890625
#   PiggyCast: area weighted rmse: 126.01454027242102
#   graphcast: area weighted rmse: 138.44069973155771
#   pangu: area weighted rmse: 145.21163901479824
#   neuralgcm: area weighted rmse: 132.73800963924572
#   ifshres: area weighted rmse: 148.1004056353596
# Fold 7:
#   mse: 22575.98046875
#   PiggyCast: area weighted rmse: 122.07570120427539
#   graphcast: area weighted rmse: 131.31973458262982
#   pangu: area weighted rmse: 135.3351329460048
#   neuralgcm: area weighted rmse: 114.7020672121849
#   ifshres: area weighted rmse: 143.99002734648664
# Fold 8:
#   mse: 28794.453125
#   PiggyCast: area weighted rmse: 135.2857121701848
#   graphcast: area weighted rmse: 129.59476764024913
#   pangu: area weighted rmse: 136.23875463621113
#   neuralgcm: area weighted rmse: 110.41159985258382
#   ifshres: area weighted rmse: 143.32332328204564
# Fold 9:
#   mse: 21071.421875
#   PiggyCast: area weighted rmse: 115.51239774589693
#   graphcast: area weighted rmse: 114.7137805558777
#   pangu: area weighted rmse: 125.56970943176108
#   neuralgcm: area weighted rmse: 93.0665026507478
#   ifshres: area weighted rmse: 145.6417139586949
# Fold 10:
#   mse: 19008.919921875
#   PiggyCast: area weighted rmse: 114.97645417211922
#   graphcast: area weighted rmse: 133.40529080211488
#   pangu: area weighted rmse: 126.92534071887634
#   neuralgcm: area weighted rmse: 99.66277455676818
#   ifshres: area weighted rmse: 140.91103534442155
# Fold 11:
#   mse: 28851.05859375
#   PiggyCast: area weighted rmse: 136.41707998405866
#   graphcast: area weighted rmse: 127.10443709975593
#   pangu: area weighted rmse: 132.45081548744344
#   neuralgcm: area weighted rmse: 120.62706821570373
#   ifshres: area weighted rmse: 138.13852399531905
# Fold 12:
#   mse: 23059.19921875
#   PiggyCast: area weighted rmse: 121.1731148373704
#   graphcast: area weighted rmse: 106.40835092769392
#   pangu: area weighted rmse: 118.4197121552055
#   neuralgcm: area weighted rmse: 115.29440462536716
#   ifshres: area weighted rmse: 128.99355826240813
# Fold 13:
#   mse: 20383.80859375
#   PiggyCast: area weighted rmse: 110.95496282213915
#   graphcast: area weighted rmse: 106.0438802619995
#   pangu: area weighted rmse: 111.94863894931144
#   neuralgcm: area weighted rmse: 105.23922740013586
#   ifshres: area weighted rmse: 118.3307683833852
# Fold 14:
#   mse: 25570.58984375
#   PiggyCast: area weighted rmse: 128.01240151664754
#   graphcast: area weighted rmse: 107.62754034762416
#   pangu: area weighted rmse: 119.42238594512861
#   neuralgcm: area weighted rmse: 97.13247618557313
#   ifshres: area weighted rmse: 114.84965909700767
# Fold 15:
#   mse: 17523.546875
#   PiggyCast: area weighted rmse: 106.74020100025254
#   graphcast: area weighted rmse: 104.1962484520506
#   pangu: area weighted rmse: 108.50019306014802
#   neuralgcm: area weighted rmse: 97.67581152417796
#   ifshres: area weighted rmse: 109.66642421447058
# Fold 16:
#   mse: 16940.462890625
#   PiggyCast: area weighted rmse: 101.05369852234496
#   graphcast: area weighted rmse: 106.33814653375993
#   pangu: area weighted rmse: 113.16323771363433
#   neuralgcm: area weighted rmse: 91.30117633646934
#   ifshres: area weighted rmse: 122.99635669245549
# Fold 17:
#   mse: 14706.52734375
#   PiggyCast: area weighted rmse: 104.31561318158215
#   graphcast: area weighted rmse: 120.52721369025902
#   pangu: area weighted rmse: 118.26210155591443
#   neuralgcm: area weighted rmse: 101.74608140289176
#   ifshres: area weighted rmse: 117.12495278277189
# Fold 18:
#   mse: 13686.693359375
#   PiggyCast: area weighted rmse: 96.33743651102017
#   graphcast: area weighted rmse: 103.83435759549855
#   pangu: area weighted rmse: 111.75759988317512
#   neuralgcm: area weighted rmse: 93.84473942766665
#   ifshres: area weighted rmse: 113.15017737082239
# Fold 19:
#   mse: 18321.306640625
#   PiggyCast: area weighted rmse: 105.82616826865971
#   graphcast: area weighted rmse: 112.84847431710334
#   pangu: area weighted rmse: 123.51300468986226
#   neuralgcm: area weighted rmse: 93.51384152003027
#   ifshres: area weighted rmse: 117.82735648781174
# Fold 20:
#   mse: 24256.42578125
#   PiggyCast: area weighted rmse: 125.75038753405416
#   graphcast: area weighted rmse: 122.93448011591049
#   pangu: area weighted rmse: 130.37467016979764
#   neuralgcm: area weighted rmse: 140.76370869952885
#   ifshres: area weighted rmse: 124.43522322355194
# Fold 21:
#   mse: 23541.84765625
#   PiggyCast: area weighted rmse: 115.10574080428728
#   graphcast: area weighted rmse: 121.19673777897327
#   pangu: area weighted rmse: 124.62658714803472
#   neuralgcm: area weighted rmse: 107.64360888934614
#   ifshres: area weighted rmse: 127.8899688522556
# Fold 22:
#   mse: 26896.5078125
#   PiggyCast: area weighted rmse: 123.41255657799546
#   graphcast: area weighted rmse: 126.56594006291101
#   pangu: area weighted rmse: 133.28454366605612
#   neuralgcm: area weighted rmse: 113.24396969450927
#   ifshres: area weighted rmse: 125.29075552263123
# Fold 23:
#   mse: 27787.734375
#   PiggyCast: area weighted rmse: 128.19854704351687
#   graphcast: area weighted rmse: 119.57371794457346
#   pangu: area weighted rmse: 131.5866628043437
#   neuralgcm: area weighted rmse: 104.58519402073887
#   ifshres: area weighted rmse: 125.90442217001223
# Fold 24:
#   mse: 17251.130859375
#   PiggyCast: area weighted rmse: 102.10583371125016
#   graphcast: area weighted rmse: 107.71014961530022
#   pangu: area weighted rmse: 109.24417739279322
#   neuralgcm: area weighted rmse: 86.30979365174005
#   ifshres: area weighted rmse: 123.06369913782633
# Fold 25:
#   mse: 17282.1484375
#   PiggyCast: area weighted rmse: 103.73142656505271
#   graphcast: area weighted rmse: 106.24442680637216
#   pangu: area weighted rmse: 110.3327903037612
#   neuralgcm: area weighted rmse: 94.67416302862735
#   ifshres: area weighted rmse: 101.7706741609869
# Fold 26:
#   mse: 15919.345703125
#   PiggyCast: area weighted rmse: 102.08100266995848
#   graphcast: area weighted rmse: 99.9987961374748
#   pangu: area weighted rmse: 111.65219553108287
#   neuralgcm: area weighted rmse: 97.89020544086438
#   ifshres: area weighted rmse: 104.35389880050155
# Fold 27:
#   mse: 24218.69140625
#   PiggyCast: area weighted rmse: 113.99301589490888
#   graphcast: area weighted rmse: 106.59118986156476
#   pangu: area weighted rmse: 113.41660920587269
#   neuralgcm: area weighted rmse: 93.70740479603413
#   ifshres: area weighted rmse: 114.29499689260702
# Fold 28:
#   mse: 15072.5322265625
#   PiggyCast: area weighted rmse: 101.0660546261142
#   graphcast: area weighted rmse: 110.83566645650703
#   pangu: area weighted rmse: 114.75189693804639
#   neuralgcm: area weighted rmse: 94.4738226283157
#   ifshres: area weighted rmse: 125.72216030724672
# Fold 29:
#   mse: 13260.2744140625
#   PiggyCast: area weighted rmse: 93.58197775181912
#   graphcast: area weighted rmse: 102.46435542622446
#   pangu: area weighted rmse: 102.68388040990256
#   neuralgcm: area weighted rmse: 89.27424551304968
#   ifshres: area weighted rmse: 113.0129853857144
# Fold 30:
#   mse: 17349.05859375
#   PiggyCast: area weighted rmse: 109.26210284418762
#   graphcast: area weighted rmse: 118.37075657244114
#   pangu: area weighted rmse: 119.07742700349729
#   neuralgcm: area weighted rmse: 103.29454172607268
#   ifshres: area weighted rmse: 115.71784263440911
# Fold 31:
#   mse: 17822.087890625
#   PiggyCast: area weighted rmse: 112.36256591353565
#   graphcast: area weighted rmse: 121.75931690964366
#   pangu: area weighted rmse: 128.0405458032046
#   neuralgcm: area weighted rmse: 110.77558197911914
#   ifshres: area weighted rmse: 118.58492815663335
# Fold 32:
#   mse: 19386.6171875
#   PiggyCast: area weighted rmse: 111.08564600222884
#   graphcast: area weighted rmse: 106.46363005551439
#   pangu: area weighted rmse: 118.6971089947596
#   neuralgcm: area weighted rmse: 107.74031345384277
#   ifshres: area weighted rmse: 128.3977754461338
# Fold 33:
#   mse: 20326.4375
#   PiggyCast: area weighted rmse: 119.8789144385455
#   graphcast: area weighted rmse: 122.31811653076451
#   pangu: area weighted rmse: 121.15229690851064
#   neuralgcm: area weighted rmse: 107.74229742316017
#   ifshres: area weighted rmse: 132.06270786748192
# Fold 34:
#   mse: 22113.568359375
#   PiggyCast: area weighted rmse: 120.27080247475776
#   graphcast: area weighted rmse: 112.08963925783848
#   pangu: area weighted rmse: 120.34861461574475
#   neuralgcm: area weighted rmse: 109.32095099234303
#   ifshres: area weighted rmse: 139.7594669421377
# Fold 35:
#   mse: 15465.193359375
#   PiggyCast: area weighted rmse: 105.4248351578561
#   graphcast: area weighted rmse: 108.4978829077564
#   pangu: area weighted rmse: 121.13394692117632
#   neuralgcm: area weighted rmse: 99.12593409932633
#   ifshres: area weighted rmse: 129.62589337264777
# Fold 36:
#   mse: 16935.775390625
#   PiggyCast: area weighted rmse: 112.30652770452845
#   graphcast: area weighted rmse: 118.3155480224059
#   pangu: area weighted rmse: 131.19419994209485
#   neuralgcm: area weighted rmse: 107.62007075189351
#   ifshres: area weighted rmse: 124.84656815404803
# Fold 37:
#   mse: 18045.916015625
#   PiggyCast: area weighted rmse: 111.14402861004432
#   graphcast: area weighted rmse: 111.631366296304
#   pangu: area weighted rmse: 131.07081626313237
#   neuralgcm: area weighted rmse: 104.82415030186439
#   ifshres: area weighted rmse: 117.73588551077938
# Fold 38:
#   mse: 21247.7265625
#   PiggyCast: area weighted rmse: 111.68152429695773
#   graphcast: area weighted rmse: 111.2284053501701
#   pangu: area weighted rmse: 118.81191689336151
#   neuralgcm: area weighted rmse: 107.80438331656504
#   ifshres: area weighted rmse: 117.8284764898049
# Fold 39:
#   mse: 35064.625
#   PiggyCast: area weighted rmse: 124.39043362252146
#   graphcast: area weighted rmse: 108.12090077657136
#   pangu: area weighted rmse: 120.01906805136204
#   neuralgcm: area weighted rmse: 103.73489433856312
#   ifshres: area weighted rmse: 124.23773326537636
# Fold 40:
#   mse: 30674.720703125
#   PiggyCast: area weighted rmse: 120.28756333119908
#   graphcast: area weighted rmse: 104.01725927114889
#   pangu: area weighted rmse: 117.9481576809641
#   neuralgcm: area weighted rmse: 94.86585719374814
#   ifshres: area weighted rmse: 112.80005482802568
# Fold 41:
#   mse: 19248.43359375
#   PiggyCast: area weighted rmse: 112.31009734087107
#   graphcast: area weighted rmse: 110.85366562130149
#   pangu: area weighted rmse: 120.2737098068324
#   neuralgcm: area weighted rmse: 102.28874833242514
#   ifshres: area weighted rmse: 130.0242295505124
# Fold 42:
#   mse: 14739.30078125
#   PiggyCast: area weighted rmse: 101.36359303162433
#   graphcast: area weighted rmse: 107.92580780143379
#   pangu: area weighted rmse: 111.84443165819785
#   neuralgcm: area weighted rmse: 86.47259419553103
#   ifshres: area weighted rmse: 114.61771319447429
# Fold 43:
#   mse: 14638.8701171875
#   PiggyCast: area weighted rmse: 97.97002315717238
#   graphcast: area weighted rmse: 103.25432415184945
#   pangu: area weighted rmse: 109.23877312601584
#   neuralgcm: area weighted rmse: 92.28711151299079
#   ifshres: area weighted rmse: 108.02708872244226
# Fold 44:
#   mse: 15497.3916015625
#   PiggyCast: area weighted rmse: 102.29932217525652
#   graphcast: area weighted rmse: 114.0275282726967
#   pangu: area weighted rmse: 114.44792011728121
#   neuralgcm: area weighted rmse: 93.04381136794292
#   ifshres: area weighted rmse: 107.94824492432132
# Fold 45:
#   mse: 23317.25390625
#   PiggyCast: area weighted rmse: 104.72277361865801
#   graphcast: area weighted rmse: 101.22876431100674
#   pangu: area weighted rmse: 100.76563256956794
#   neuralgcm: area weighted rmse: 95.70690069344683
#   ifshres: area weighted rmse: 94.5830039588368
# Fold 46:
#   mse: 19488.7265625
#   PiggyCast: area weighted rmse: 106.73877136018724
#   graphcast: area weighted rmse: 107.1930374708433
#   pangu: area weighted rmse: 107.11542299693583
#   neuralgcm: area weighted rmse: 110.5668284920707
#   ifshres: area weighted rmse: 97.20672770719133
# Fold 47:
#   mse: 15757.984375
#   PiggyCast: area weighted rmse: 105.83624037292861
#   graphcast: area weighted rmse: 104.68872017625797
#   pangu: area weighted rmse: 115.03169386790593
#   neuralgcm: area weighted rmse: 110.1188928755793
#   ifshres: area weighted rmse: 113.96124530540042
# Fold 48:
#   mse: 23329.599609375
#   PiggyCast: area weighted rmse: 117.94347361335525
#   graphcast: area weighted rmse: 119.07897405438878
#   pangu: area weighted rmse: 124.18700421835227
#   neuralgcm: area weighted rmse: 104.77824162567175
#   ifshres: area weighted rmse: 130.2865875227339
# Fold 49:
#   mse: 23343.1796875
#   PiggyCast: area weighted rmse: 116.16210654798017
#   graphcast: area weighted rmse: 130.53792716174235
#   pangu: area weighted rmse: 142.96311573646486
#   neuralgcm: area weighted rmse: 114.08110261214269
#   ifshres: area weighted rmse: 148.89898496564624
# Fold 50:
#   mse: 15999.513671875
#   PiggyCast: area weighted rmse: 102.35745885293606
#   graphcast: area weighted rmse: 115.36724049479974
#   pangu: area weighted rmse: 121.51332045092053
#   neuralgcm: area weighted rmse: 97.46441630672527
#   ifshres: area weighted rmse: 123.11340554657491
# Fold 51:
#   mse: 20620.21484375
#   PiggyCast: area weighted rmse: 115.02958359880147
#   graphcast: area weighted rmse: 117.77855016572933
#   pangu: area weighted rmse: 127.2145172609764
#   neuralgcm: area weighted rmse: 110.62484092956555
#   ifshres: area weighted rmse: 133.17765603651384
# Fold 52:
#   mse: 19221.384765625
#   PiggyCast: area weighted rmse: 109.2482765834284
#   graphcast: area weighted rmse: 123.88308762160507
#   pangu: area weighted rmse: 127.64664422176315
#   neuralgcm: area weighted rmse: 98.41864908680438
#   ifshres: area weighted rmse: 134.8304905145069
# Fold 53:
#   mse: 15633.8466796875
#   PiggyCast: area weighted rmse: 100.63991598024221
#   graphcast: area weighted rmse: 103.8420001129641
#   pangu: area weighted rmse: 122.3343213036534
#   neuralgcm: area weighted rmse: 96.99854007363491
#   ifshres: area weighted rmse: 117.6502625276291
# Fold 54:
#   mse: 18405.796875
#   PiggyCast: area weighted rmse: 106.88117609949612
#   graphcast: area weighted rmse: 96.26465298294372
#   pangu: area weighted rmse: 116.31837962389943
#   neuralgcm: area weighted rmse: 95.94154296706272
#   ifshres: area weighted rmse: 111.42772415283838
# Fold 55:
#   mse: 29536.298828125
#   PiggyCast: area weighted rmse: 133.96296798939446
#   graphcast: area weighted rmse: 108.0252573408706
#   pangu: area weighted rmse: 133.73993441851533
#   neuralgcm: area weighted rmse: 97.02142675280045
#   ifshres: area weighted rmse: 110.180118231103
# Fold 56:
#   mse: 22729.69140625
#   PiggyCast: area weighted rmse: 123.14917849530465
#   graphcast: area weighted rmse: 112.7166679040134
#   pangu: area weighted rmse: 120.04207755026182
#   neuralgcm: area weighted rmse: 99.84431772853044
#   ifshres: area weighted rmse: 116.30672005731891
# Fold 57:
#   mse: 16375.5263671875
#   PiggyCast: area weighted rmse: 103.10570114313099
#   graphcast: area weighted rmse: 110.03428992649492
#   pangu: area weighted rmse: 113.34642657960285
#   neuralgcm: area weighted rmse: 103.82033632427664
#   ifshres: area weighted rmse: 114.99950668859748
# Fold 58:
#   mse: 16345.90234375
#   PiggyCast: area weighted rmse: 105.86009878597116
#   graphcast: area weighted rmse: 117.34050930768149
#   pangu: area weighted rmse: 134.478927733224
#   neuralgcm: area weighted rmse: 103.84240208870256
#   ifshres: area weighted rmse: 119.57805505245375
# Fold 59:
#   mse: 15038.23046875
#   PiggyCast: area weighted rmse: 102.06954897789771
#   graphcast: area weighted rmse: 104.74367557309661
#   pangu: area weighted rmse: 119.27442878966885
#   neuralgcm: area weighted rmse: 100.70016598816635
#   ifshres: area weighted rmse: 103.98979969599047
# Fold 60:
#   mse: 14686.830078125
#   PiggyCast: area weighted rmse: 101.9687245180401
#   graphcast: area weighted rmse: 106.14334411823661
#   pangu: area weighted rmse: 110.36539669066224
#   neuralgcm: area weighted rmse: 94.86646611327264
#   ifshres: area weighted rmse: 104.66259807430407
# Fold 61:
#   mse: 15172.080078125
#   PiggyCast: area weighted rmse: 103.92757861665045
#   graphcast: area weighted rmse: 106.8531438060292
#   pangu: area weighted rmse: 109.60003111443743
#   neuralgcm: area weighted rmse: 93.33517876984477
#   ifshres: area weighted rmse: 127.18993991854596
# Fold 62:
#   mse: 20896.021484375
#   PiggyCast: area weighted rmse: 113.19316681412859
#   graphcast: area weighted rmse: 111.35190734326467
#   pangu: area weighted rmse: 113.8158860878823
#   neuralgcm: area weighted rmse: 107.87778257892782
#   ifshres: area weighted rmse: 128.78257151780053
# Fold 63:
#   mse: 18007.107421875
#   PiggyCast: area weighted rmse: 107.42606293761482
#   graphcast: area weighted rmse: 106.00971339851533
#   pangu: area weighted rmse: 122.04188978299952
#   neuralgcm: area weighted rmse: 105.89474193854366
#   ifshres: area weighted rmse: 123.93770389309665
# Fold 64:
#   mse: 17467.55078125
#   PiggyCast: area weighted rmse: 107.48719217658699
#   graphcast: area weighted rmse: 102.20731397212808
#   pangu: area weighted rmse: 122.02677320989551
#   neuralgcm: area weighted rmse: 97.642977211097
#   ifshres: area weighted rmse: 128.88494715204558
# Fold 65:
#   mse: 13180.0205078125
#   PiggyCast: area weighted rmse: 98.44610129871204
#   graphcast: area weighted rmse: 98.56863161420223
#   pangu: area weighted rmse: 110.33997716372447
#   neuralgcm: area weighted rmse: 89.48364266214273
#   ifshres: area weighted rmse: 113.44895744297129
# Fold 66:
#   mse: 13508.810546875
#   PiggyCast: area weighted rmse: 97.30707927063335
#   graphcast: area weighted rmse: 96.80120236328067
#   pangu: area weighted rmse: 109.27351132867268
#   neuralgcm: area weighted rmse: 97.75631029819327
#   ifshres: area weighted rmse: 116.71214704708854
# Fold 67:
#   mse: 18147.20703125
#   PiggyCast: area weighted rmse: 109.17598769213366
#   graphcast: area weighted rmse: 122.16721007894081
#   pangu: area weighted rmse: 121.83277819488572
#   neuralgcm: area weighted rmse: 114.62293933843743
#   ifshres: area weighted rmse: 126.53878284215452
# Fold 68:
#   mse: 14706.7802734375
#   PiggyCast: area weighted rmse: 104.67151653088243
#   graphcast: area weighted rmse: 115.72449043646748
#   pangu: area weighted rmse: 116.93327959118596
#   neuralgcm: area weighted rmse: 101.74082977181908
#   ifshres: area weighted rmse: 145.79912274908432
# Fold 69:
#   mse: 13338.3310546875
#   PiggyCast: area weighted rmse: 99.98743115081876
#   graphcast: area weighted rmse: 104.6297331814364
#   pangu: area weighted rmse: 112.39764080362302
#   neuralgcm: area weighted rmse: 97.40904636565759
#   ifshres: area weighted rmse: 124.64651045102123
# Fold 70:
#   mse: 19594.10546875
#   PiggyCast: area weighted rmse: 112.48769398890288
#   graphcast: area weighted rmse: 107.18653471779432
#   pangu: area weighted rmse: 125.23485744380073
#   neuralgcm: area weighted rmse: 108.6327312363031
#   ifshres: area weighted rmse: 126.20790137955136
# Fold 71:
#   mse: 18908.29296875
#   PiggyCast: area weighted rmse: 112.25590027555509
#   graphcast: area weighted rmse: 115.06355229329347
#   pangu: area weighted rmse: 151.15858222920085
#   neuralgcm: area weighted rmse: 106.66794477602913
#   ifshres: area weighted rmse: 130.06436796706518
# Fold 72:
#   mse: 20375.2578125
#   PiggyCast: area weighted rmse: 118.21108395641095
#   graphcast: area weighted rmse: 117.82000303600995
#   pangu: area weighted rmse: 138.67880731337107
#   neuralgcm: area weighted rmse: 113.06972401335777
#   ifshres: area weighted rmse: 127.49392795020357
# Fold 73:
#   mse: 28813.04296875
#   PiggyCast: area weighted rmse: 127.86211202646636
#   graphcast: area weighted rmse: 117.05739076900073
#   pangu: area weighted rmse: 118.50781962806452
#   neuralgcm: area weighted rmse: 102.84101804683847
#   ifshres: area weighted rmse: 124.37228811522745
# Fold 74:
#   mse: 15800.779296875
#   PiggyCast: area weighted rmse: 100.15517136800811
#   graphcast: area weighted rmse: 101.95015540758907
#   pangu: area weighted rmse: 121.12853392687373
#   neuralgcm: area weighted rmse: 95.11523086555567
#   ifshres: area weighted rmse: 118.11203434130333
# Fold 75:
#   mse: 16671.837890625
#   PiggyCast: area weighted rmse: 110.23067885513827
#   graphcast: area weighted rmse: 105.5588896373727
#   pangu: area weighted rmse: 118.81950931295216
#   neuralgcm: area weighted rmse: 105.84110201508528
#   ifshres: area weighted rmse: 120.99194960878434
# Fold 76:
#   mse: 14798.376953125
#   PiggyCast: area weighted rmse: 105.24897029224478
#   graphcast: area weighted rmse: 109.82351179588993
#   pangu: area weighted rmse: 113.75148531634822
#   neuralgcm: area weighted rmse: 95.86007563540761
#   ifshres: area weighted rmse: 125.13454040282603
# Fold 77:
#   mse: 17311.24609375
#   PiggyCast: area weighted rmse: 112.53249563111474
#   graphcast: area weighted rmse: 113.15723759026152
#   pangu: area weighted rmse: 126.67526133074637
#   neuralgcm: area weighted rmse: 108.1729752154254
#   ifshres: area weighted rmse: 117.4886604569731
# Fold 78:
#   mse: 14654.04296875
#   PiggyCast: area weighted rmse: 104.9174146402135
#   graphcast: area weighted rmse: 114.1428737791281
#   pangu: area weighted rmse: 117.41072086915207
#   neuralgcm: area weighted rmse: 98.41579021846195
#   ifshres: area weighted rmse: 117.84425063451262
# Fold 79:
#   mse: 15174.685546875
#   PiggyCast: area weighted rmse: 109.2088752191088
#   graphcast: area weighted rmse: 106.22055200859783
#   pangu: area weighted rmse: 111.40788662414434
#   neuralgcm: area weighted rmse: 97.39128907175208
#   ifshres: area weighted rmse: 119.28047780589137
# Fold 80:
#   mse: 14263.751953125
#   PiggyCast: area weighted rmse: 109.47025779886687
#   graphcast: area weighted rmse: 112.78538872923504
#   pangu: area weighted rmse: 114.33920695945447
#   neuralgcm: area weighted rmse: 96.96834154105272
#   ifshres: area weighted rmse: 128.4664829928899
# Fold 81:
#   mse: 12495.73828125
#   PiggyCast: area weighted rmse: 97.64790458903205
#   graphcast: area weighted rmse: 100.7641411994696
#   pangu: area weighted rmse: 98.76351895652837
#   neuralgcm: area weighted rmse: 102.50468476391023
#   ifshres: area weighted rmse: 105.35988109742719
# Fold 82:
#   mse: 14154.525390625
#   PiggyCast: area weighted rmse: 103.35961480996652
#   graphcast: area weighted rmse: 111.21904590395079
#   pangu: area weighted rmse: 115.4046420059413
#   neuralgcm: area weighted rmse: 99.3694487511243
#   ifshres: area weighted rmse: 108.36162942576823
# Fold 83:
#   mse: 13929.33984375
#   PiggyCast: area weighted rmse: 97.91936719478853
#   graphcast: area weighted rmse: 108.48898065583006
#   pangu: area weighted rmse: 100.87625358417607
#   neuralgcm: area weighted rmse: 88.7370710281805
#   ifshres: area weighted rmse: 114.49927636410787
# Fold 84:
#   mse: 11689.4375
#   PiggyCast: area weighted rmse: 88.9065323796228
#   graphcast: area weighted rmse: 94.03986746670846
#   pangu: area weighted rmse: 104.07034768910944
#   neuralgcm: area weighted rmse: 94.33624481515815
#   ifshres: area weighted rmse: 95.55658192447659
# Fold 85:
#   mse: 12484.9169921875
#   PiggyCast: area weighted rmse: 95.54516615950227
#   graphcast: area weighted rmse: 107.9668344821911
#   pangu: area weighted rmse: 111.31424750807818
#   neuralgcm: area weighted rmse: 94.90406567522214
#   ifshres: area weighted rmse: 107.98242268965984
# Fold 86:
#   mse: 12085.650390625
#   PiggyCast: area weighted rmse: 91.37584521562556
#   graphcast: area weighted rmse: 99.98929112560505
#   pangu: area weighted rmse: 99.94089702858362
#   neuralgcm: area weighted rmse: 86.80571864248631
#   ifshres: area weighted rmse: 101.8010473524847
# Fold 87:
#   mse: 11674.123046875
#   PiggyCast: area weighted rmse: 94.4499602649674
#   graphcast: area weighted rmse: 95.30888253221472
#   pangu: area weighted rmse: 105.01671276450814
#   neuralgcm: area weighted rmse: 92.05582968943939
#   ifshres: area weighted rmse: 105.82610420072793
# Fold 88:
#   mse: 10745.64453125
#   PiggyCast: area weighted rmse: 89.02993566240495
#   graphcast: area weighted rmse: 100.9208446422231
#   pangu: area weighted rmse: 104.42375607089677
#   neuralgcm: area weighted rmse: 88.47244265928207
#   ifshres: area weighted rmse: 100.24893587912905
# Fold 89:
#   mse: 12081.666015625
#   PiggyCast: area weighted rmse: 93.71616604430798
#   graphcast: area weighted rmse: 104.81203858974052
#   pangu: area weighted rmse: 105.57989610658542
#   neuralgcm: area weighted rmse: 80.95848618516102
#   ifshres: area weighted rmse: 107.55175143575927
# Fold 90:
#   mse: 12582.2119140625
#   PiggyCast: area weighted rmse: 93.36052805263334
#   graphcast: area weighted rmse: 95.59551579274464
#   pangu: area weighted rmse: 105.42739738883469
#   neuralgcm: area weighted rmse: 77.68688924864917
#   ifshres: area weighted rmse: 113.96116405255218
# Fold 91:
#   mse: 13201.7216796875
#   PiggyCast: area weighted rmse: 97.27630962691444
#   graphcast: area weighted rmse: 109.6501120997446
#   pangu: area weighted rmse: 112.27630628058601
#   neuralgcm: area weighted rmse: 92.32765526639002
#   ifshres: area weighted rmse: 123.33733439308548
# Fold 92:
#   mse: 16134.65234375
#   PiggyCast: area weighted rmse: 107.42423343010655
#   graphcast: area weighted rmse: 123.59993196361212
#   pangu: area weighted rmse: 140.44633350512558
#   neuralgcm: area weighted rmse: 103.90301052046142
#   ifshres: area weighted rmse: 126.32376452738023
# Fold 93:
#   mse: 11763.8349609375
#   PiggyCast: area weighted rmse: 89.96123066479922
#   graphcast: area weighted rmse: 126.05817310680972
#   pangu: area weighted rmse: 130.2501806359575
#   neuralgcm: area weighted rmse: 92.44149792886678
#   ifshres: area weighted rmse: 105.7291348796898
# Fold 94:
#   mse: 15195.791015625
#   PiggyCast: area weighted rmse: 103.53422336457965
#   graphcast: area weighted rmse: 126.5380007464147
#   pangu: area weighted rmse: 120.41466272184006
#   neuralgcm: area weighted rmse: 95.33640699763652
#   ifshres: area weighted rmse: 115.90192427240216
# Fold 95:
#   mse: 15803.7802734375
#   PiggyCast: area weighted rmse: 94.3308412057856
#   graphcast: area weighted rmse: 103.75425818411006
#   pangu: area weighted rmse: 115.63517847892646
#   neuralgcm: area weighted rmse: 88.0468679176748
#   ifshres: area weighted rmse: 115.09638255071818
# Fold 96:
#   mse: 25501.35546875
#   PiggyCast: area weighted rmse: 105.44036691431685
#   graphcast: area weighted rmse: 109.28996232537177
#   pangu: area weighted rmse: 114.3119369898936
#   neuralgcm: area weighted rmse: 93.43756292342795
#   ifshres: area weighted rmse: 114.41057055716405
# Fold 97:
#   mse: 15088.90234375
#   PiggyCast: area weighted rmse: 103.30099519171279
#   graphcast: area weighted rmse: 125.45500398526008
#   pangu: area weighted rmse: 127.40766765615155
#   neuralgcm: area weighted rmse: 89.46045084011229
#   ifshres: area weighted rmse: 122.49147773858215
# Fold 98:
#   mse: 15870.00390625
#   PiggyCast: area weighted rmse: 103.7464690359838
#   graphcast: area weighted rmse: 118.38120338680854
#   pangu: area weighted rmse: 118.25145252115341
#   neuralgcm: area weighted rmse: 96.13822025753028
#   ifshres: area weighted rmse: 114.94081708377955
# Fold 99:
#   mse: 16922.263671875
#   PiggyCast: area weighted rmse: 107.55849026134293
#   graphcast: area weighted rmse: 108.98555571842671
#   pangu: area weighted rmse: 124.8423392091476
#   neuralgcm: area weighted rmse: 101.97478686181965
#   ifshres: area weighted rmse: 125.8089967587865
# Fold 100:
#   mse: 14162.9765625
#   PiggyCast: area weighted rmse: 100.69977437154145
#   graphcast: area weighted rmse: 103.16310083731472
#   pangu: area weighted rmse: 124.43941923168764
#   neuralgcm: area weighted rmse: 99.67586195102744
#   ifshres: area weighted rmse: 117.74454602548956
# {48: {'PiggyCast': 66.79803191395125,
#       'graphcast': 68.30286540686531,
#       'ifshres': 72.26321581642165,
#       'neuralgcm': 58.8188866450093,
#       'pangu': 72.53779305424568},
#  72: {'PiggyCast': 107.94384671656853,
#       'graphcast': 111.42913152151061,
#       'ifshres': 120.12220493594052,
#       'neuralgcm': 100.2072524465265,
#       'pangu': 119.10993731096305}}

# %%
# @title Training and Evaluation Loop- Time series split : 60 Days Training, 1 Day Gap and 1 Day Testing

# Initialize xgb regressor
xgb = xgboost.XGBRegressor(random_state=42, device="cuda")

# Calculate Cross-Validation using 10 folds
cv_timeseries = TimeSeriesSplit(n_splits=50, max_train_size=32 * 64 * 2 * 60,
                                test_size= 32 * 64 * 2 * 1, gap=32 * 64 * 2 * 1)

# Lead Times
lead_times=[48, 72]

nested_scores = {} # Nested scores for each lead time
rmse_results = {} # rmse results for each lead time, models

for lead_time in lead_times:
  print(f"======Lead time: {lead_time}========")

  df_filtered = data_per_lead_time(full_df,lead_time)

  X = df_filtered[[f"graphcast_lt{lead_time}", f"pangu_lt{lead_time}",
                   f"neuralgcm_lt{lead_time}",
                  #  f"keisler_lt{lead_time}",
                   f"ifshres_lt{lead_time}", "longitude", "latitude"]]
  y = df_filtered["era5"]
  area_weight = df_filtered["area_weight"]

  print(f"Shape of x :{X.shape}")
  print(f"Shape of y : {y.shape}")

  # Nested Scores
  nested_score = cross_validate(xgb, X=X, y=y, cv=cv_timeseries,
                              scoring=('neg_mean_squared_error', 'r2'),
                              params={'sample_weight': area_weight}
                              )
  nested_scores[lead_time] = nested_score

  # Cross validation plot
  cross_validation_plot(df_filtered, cv_timeseries, lead_time)

  # RMSE
  rmse_result = train_and_evaluate(xgb, cv_timeseries,X,y, area_weight, lead_time)
  rmse_results[lead_time] = rmse_result

  # RMSE plots per model
  rmse_per_fold_plot(rmse_result, lead_time)

  # print nicely average RMSE per Leadtime
  average_scores = rmse_mean_per_lead_time_and_model(rmse_results)
  pprint(average_scores)
# Out:
# ======Lead time: 48========
# Shape of x :(1497088, 6)
# Shape of y : (1497088,)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [05:23:28] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# Train times Min Date: 2020-09-14 00:00:00 Train times Max Date:2020-11-12 12:00:00
# Test times Min Date: 2020-11-14 00:00:00 Test times Max Date:2020-11-14 12:00:00
# Train times Min Date: 2020-09-15 00:00:00 Train times Max Date:2020-11-13 12:00:00
# Test times Min Date: 2020-11-15 00:00:00 Test times Max Date:2020-11-15 12:00:00
# Train times Min Date: 2020-09-16 00:00:00 Train times Max Date:2020-11-14 12:00:00
# Test times Min Date: 2020-11-16 00:00:00 Test times Max Date:2020-11-16 12:00:00
# Train times Min Date: 2020-09-17 00:00:00 Train times Max Date:2020-11-15 12:00:00
# Test times Min Date: 2020-11-17 00:00:00 Test times Max Date:2020-11-17 12:00:00
# Train times Min Date: 2020-09-18 00:00:00 Train times Max Date:2020-11-16 12:00:00
# Test times Min Date: 2020-11-18 00:00:00 Test times Max Date:2020-11-18 12:00:00
# Train times Min Date: 2020-09-19 00:00:00 Train times Max Date:2020-11-17 12:00:00
# Test times Min Date: 2020-11-19 00:00:00 Test times Max Date:2020-11-19 12:00:00
# Train times Min Date: 2020-09-20 00:00:00 Train times Max Date:2020-11-18 12:00:00
# Test times Min Date: 2020-11-20 00:00:00 Test times Max Date:2020-11-20 12:00:00
# Train times Min Date: 2020-09-21 00:00:00 Train times Max Date:2020-11-19 12:00:00
# Test times Min Date: 2020-11-21 00:00:00 Test times Max Date:2020-11-21 12:00:00
# Train times Min Date: 2020-09-22 00:00:00 Train times Max Date:2020-11-20 12:00:00
# Test times Min Date: 2020-11-22 00:00:00 Test times Max Date:2020-11-22 12:00:00
# Train times Min Date: 2020-09-23 00:00:00 Train times Max Date:2020-11-21 12:00:00
# Test times Min Date: 2020-11-23 00:00:00 Test times Max Date:2020-11-23 12:00:00
# Fold 1:
#   mse: 4568.5498046875
#   PiggyCast: area weighted rmse: 55.715367462108254
#   graphcast: area weighted rmse: 67.26584189280081
#   pangu: area weighted rmse: 79.14576529735893
#   neuralgcm: area weighted rmse: 60.28657172531705
#   ifshres: area weighted rmse: 74.44224470999734
# Fold 2:
#   mse: 4854.421875
#   PiggyCast: area weighted rmse: 58.37261338156236
#   graphcast: area weighted rmse: 72.38865764918006
#   pangu: area weighted rmse: 80.92375255983762
#   neuralgcm: area weighted rmse: 59.581779657256625
#   ifshres: area weighted rmse: 79.7550172093289
# Fold 3:
#   mse: 4516.255859375
#   PiggyCast: area weighted rmse: 56.61145340536326
#   graphcast: area weighted rmse: 68.19580830057947
#   pangu: area weighted rmse: 76.94252000249926
#   neuralgcm: area weighted rmse: 60.911534441497196
#   ifshres: area weighted rmse: 79.08546032051333
# Fold 4:
#   mse: 3737.99072265625
#   PiggyCast: area weighted rmse: 50.796521191390504
#   graphcast: area weighted rmse: 62.53395595099651
#   pangu: area weighted rmse: 66.3340801576231
#   neuralgcm: area weighted rmse: 56.2409456004878
#   ifshres: area weighted rmse: 70.62596769582896
# Fold 5:
#   mse: 4170.08447265625
#   PiggyCast: area weighted rmse: 49.82342696429872
#   graphcast: area weighted rmse: 64.19010297925611
#   pangu: area weighted rmse: 78.47084246182114
#   neuralgcm: area weighted rmse: 54.960207725418584
#   ifshres: area weighted rmse: 68.78146539823196
# Fold 6:
#   mse: 3900.361328125
#   PiggyCast: area weighted rmse: 50.923834435560956
#   graphcast: area weighted rmse: 66.07070047587021
#   pangu: area weighted rmse: 77.28869075314527
#   neuralgcm: area weighted rmse: 57.53403242621801
#   ifshres: area weighted rmse: 67.9395654294876
# Fold 7:
#   mse: 4362.1201171875
#   PiggyCast: area weighted rmse: 54.772620351758256
#   graphcast: area weighted rmse: 69.26758215040849
#   pangu: area weighted rmse: 70.06884090220724
#   neuralgcm: area weighted rmse: 59.2280069459056
#   ifshres: area weighted rmse: 75.12870650665054
# Fold 8:
#   mse: 4455.466796875
#   PiggyCast: area weighted rmse: 56.36901404280793
#   graphcast: area weighted rmse: 67.38047491335804
#   pangu: area weighted rmse: 77.75194250495622
#   neuralgcm: area weighted rmse: 60.49376550789836
#   ifshres: area weighted rmse: 74.40692586991908
# Fold 9:
#   mse: 4259.3515625
#   PiggyCast: area weighted rmse: 54.72616874172022
#   graphcast: area weighted rmse: 65.2519219447887
#   pangu: area weighted rmse: 71.96728818789828
#   neuralgcm: area weighted rmse: 61.325070685219956
#   ifshres: area weighted rmse: 69.05436037414748
# Fold 10:
#   mse: 4473.5634765625
#   PiggyCast: area weighted rmse: 56.81629152083995
#   graphcast: area weighted rmse: 70.81764806171869
#   pangu: area weighted rmse: 71.74852721096713
#   neuralgcm: area weighted rmse: 62.54230980192203
#   ifshres: area weighted rmse: 66.83198016820278
# Fold 11:
#   mse: 3294.11962890625
#   PiggyCast: area weighted rmse: 48.57298082655588
#   graphcast: area weighted rmse: 59.933278027014964
#   pangu: area weighted rmse: 67.44601959313619
#   neuralgcm: area weighted rmse: 56.22660301487149
#   ifshres: area weighted rmse: 68.3784959201829
# Fold 12:
#   mse: 4329.4521484375
#   PiggyCast: area weighted rmse: 54.04317655724356
#   graphcast: area weighted rmse: 64.89259679014344
#   pangu: area weighted rmse: 68.14302298202959
#   neuralgcm: area weighted rmse: 60.42533313103018
#   ifshres: area weighted rmse: 75.1636284217382
# Fold 13:
#   mse: 4668.96484375
#   PiggyCast: area weighted rmse: 55.7341900708338
#   graphcast: area weighted rmse: 65.328452851907
#   pangu: area weighted rmse: 71.72144889980798
#   neuralgcm: area weighted rmse: 63.47103669289252
#   ifshres: area weighted rmse: 77.76896018980413
# Fold 14:
#   mse: 3911.13427734375
#   PiggyCast: area weighted rmse: 54.86457219249331
#   graphcast: area weighted rmse: 64.45592205974278
#   pangu: area weighted rmse: 76.78686712161165
#   neuralgcm: area weighted rmse: 60.51622667331678
#   ifshres: area weighted rmse: 76.42801795347528
# Fold 15:
#   mse: 3616.745849609375
#   PiggyCast: area weighted rmse: 52.73130062297145
#   graphcast: area weighted rmse: 61.599743970979
#   pangu: area weighted rmse: 72.03399736144858
#   neuralgcm: area weighted rmse: 56.39544298369116
#   ifshres: area weighted rmse: 72.65690643286824
# Fold 16:
#   mse: 3506.0810546875
#   PiggyCast: area weighted rmse: 52.31569297434436
#   graphcast: area weighted rmse: 60.55395181112729
#   pangu: area weighted rmse: 69.92163859833576
#   neuralgcm: area weighted rmse: 55.717369689019066
#   ifshres: area weighted rmse: 70.6202255693586
# Fold 17:
#   mse: 3657.482421875
#   PiggyCast: area weighted rmse: 52.93050352302922
#   graphcast: area weighted rmse: 69.57895590223322
#   pangu: area weighted rmse: 70.5320261895935
#   neuralgcm: area weighted rmse: 57.53758026494272
#   ifshres: area weighted rmse: 69.57519338286794
# Fold 18:
#   mse: 4078.1669921875
#   PiggyCast: area weighted rmse: 53.59784102144296
#   graphcast: area weighted rmse: 69.84757762147296
#   pangu: area weighted rmse: 75.00777599587124
#   neuralgcm: area weighted rmse: 56.61217514355405
#   ifshres: area weighted rmse: 79.47194442726041
# Fold 19:
#   mse: 3220.10595703125
#   PiggyCast: area weighted rmse: 49.326215949428594
#   graphcast: area weighted rmse: 63.58564963511097
#   pangu: area weighted rmse: 62.79519623125233
#   neuralgcm: area weighted rmse: 56.684712583598916
#   ifshres: area weighted rmse: 75.51309758375393
# Fold 20:
#   mse: 3823.12255859375
#   PiggyCast: area weighted rmse: 53.489475858202674
#   graphcast: area weighted rmse: 63.645910732636345
#   pangu: area weighted rmse: 71.68260961424603
#   neuralgcm: area weighted rmse: 57.95627154342962
#   ifshres: area weighted rmse: 74.25557803143055
# Fold 21:
#   mse: 5112.21533203125
#   PiggyCast: area weighted rmse: 57.66109218751098
#   graphcast: area weighted rmse: 69.66709291568554
#   pangu: area weighted rmse: 82.84680467579788
#   neuralgcm: area weighted rmse: 62.871526779488356
#   ifshres: area weighted rmse: 76.94083770487161
# Fold 22:
#   mse: 5284.8994140625
#   PiggyCast: area weighted rmse: 59.36893485107542
#   graphcast: area weighted rmse: 68.78920964856272
#   pangu: area weighted rmse: 85.86727113310738
#   neuralgcm: area weighted rmse: 67.18137318781045
#   ifshres: area weighted rmse: 76.55041427622612
# Fold 23:
#   mse: 4373.5859375
#   PiggyCast: area weighted rmse: 54.93702507461244
#   graphcast: area weighted rmse: 72.82594097141208
#   pangu: area weighted rmse: 76.12089893087865
#   neuralgcm: area weighted rmse: 58.916587734326555
#   ifshres: area weighted rmse: 76.64220271940248
# Fold 24:
#   mse: 3898.5693359375
#   PiggyCast: area weighted rmse: 53.089010066579156
#   graphcast: area weighted rmse: 65.86842836446672
#   pangu: area weighted rmse: 75.39454190580291
#   neuralgcm: area weighted rmse: 59.40917186603913
#   ifshres: area weighted rmse: 75.649332110388
# Fold 25:
#   mse: 3984.58056640625
#   PiggyCast: area weighted rmse: 54.14397861429683
#   graphcast: area weighted rmse: 66.5251295283256
#   pangu: area weighted rmse: 76.72416974887216
#   neuralgcm: area weighted rmse: 60.549564103931445
#   ifshres: area weighted rmse: 74.47730455743194
# Fold 26:
#   mse: 3817.115234375
#   PiggyCast: area weighted rmse: 54.66427848110291
#   graphcast: area weighted rmse: 66.95664508271008
#   pangu: area weighted rmse: 68.84162710312215
#   neuralgcm: area weighted rmse: 60.12880370562759
#   ifshres: area weighted rmse: 77.36362535171068
# Fold 27:
#   mse: 4382.79541015625
#   PiggyCast: area weighted rmse: 57.020383734543884
#   graphcast: area weighted rmse: 67.4236271818905
#   pangu: area weighted rmse: 70.46211705153596
#   neuralgcm: area weighted rmse: 61.51706306337658
#   ifshres: area weighted rmse: 74.58004674123707
# Fold 28:
#   mse: 3945.230224609375
#   PiggyCast: area weighted rmse: 53.185410159043535
#   graphcast: area weighted rmse: 67.34320214286417
#   pangu: area weighted rmse: 72.93367039620497
#   neuralgcm: area weighted rmse: 56.33071465770929
#   ifshres: area weighted rmse: 69.6743141393286
# Fold 29:
#   mse: 4147.07421875
#   PiggyCast: area weighted rmse: 52.3871936962885
#   graphcast: area weighted rmse: 64.58549694574042
#   pangu: area weighted rmse: 74.39528218122722
#   neuralgcm: area weighted rmse: 53.75432972847788
#   ifshres: area weighted rmse: 74.00434717738082
# Fold 30:
#   mse: 3271.51708984375
#   PiggyCast: area weighted rmse: 50.20141487744963
#   graphcast: area weighted rmse: 63.89198660461966
#   pangu: area weighted rmse: 66.68727942850262
#   neuralgcm: area weighted rmse: 53.30843288249649
#   ifshres: area weighted rmse: 69.88854817225096
# Fold 31:
#   mse: 3606.2705078125
#   PiggyCast: area weighted rmse: 51.94682490826426
#   graphcast: area weighted rmse: 62.03267721168619
#   pangu: area weighted rmse: 62.10756986352995
#   neuralgcm: area weighted rmse: 60.75066253864496
#   ifshres: area weighted rmse: 68.2292074165636
# Fold 32:
#   mse: 3828.712646484375
#   PiggyCast: area weighted rmse: 53.368854750164694
#   graphcast: area weighted rmse: 68.29172858768719
#   pangu: area weighted rmse: 69.49720291454378
#   neuralgcm: area weighted rmse: 58.91523486118738
#   ifshres: area weighted rmse: 67.81773477867841
# Fold 33:
#   mse: 3603.26806640625
#   PiggyCast: area weighted rmse: 51.26903235287372
#   graphcast: area weighted rmse: 71.4450424783458
#   pangu: area weighted rmse: 67.46550261811545
#   neuralgcm: area weighted rmse: 54.8612689811241
#   ifshres: area weighted rmse: 67.79704524266077
# Fold 34:
#   mse: 3542.44970703125
#   PiggyCast: area weighted rmse: 48.22391685612956
#   graphcast: area weighted rmse: 63.81584575632564
#   pangu: area weighted rmse: 66.31703229655496
#   neuralgcm: area weighted rmse: 55.01668042503871
#   ifshres: area weighted rmse: 62.36217013091288
# Fold 35:
#   mse: 4178.04541015625
#   PiggyCast: area weighted rmse: 53.84301879141189
#   graphcast: area weighted rmse: 65.57865417898648
#   pangu: area weighted rmse: 71.5513615984652
#   neuralgcm: area weighted rmse: 58.66199704340532
#   ifshres: area weighted rmse: 71.08587196896119
# Fold 36:
#   mse: 3466.869140625
#   PiggyCast: area weighted rmse: 50.813556068841514
#   graphcast: area weighted rmse: 62.67171268177121
#   pangu: area weighted rmse: 65.19007226998932
#   neuralgcm: area weighted rmse: 57.89470738036137
#   ifshres: area weighted rmse: 65.36429318294367
# Fold 37:
#   mse: 3064.64892578125
#   PiggyCast: area weighted rmse: 47.59168836369907
#   graphcast: area weighted rmse: 59.577721198774505
#   pangu: area weighted rmse: 64.13759915641205
#   neuralgcm: area weighted rmse: 53.96052981793556
#   ifshres: area weighted rmse: 67.62794733793798
# Fold 38:
#   mse: 3497.274169921875
#   PiggyCast: area weighted rmse: 50.87944804673054
#   graphcast: area weighted rmse: 62.742429186707625
#   pangu: area weighted rmse: 65.3841052284691
#   neuralgcm: area weighted rmse: 55.51420741199465
#   ifshres: area weighted rmse: 64.46709452521159
# Fold 39:
#   mse: 3349.93212890625
#   PiggyCast: area weighted rmse: 49.999405835995425
#   graphcast: area weighted rmse: 63.37140709707658
#   pangu: area weighted rmse: 64.81450057974605
#   neuralgcm: area weighted rmse: 56.11000411235413
#   ifshres: area weighted rmse: 68.00243159802432
# Fold 40:
#   mse: 3321.643310546875
#   PiggyCast: area weighted rmse: 48.590579587550785
#   graphcast: area weighted rmse: 59.23164217497702
#   pangu: area weighted rmse: 65.26991620473102
#   neuralgcm: area weighted rmse: 54.062243823677974
#   ifshres: area weighted rmse: 66.40752935441738
# Fold 41:
#   mse: 3260.04345703125
#   PiggyCast: area weighted rmse: 48.76886284648526
#   graphcast: area weighted rmse: 63.083418684014084
#   pangu: area weighted rmse: 64.33248106487942
#   neuralgcm: area weighted rmse: 52.240457318080026
#   ifshres: area weighted rmse: 74.2028636106765
# Fold 42:
#   mse: 3903.5283203125
#   PiggyCast: area weighted rmse: 53.56686894544806
#   graphcast: area weighted rmse: 68.46041310280312
#   pangu: area weighted rmse: 74.54495454477772
#   neuralgcm: area weighted rmse: 60.114366035783206
#   ifshres: area weighted rmse: 78.54278335383486
# Fold 43:
#   mse: 4183.9599609375
#   PiggyCast: area weighted rmse: 54.275911943877205
#   graphcast: area weighted rmse: 73.01265033337859
#   pangu: area weighted rmse: 84.09092469044036
#   neuralgcm: area weighted rmse: 61.95364797642772
#   ifshres: area weighted rmse: 72.07796502186824
# Fold 44:
#   mse: 3375.43408203125
#   PiggyCast: area weighted rmse: 49.62245592081783
#   graphcast: area weighted rmse: 76.27333365199067
#   pangu: area weighted rmse: 74.62399010196076
#   neuralgcm: area weighted rmse: 54.64057820938011
#   ifshres: area weighted rmse: 71.25831237430039
# Fold 45:
#   mse: 3739.03125
#   PiggyCast: area weighted rmse: 51.3485377140541
#   graphcast: area weighted rmse: 74.99332155830584
#   pangu: area weighted rmse: 78.29068685516559
#   neuralgcm: area weighted rmse: 54.34427494642919
#   ifshres: area weighted rmse: 74.83026571347855
# Fold 46:
#   mse: 3854.45556640625
#   PiggyCast: area weighted rmse: 49.51854329348353
#   graphcast: area weighted rmse: 71.62936273211632
#   pangu: area weighted rmse: 66.93224767583627
#   neuralgcm: area weighted rmse: 54.54391872077912
#   ifshres: area weighted rmse: 68.32694008033468
# Fold 47:
#   mse: 4321.478515625
#   PiggyCast: area weighted rmse: 54.44461483190208
#   graphcast: area weighted rmse: 75.85853017809892
#   pangu: area weighted rmse: 75.4831820277207
#   neuralgcm: area weighted rmse: 56.34421898447252
#   ifshres: area weighted rmse: 73.27075817986373
# Fold 48:
#   mse: 4180.25341796875
#   PiggyCast: area weighted rmse: 52.78945472850064
#   graphcast: area weighted rmse: 70.78828653461707
#   pangu: area weighted rmse: 73.21256705163327
#   neuralgcm: area weighted rmse: 56.109070767840855
#   ifshres: area weighted rmse: 73.38178211755877
# Fold 49:
#   mse: 5169.25830078125
#   PiggyCast: area weighted rmse: 54.747464057217584
#   graphcast: area weighted rmse: 68.652961859522
#   pangu: area weighted rmse: 76.20739341188592
#   neuralgcm: area weighted rmse: 56.92006845797425
#   ifshres: area weighted rmse: 78.44100315869099
# Fold 50:
#   mse: 4596.1640625
#   PiggyCast: area weighted rmse: 57.04628829150044
#   graphcast: area weighted rmse: 70.04275843023265
#   pangu: area weighted rmse: 78.05165308235262
#   neuralgcm: area weighted rmse: 63.44878067005872
#   ifshres: area weighted rmse: 77.01315702451073
# {48: {'PiggyCast': 53.03694621942815,
#       'graphcast': 66.84430781450041,
#       'ifshres': 72.4432374143341,
#       'neuralgcm': 58.10042924859443,
#       'pangu': 72.28982916835817}}
# ======Lead time: 72========
# Shape of x :(1497088, 6)
# Shape of y : (1497088,)
# Train times Min Date: 2020-09-15 00:00:00 Train times Max Date:2020-11-13 12:00:00
# Test times Min Date: 2020-11-15 00:00:00 Test times Max Date:2020-11-15 12:00:00
# Train times Min Date: 2020-09-16 00:00:00 Train times Max Date:2020-11-14 12:00:00
# Test times Min Date: 2020-11-16 00:00:00 Test times Max Date:2020-11-16 12:00:00
# Train times Min Date: 2020-09-17 00:00:00 Train times Max Date:2020-11-15 12:00:00
# Test times Min Date: 2020-11-17 00:00:00 Test times Max Date:2020-11-17 12:00:00
# Train times Min Date: 2020-09-18 00:00:00 Train times Max Date:2020-11-16 12:00:00
# Test times Min Date: 2020-11-18 00:00:00 Test times Max Date:2020-11-18 12:00:00
# Train times Min Date: 2020-09-19 00:00:00 Train times Max Date:2020-11-17 12:00:00
# Test times Min Date: 2020-11-19 00:00:00 Test times Max Date:2020-11-19 12:00:00
# Train times Min Date: 2020-09-20 00:00:00 Train times Max Date:2020-11-18 12:00:00
# Test times Min Date: 2020-11-20 00:00:00 Test times Max Date:2020-11-20 12:00:00
# Train times Min Date: 2020-09-21 00:00:00 Train times Max Date:2020-11-19 12:00:00
# Test times Min Date: 2020-11-21 00:00:00 Test times Max Date:2020-11-21 12:00:00
# Train times Min Date: 2020-09-22 00:00:00 Train times Max Date:2020-11-20 12:00:00
# Test times Min Date: 2020-11-22 00:00:00 Test times Max Date:2020-11-22 12:00:00
# Train times Min Date: 2020-09-23 00:00:00 Train times Max Date:2020-11-21 12:00:00
# Test times Min Date: 2020-11-23 00:00:00 Test times Max Date:2020-11-23 12:00:00
# Train times Min Date: 2020-09-24 00:00:00 Train times Max Date:2020-11-22 12:00:00
# Test times Min Date: 2020-11-24 00:00:00 Test times Max Date:2020-11-24 12:00:00
# Fold 1:
#   mse: 15209.384765625
#   PiggyCast: area weighted rmse: 101.7729988943827
#   graphcast: area weighted rmse: 117.77855016572933
#   pangu: area weighted rmse: 127.2145172609764
#   neuralgcm: area weighted rmse: 110.62484092956555
#   ifshres: area weighted rmse: 133.17765603651384
# Fold 2:
#   mse: 14454.0849609375
#   PiggyCast: area weighted rmse: 97.01946013096051
#   graphcast: area weighted rmse: 123.88308762160507
#   pangu: area weighted rmse: 127.64664422176315
#   neuralgcm: area weighted rmse: 98.41864908680438
#   ifshres: area weighted rmse: 134.8304905145069
# Fold 3:
#   mse: 11714.0625
#   PiggyCast: area weighted rmse: 89.29832402124414
#   graphcast: area weighted rmse: 103.8420001129641
#   pangu: area weighted rmse: 122.3343213036534
#   neuralgcm: area weighted rmse: 96.99854007363491
#   ifshres: area weighted rmse: 117.6502625276291
# Fold 4:
#   mse: 9819.94140625
#   PiggyCast: area weighted rmse: 80.94750412824678
#   graphcast: area weighted rmse: 96.26465298294372
#   pangu: area weighted rmse: 116.31837962389943
#   neuralgcm: area weighted rmse: 95.94154296706272
#   ifshres: area weighted rmse: 111.42772415283838
# Fold 5:
#   mse: 12919.1953125
#   PiggyCast: area weighted rmse: 90.33997939278947
#   graphcast: area weighted rmse: 108.0252573408706
#   pangu: area weighted rmse: 133.73993441851533
#   neuralgcm: area weighted rmse: 97.02142675280045
#   ifshres: area weighted rmse: 110.180118231103
# Fold 6:
#   mse: 11545.9609375
#   PiggyCast: area weighted rmse: 90.4951329261005
#   graphcast: area weighted rmse: 112.7166679040134
#   pangu: area weighted rmse: 120.04207755026182
#   neuralgcm: area weighted rmse: 99.84431772853044
#   ifshres: area weighted rmse: 116.30672005731891
# Fold 7:
#   mse: 13053.388671875
#   PiggyCast: area weighted rmse: 93.09794027867325
#   graphcast: area weighted rmse: 110.03428992649492
#   pangu: area weighted rmse: 113.34642657960285
#   neuralgcm: area weighted rmse: 103.82033632427664
#   ifshres: area weighted rmse: 114.99950668859748
# Fold 8:
#   mse: 14046.75
#   PiggyCast: area weighted rmse: 98.18248522867565
#   graphcast: area weighted rmse: 117.34050930768149
#   pangu: area weighted rmse: 134.478927733224
#   neuralgcm: area weighted rmse: 103.84240208870256
#   ifshres: area weighted rmse: 119.57805505245375
# Fold 9:
#   mse: 11755.419921875
#   PiggyCast: area weighted rmse: 89.87872957871727
#   graphcast: area weighted rmse: 104.74367557309661
#   pangu: area weighted rmse: 119.27442878966885
#   neuralgcm: area weighted rmse: 100.70016598816635
#   ifshres: area weighted rmse: 103.98979969599047
# Fold 10:
#   mse: 9974.5830078125
#   PiggyCast: area weighted rmse: 85.01843710074539
#   graphcast: area weighted rmse: 106.14334411823661
#   pangu: area weighted rmse: 110.36539669066224
#   neuralgcm: area weighted rmse: 94.86646611327264
#   ifshres: area weighted rmse: 104.66259807430407
# Fold 11:
#   mse: 9729.59765625
#   PiggyCast: area weighted rmse: 85.9776216953276
#   graphcast: area weighted rmse: 106.8531438060292
#   pangu: area weighted rmse: 109.60003111443743
#   neuralgcm: area weighted rmse: 93.33517876984477
#   ifshres: area weighted rmse: 127.18993991854596
# Fold 12:
#   mse: 14615.5625
#   PiggyCast: area weighted rmse: 96.53760231346101
#   graphcast: area weighted rmse: 111.35190734326467
#   pangu: area weighted rmse: 113.8158860878823
#   neuralgcm: area weighted rmse: 107.87778257892782
#   ifshres: area weighted rmse: 128.78257151780053
# Fold 13:
#   mse: 12059.8525390625
#   PiggyCast: area weighted rmse: 93.59013710378237
#   graphcast: area weighted rmse: 106.00971339851533
#   pangu: area weighted rmse: 122.04188978299952
#   neuralgcm: area weighted rmse: 105.89474193854366
#   ifshres: area weighted rmse: 123.93770389309665
# Fold 14:
#   mse: 10559.064453125
#   PiggyCast: area weighted rmse: 91.10206425862735
#   graphcast: area weighted rmse: 102.20731397212808
#   pangu: area weighted rmse: 122.02677320989551
#   neuralgcm: area weighted rmse: 97.642977211097
#   ifshres: area weighted rmse: 128.88494715204558
# Fold 15:
#   mse: 8403.388671875
#   PiggyCast: area weighted rmse: 81.75806217644256
#   graphcast: area weighted rmse: 98.56863161420223
#   pangu: area weighted rmse: 110.33997716372447
#   neuralgcm: area weighted rmse: 89.48364266214273
#   ifshres: area weighted rmse: 113.44895744297129
# Fold 16:
#   mse: 9281.83984375
#   PiggyCast: area weighted rmse: 85.11144528816718
#   graphcast: area weighted rmse: 96.80120236328067
#   pangu: area weighted rmse: 109.27351132867268
#   neuralgcm: area weighted rmse: 97.75631029819327
#   ifshres: area weighted rmse: 116.71214704708854
# Fold 17:
#   mse: 13803.62109375
#   PiggyCast: area weighted rmse: 100.32234049096651
#   graphcast: area weighted rmse: 122.16721007894081
#   pangu: area weighted rmse: 121.83277819488572
#   neuralgcm: area weighted rmse: 114.62293933843743
#   ifshres: area weighted rmse: 126.53878284215452
# Fold 18:
#   mse: 11816.046875
#   PiggyCast: area weighted rmse: 96.09639267301849
#   graphcast: area weighted rmse: 115.72449043646748
#   pangu: area weighted rmse: 116.93327959118596
#   neuralgcm: area weighted rmse: 101.74082977181908
#   ifshres: area weighted rmse: 145.79912274908432
# Fold 19:
#   mse: 10628.3779296875
#   PiggyCast: area weighted rmse: 87.48559467575535
#   graphcast: area weighted rmse: 104.6297331814364
#   pangu: area weighted rmse: 112.39764080362302
#   neuralgcm: area weighted rmse: 97.40904636565759
#   ifshres: area weighted rmse: 124.64651045102123
# Fold 20:
#   mse: 13409.6611328125
#   PiggyCast: area weighted rmse: 93.66517716098741
#   graphcast: area weighted rmse: 107.18653471779432
#   pangu: area weighted rmse: 125.23485744380073
#   neuralgcm: area weighted rmse: 108.6327312363031
#   ifshres: area weighted rmse: 126.20790137955136
# Fold 21:
#   mse: 15074.5751953125
#   PiggyCast: area weighted rmse: 98.05390845437744
#   graphcast: area weighted rmse: 115.06355229329347
#   pangu: area weighted rmse: 151.15858222920085
#   neuralgcm: area weighted rmse: 106.66794477602913
#   ifshres: area weighted rmse: 130.06436796706518
# Fold 22:
#   mse: 14875.150390625
#   PiggyCast: area weighted rmse: 101.23329607658174
#   graphcast: area weighted rmse: 117.82000303600995
#   pangu: area weighted rmse: 138.67880731337107
#   neuralgcm: area weighted rmse: 113.06972401335777
#   ifshres: area weighted rmse: 127.49392795020357
# Fold 23:
#   mse: 12466.1484375
#   PiggyCast: area weighted rmse: 91.359323639915
#   graphcast: area weighted rmse: 117.05739076900073
#   pangu: area weighted rmse: 118.50781962806452
#   neuralgcm: area weighted rmse: 102.84101804683847
#   ifshres: area weighted rmse: 124.37228811522745
# Fold 24:
#   mse: 10488.30859375
#   PiggyCast: area weighted rmse: 85.7470280161264
#   graphcast: area weighted rmse: 101.95015540758907
#   pangu: area weighted rmse: 121.12853392687373
#   neuralgcm: area weighted rmse: 95.11523086555567
#   ifshres: area weighted rmse: 118.11203434130333
# Fold 25:
#   mse: 11513.998046875
#   PiggyCast: area weighted rmse: 93.13679007155837
#   graphcast: area weighted rmse: 105.5588896373727
#   pangu: area weighted rmse: 118.81950931295216
#   neuralgcm: area weighted rmse: 105.84110201508528
#   ifshres: area weighted rmse: 120.99194960878434
# Fold 26:
#   mse: 11171.25
#   PiggyCast: area weighted rmse: 93.42957371159035
#   graphcast: area weighted rmse: 109.82351179588993
#   pangu: area weighted rmse: 113.75148531634822
#   neuralgcm: area weighted rmse: 95.86007563540761
#   ifshres: area weighted rmse: 125.13454040282603
# Fold 27:
#   mse: 13361.298828125
#   PiggyCast: area weighted rmse: 100.96528268246718
#   graphcast: area weighted rmse: 113.15723759026152
#   pangu: area weighted rmse: 126.67526133074637
#   neuralgcm: area weighted rmse: 108.1729752154254
#   ifshres: area weighted rmse: 117.4886604569731
# Fold 28:
#   mse: 12692.142578125
#   PiggyCast: area weighted rmse: 96.458951219933
#   graphcast: area weighted rmse: 114.1428737791281
#   pangu: area weighted rmse: 117.41072086915207
#   neuralgcm: area weighted rmse: 98.41579021846195
#   ifshres: area weighted rmse: 117.84425063451262
# Fold 29:
#   mse: 11512.822265625
#   PiggyCast: area weighted rmse: 91.01721940358182
#   graphcast: area weighted rmse: 106.22055200859783
#   pangu: area weighted rmse: 111.40788662414434
#   neuralgcm: area weighted rmse: 97.39128907175208
#   ifshres: area weighted rmse: 119.28047780589137
# Fold 30:
#   mse: 10363.97265625
#   PiggyCast: area weighted rmse: 91.06439392319238
#   graphcast: area weighted rmse: 112.78538872923504
#   pangu: area weighted rmse: 114.33920695945447
#   neuralgcm: area weighted rmse: 96.96834154105272
#   ifshres: area weighted rmse: 128.4664829928899
# Fold 31:
#   mse: 11341.375
#   PiggyCast: area weighted rmse: 88.00211157074929
#   graphcast: area weighted rmse: 100.7641411994696
#   pangu: area weighted rmse: 98.76351895652837
#   neuralgcm: area weighted rmse: 102.50468476391023
#   ifshres: area weighted rmse: 105.35988109742719
# Fold 32:
#   mse: 11313.6826171875
#   PiggyCast: area weighted rmse: 90.0419597098268
#   graphcast: area weighted rmse: 111.21904590395079
#   pangu: area weighted rmse: 115.4046420059413
#   neuralgcm: area weighted rmse: 99.3694487511243
#   ifshres: area weighted rmse: 108.36162942576823
# Fold 33:
#   mse: 9083.404296875
#   PiggyCast: area weighted rmse: 81.6920140568941
#   graphcast: area weighted rmse: 108.48898065583006
#   pangu: area weighted rmse: 100.87625358417607
#   neuralgcm: area weighted rmse: 88.7370710281805
#   ifshres: area weighted rmse: 114.49927636410787
# Fold 34:
#   mse: 8482.2197265625
#   PiggyCast: area weighted rmse: 78.03402625008373
#   graphcast: area weighted rmse: 94.03986746670846
#   pangu: area weighted rmse: 104.07034768910944
#   neuralgcm: area weighted rmse: 94.33624481515815
#   ifshres: area weighted rmse: 95.55658192447659
# Fold 35:
#   mse: 9631.509765625
#   PiggyCast: area weighted rmse: 86.29926590396636
#   graphcast: area weighted rmse: 107.9668344821911
#   pangu: area weighted rmse: 111.31424750807818
#   neuralgcm: area weighted rmse: 94.90406567522214
#   ifshres: area weighted rmse: 107.98242268965984
# Fold 36:
#   mse: 9114.654296875
#   PiggyCast: area weighted rmse: 78.79929447158848
#   graphcast: area weighted rmse: 99.98929112560505
#   pangu: area weighted rmse: 99.94089702858362
#   neuralgcm: area weighted rmse: 86.80571864248631
#   ifshres: area weighted rmse: 101.8010473524847
# Fold 37:
#   mse: 8706.09765625
#   PiggyCast: area weighted rmse: 81.12368364550474
#   graphcast: area weighted rmse: 95.30888253221472
#   pangu: area weighted rmse: 105.01671276450814
#   neuralgcm: area weighted rmse: 92.05582968943939
#   ifshres: area weighted rmse: 105.82610420072793
# Fold 38:
#   mse: 8550.126953125
#   PiggyCast: area weighted rmse: 78.74811493264068
#   graphcast: area weighted rmse: 100.9208446422231
#   pangu: area weighted rmse: 104.42375607089677
#   neuralgcm: area weighted rmse: 88.47244265928207
#   ifshres: area weighted rmse: 100.24893587912905
# Fold 39:
#   mse: 8829.802734375
#   PiggyCast: area weighted rmse: 79.1502884093799
#   graphcast: area weighted rmse: 104.81203858974052
#   pangu: area weighted rmse: 105.57989610658542
#   neuralgcm: area weighted rmse: 80.95848618516102
#   ifshres: area weighted rmse: 107.55175143575927
# Fold 40:
#   mse: 8180.876953125
#   PiggyCast: area weighted rmse: 76.47892345308492
#   graphcast: area weighted rmse: 95.59551579274464
#   pangu: area weighted rmse: 105.42739738883469
#   neuralgcm: area weighted rmse: 77.68688924864917
#   ifshres: area weighted rmse: 113.96116405255218
# Fold 41:
#   mse: 10087.9462890625
#   PiggyCast: area weighted rmse: 88.70035091854724
#   graphcast: area weighted rmse: 109.6501120997446
#   pangu: area weighted rmse: 112.27630628058601
#   neuralgcm: area weighted rmse: 92.32765526639002
#   ifshres: area weighted rmse: 123.33733439308548
# Fold 42:
#   mse: 12886.3388671875
#   PiggyCast: area weighted rmse: 97.54927772349046
#   graphcast: area weighted rmse: 123.59993196361212
#   pangu: area weighted rmse: 140.44633350512558
#   neuralgcm: area weighted rmse: 103.90301052046142
#   ifshres: area weighted rmse: 126.32376452738023
# Fold 43:
#   mse: 9704.701171875
#   PiggyCast: area weighted rmse: 82.43454455193786
#   graphcast: area weighted rmse: 126.05817310680972
#   pangu: area weighted rmse: 130.2501806359575
#   neuralgcm: area weighted rmse: 92.44149792886678
#   ifshres: area weighted rmse: 105.7291348796898
# Fold 44:
#   mse: 11222.169921875
#   PiggyCast: area weighted rmse: 87.82708362433341
#   graphcast: area weighted rmse: 126.5380007464147
#   pangu: area weighted rmse: 120.41466272184006
#   neuralgcm: area weighted rmse: 95.33640699763652
#   ifshres: area weighted rmse: 115.90192427240216
# Fold 45:
#   mse: 9034.7001953125
#   PiggyCast: area weighted rmse: 78.7049558404683
#   graphcast: area weighted rmse: 103.75425818411006
#   pangu: area weighted rmse: 115.63517847892646
#   neuralgcm: area weighted rmse: 88.0468679176748
#   ifshres: area weighted rmse: 115.09638255071818
# Fold 46:
#   mse: 10511.439453125
#   PiggyCast: area weighted rmse: 85.86121013273456
#   graphcast: area weighted rmse: 109.28996232537177
#   pangu: area weighted rmse: 114.3119369898936
#   neuralgcm: area weighted rmse: 93.43756292342795
#   ifshres: area weighted rmse: 114.41057055716405
# Fold 47:
#   mse: 11210.6591796875
#   PiggyCast: area weighted rmse: 91.5953016940995
#   graphcast: area weighted rmse: 125.45500398526008
#   pangu: area weighted rmse: 127.40766765615155
#   neuralgcm: area weighted rmse: 89.46045084011229
#   ifshres: area weighted rmse: 122.49147773858215
# Fold 48:
#   mse: 12529.791015625
#   PiggyCast: area weighted rmse: 88.24567277477321
#   graphcast: area weighted rmse: 118.38120338680854
#   pangu: area weighted rmse: 118.25145252115341
#   neuralgcm: area weighted rmse: 96.13822025753028
#   ifshres: area weighted rmse: 114.94081708377955
# Fold 49:
#   mse: 13139.564453125
#   PiggyCast: area weighted rmse: 92.37427384362505
#   graphcast: area weighted rmse: 108.98555571842671
#   pangu: area weighted rmse: 124.8423392091476
#   neuralgcm: area weighted rmse: 101.97478686181965
#   ifshres: area weighted rmse: 125.8089967587865
# Fold 50:
#   mse: 10411.3544921875
#   PiggyCast: area weighted rmse: 90.1555459276425
#   graphcast: area weighted rmse: 103.16310083731472
#   pangu: area weighted rmse: 124.43941923168764
#   neuralgcm: area weighted rmse: 99.67586195102744
#   ifshres: area weighted rmse: 117.74454602548956
# {48: {'PiggyCast': 53.03694621942815,
#       'graphcast': 66.84430781450041,
#       'ifshres': 72.4432374143341,
#       'neuralgcm': 58.10042924859443,
#       'pangu': 72.28982916835817},
#  72: {'PiggyCast': 89.4396219230353,
#       'graphcast': 109.19664431513249,
#       'ifshres': 118.02268477818927,
#       'neuralgcm': 97.9078312509262,
#       'pangu': 117.98457277474706}}

# %%
# @title Training and Evaluation Loop- Time series split : 60 Days Training, 3 Day Gap and  7 Days Testing

# Initialize xgb regressor
xgb = xgboost.XGBRegressor(random_state=42, device="cuda")

# Calculate Cross-Validation using 10 folds
cv_timeseries = TimeSeriesSplit(n_splits=50, max_train_size=32 * 64 * 2 * 60,
                                test_size= 32 * 64 * 2 * 7, gap=32 * 64 * 2 * 3)

# Lead Times
lead_times=[48, 72]

nested_scores = {} # Nested scores for each lead time
rmse_results = {} # rmse results for each lead time, models

for lead_time in lead_times:
  print(f"======Lead time: {lead_time}========")

  df_filtered = data_per_lead_time(full_df,lead_time)

  X = df_filtered[[f"graphcast_lt{lead_time}", f"pangu_lt{lead_time}",
                   f"neuralgcm_lt{lead_time}",
                  #  f"keisler_lt{lead_time}",
                   f"ifshres_lt{lead_time}", "longitude", "latitude"]]
  y = df_filtered["era5"]
  area_weight = df_filtered["area_weight"]

  print(f"Shape of x :{X.shape}")
  print(f"Shape of y : {y.shape}")

  # Nested Scores
  nested_score = cross_validate(xgb, X=X, y=y, cv=cv_timeseries,
                              scoring=('neg_mean_squared_error', 'r2'),
                              params={'sample_weight': area_weight}
                              )
  nested_scores[lead_time] = nested_score

  # Cross validation plot
  cross_validation_plot(df_filtered, cv_timeseries, lead_time)

  # RMSE
  rmse_result = train_and_evaluate(xgb, cv_timeseries,X,y, area_weight, lead_time)
  rmse_results[lead_time] = rmse_result

  # RMSE plots per model
  rmse_per_fold_plot(rmse_result, lead_time)

  # print nicely average RMSE per Leadtime
  average_scores = rmse_mean_per_lead_time_and_model(rmse_results)
  pprint(average_scores)
# Out:
# ======Lead time: 48========
# Shape of x :(1497088, 6)
# Shape of y : (1497088,)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [04:13:37] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# Train times Min Date: 2020-01-03 12:00:00 Train times Max Date:2020-01-15 12:00:00
# Test times Min Date: 2020-01-19 00:00:00 Test times Max Date:2020-01-25 12:00:00
# Train times Min Date: 2020-01-03 12:00:00 Train times Max Date:2020-01-22 12:00:00
# Test times Min Date: 2020-01-26 00:00:00 Test times Max Date:2020-02-01 12:00:00
# Train times Min Date: 2020-01-03 12:00:00 Train times Max Date:2020-01-29 12:00:00
# Test times Min Date: 2020-02-02 00:00:00 Test times Max Date:2020-02-08 12:00:00
# Train times Min Date: 2020-01-03 12:00:00 Train times Max Date:2020-02-05 12:00:00
# Test times Min Date: 2020-02-09 00:00:00 Test times Max Date:2020-02-15 12:00:00
# Train times Min Date: 2020-01-03 12:00:00 Train times Max Date:2020-02-12 12:00:00
# Test times Min Date: 2020-02-16 00:00:00 Test times Max Date:2020-02-22 12:00:00
# Train times Min Date: 2020-01-03 12:00:00 Train times Max Date:2020-02-19 12:00:00
# Test times Min Date: 2020-02-23 00:00:00 Test times Max Date:2020-02-29 12:00:00
# Train times Min Date: 2020-01-03 12:00:00 Train times Max Date:2020-02-26 12:00:00
# Test times Min Date: 2020-03-01 00:00:00 Test times Max Date:2020-03-07 12:00:00
# Train times Min Date: 2020-01-05 00:00:00 Train times Max Date:2020-03-04 12:00:00
# Test times Min Date: 2020-03-08 00:00:00 Test times Max Date:2020-03-14 12:00:00
# Train times Min Date: 2020-01-12 00:00:00 Train times Max Date:2020-03-11 12:00:00
# Test times Min Date: 2020-03-15 00:00:00 Test times Max Date:2020-03-21 12:00:00
# Train times Min Date: 2020-01-19 00:00:00 Train times Max Date:2020-03-18 12:00:00
# Test times Min Date: 2020-03-22 00:00:00 Test times Max Date:2020-03-28 12:00:00
# Fold 1:
#   mse: 5410.84130859375
#   PiggyCast: area weighted rmse: 60.47860613298887
#   graphcast: area weighted rmse: 66.20678638148297
#   pangu: area weighted rmse: 73.25187701683323
#   neuralgcm: area weighted rmse: 57.064416422694435
#   ifshres: area weighted rmse: 73.25612433115195
# Fold 2:
#   mse: 6655.94091796875
#   PiggyCast: area weighted rmse: 56.71209859961531
#   graphcast: area weighted rmse: 67.18696932095679
#   pangu: area weighted rmse: 75.6866919914812
#   neuralgcm: area weighted rmse: 56.083009122549115
#   ifshres: area weighted rmse: 76.64914821516122
# Fold 3:
#   mse: 7962.8212890625
#   PiggyCast: area weighted rmse: 61.35252082679142
#   graphcast: area weighted rmse: 72.90208568609224
#   pangu: area weighted rmse: 78.45860350690234
#   neuralgcm: area weighted rmse: 60.02047684968904
#   ifshres: area weighted rmse: 77.68003396303061
# Fold 4:
#   mse: 6079.57666015625
#   PiggyCast: area weighted rmse: 63.95967002516803
#   graphcast: area weighted rmse: 74.00325104166043
#   pangu: area weighted rmse: 79.42324814192085
#   neuralgcm: area weighted rmse: 60.66258868925265
#   ifshres: area weighted rmse: 81.2281537919591
# Fold 5:
#   mse: 6096.8564453125
#   PiggyCast: area weighted rmse: 57.02777691347635
#   graphcast: area weighted rmse: 64.39919174371511
#   pangu: area weighted rmse: 74.550773387076
#   neuralgcm: area weighted rmse: 56.89447718310362
#   ifshres: area weighted rmse: 76.5106855304369
# Fold 6:
#   mse: 5369.83349609375
#   PiggyCast: area weighted rmse: 56.768163161950504
#   graphcast: area weighted rmse: 66.21749042118111
#   pangu: area weighted rmse: 76.55772127750818
#   neuralgcm: area weighted rmse: 59.068154463257386
#   ifshres: area weighted rmse: 77.6373230342622
# Fold 7:
#   mse: 8853.9833984375
#   PiggyCast: area weighted rmse: 63.62617564799933
#   graphcast: area weighted rmse: 69.39007363666185
#   pangu: area weighted rmse: 79.3285971637632
#   neuralgcm: area weighted rmse: 60.56658376450028
#   ifshres: area weighted rmse: 75.67671543598414
# Fold 8:
#   mse: 18941.763671875
#   PiggyCast: area weighted rmse: 74.81082048605397
#   graphcast: area weighted rmse: 67.14454393580866
#   pangu: area weighted rmse: 71.83729600602409
#   neuralgcm: area weighted rmse: 58.33544530858417
#   ifshres: area weighted rmse: 76.89570426870856
# Fold 9:
#   mse: 20294.49609375
#   PiggyCast: area weighted rmse: 87.16915436284604
#   graphcast: area weighted rmse: 73.84589682417504
#   pangu: area weighted rmse: 86.22700254478103
#   neuralgcm: area weighted rmse: 62.36404144190721
#   ifshres: area weighted rmse: 78.9632666853088
# Fold 10:
#   mse: 13261.3681640625
#   PiggyCast: area weighted rmse: 72.33554065926415
#   graphcast: area weighted rmse: 74.57735971577287
#   pangu: area weighted rmse: 83.01794047581258
#   neuralgcm: area weighted rmse: 59.4057025517564
#   ifshres: area weighted rmse: 77.52018809321092
# Fold 11:
#   mse: 5606.36572265625
#   PiggyCast: area weighted rmse: 61.043042802572316
#   graphcast: area weighted rmse: 74.67653030843756
#   pangu: area weighted rmse: 83.32490198780404
#   neuralgcm: area weighted rmse: 62.8803577283202
#   ifshres: area weighted rmse: 78.66876997832419
# Fold 12:
#   mse: 5634.30419921875
#   PiggyCast: area weighted rmse: 61.089430285487296
#   graphcast: area weighted rmse: 71.83526751159391
#   pangu: area weighted rmse: 77.88217343269964
#   neuralgcm: area weighted rmse: 64.14224874288915
#   ifshres: area weighted rmse: 76.49786523200481
# Fold 13:
#   mse: 11903.3193359375
#   PiggyCast: area weighted rmse: 71.0462682731381
#   graphcast: area weighted rmse: 73.6557404852364
#   pangu: area weighted rmse: 83.8644184535021
#   neuralgcm: area weighted rmse: 62.670121019744016
#   ifshres: area weighted rmse: 78.97718889180375
# Fold 14:
#   mse: 12055.5166015625
#   PiggyCast: area weighted rmse: 72.1174039189111
#   graphcast: area weighted rmse: 71.65757162468037
#   pangu: area weighted rmse: 79.63440167298405
#   neuralgcm: area weighted rmse: 59.12695242375497
#   ifshres: area weighted rmse: 73.9211740300101
# Fold 15:
#   mse: 5545.4736328125
#   PiggyCast: area weighted rmse: 58.924855173164715
#   graphcast: area weighted rmse: 69.13347368206266
#   pangu: area weighted rmse: 82.93100669482133
#   neuralgcm: area weighted rmse: 63.16794988251347
#   ifshres: area weighted rmse: 77.45780940736174
# Fold 16:
#   mse: 5638.1748046875
#   PiggyCast: area weighted rmse: 59.28020948646604
#   graphcast: area weighted rmse: 69.9690885418903
#   pangu: area weighted rmse: 74.6384921411598
#   neuralgcm: area weighted rmse: 61.9300213491186
#   ifshres: area weighted rmse: 74.64869910788599
# Fold 17:
#   mse: 5621.8447265625
#   PiggyCast: area weighted rmse: 58.77287041787751
#   graphcast: area weighted rmse: 70.70354190987261
#   pangu: area weighted rmse: 79.99265554672299
#   neuralgcm: area weighted rmse: 62.34462373331609
#   ifshres: area weighted rmse: 76.85539054112753
# Fold 18:
#   mse: 7154.64013671875
#   PiggyCast: area weighted rmse: 63.96256166762489
#   graphcast: area weighted rmse: 69.801140060063
#   pangu: area weighted rmse: 72.84180108939732
#   neuralgcm: area weighted rmse: 60.950612942022325
#   ifshres: area weighted rmse: 78.50999438389537
# Fold 19:
#   mse: 8755.771484375
#   PiggyCast: area weighted rmse: 69.91068795814176
#   graphcast: area weighted rmse: 70.93848149714479
#   pangu: area weighted rmse: 73.11501889950199
#   neuralgcm: area weighted rmse: 62.382405816170085
#   ifshres: area weighted rmse: 73.5842224992343
# Fold 20:
#   mse: 7366.9384765625
#   PiggyCast: area weighted rmse: 66.10304029529489
#   graphcast: area weighted rmse: 70.37276347476993
#   pangu: area weighted rmse: 72.66778894321779
#   neuralgcm: area weighted rmse: 60.29145593301373
#   ifshres: area weighted rmse: 71.45096959311739
# Fold 21:
#   mse: 7892.94677734375
#   PiggyCast: area weighted rmse: 67.14693590578594
#   graphcast: area weighted rmse: 67.87084438206156
#   pangu: area weighted rmse: 75.82972734591169
#   neuralgcm: area weighted rmse: 63.850793438019295
#   ifshres: area weighted rmse: 73.56494555336853
# Fold 22:
#   mse: 13695.3642578125
#   PiggyCast: area weighted rmse: 79.02405651487189
#   graphcast: area weighted rmse: 69.96457479497236
#   pangu: area weighted rmse: 78.35104898053655
#   neuralgcm: area weighted rmse: 62.77019063220203
#   ifshres: area weighted rmse: 75.35843385438864
# Fold 23:
#   mse: 11645.708984375
#   PiggyCast: area weighted rmse: 77.02406968876612
#   graphcast: area weighted rmse: 64.99853581395674
#   pangu: area weighted rmse: 75.87361278251751
#   neuralgcm: area weighted rmse: 60.4826236036958
#   ifshres: area weighted rmse: 71.21952544826665
# Fold 24:
#   mse: 5815.05322265625
#   PiggyCast: area weighted rmse: 58.866633693395585
#   graphcast: area weighted rmse: 69.19483515204078
#   pangu: area weighted rmse: 74.02332772354171
#   neuralgcm: area weighted rmse: 62.38177233513841
#   ifshres: area weighted rmse: 72.20352232983973
# Fold 25:
#   mse: 5219.23828125
#   PiggyCast: area weighted rmse: 59.51548309385238
#   graphcast: area weighted rmse: 68.5353006728276
#   pangu: area weighted rmse: 75.39832100896746
#   neuralgcm: area weighted rmse: 62.83394925930707
#   ifshres: area weighted rmse: 75.96904069322166
# Fold 26:
#   mse: 6174.64453125
#   PiggyCast: area weighted rmse: 60.9067348414109
#   graphcast: area weighted rmse: 72.00892284133367
#   pangu: area weighted rmse: 81.95555590338212
#   neuralgcm: area weighted rmse: 62.02951174836391
#   ifshres: area weighted rmse: 75.201942951334
# Fold 27:
#   mse: 7496.5517578125
#   PiggyCast: area weighted rmse: 64.03436315633553
#   graphcast: area weighted rmse: 66.67685582150068
#   pangu: area weighted rmse: 74.27483395153533
#   neuralgcm: area weighted rmse: 64.83312295543841
#   ifshres: area weighted rmse: 68.96418969773106
# Fold 28:
#   mse: 6897.90966796875
#   PiggyCast: area weighted rmse: 61.961128626524555
#   graphcast: area weighted rmse: 70.0072732558609
#   pangu: area weighted rmse: 72.54856571469618
#   neuralgcm: area weighted rmse: 60.95674700645925
#   ifshres: area weighted rmse: 71.46290430525787
# Fold 29:
#   mse: 12283.072265625
#   PiggyCast: area weighted rmse: 79.56872214460493
#   graphcast: area weighted rmse: 71.07734698341558
#   pangu: area weighted rmse: 76.21010420955628
#   neuralgcm: area weighted rmse: 61.0847538620234
#   ifshres: area weighted rmse: 73.39909676804561
# Fold 30:
#   mse: 5841.17236328125
#   PiggyCast: area weighted rmse: 58.86909720324773
#   graphcast: area weighted rmse: 69.40014789550864
#   pangu: area weighted rmse: 75.32707760813076
#   neuralgcm: area weighted rmse: 60.73944594014233
#   ifshres: area weighted rmse: 77.29124069818009
# Fold 31:
#   mse: 5644.5537109375
#   PiggyCast: area weighted rmse: 59.5336975964907
#   graphcast: area weighted rmse: 72.33931986675769
#   pangu: area weighted rmse: 77.87893775149341
#   neuralgcm: area weighted rmse: 61.04935534171192
#   ifshres: area weighted rmse: 75.61407151005736
# Fold 32:
#   mse: 7196.5390625
#   PiggyCast: area weighted rmse: 61.678904778696875
#   graphcast: area weighted rmse: 68.5957997996403
#   pangu: area weighted rmse: 77.40595815742452
#   neuralgcm: area weighted rmse: 62.08836726530366
#   ifshres: area weighted rmse: 73.65544636939208
# Fold 33:
#   mse: 6152.8134765625
#   PiggyCast: area weighted rmse: 62.07510213467268
#   graphcast: area weighted rmse: 72.8556992696679
#   pangu: area weighted rmse: 84.77304744939102
#   neuralgcm: area weighted rmse: 64.08373500029234
#   ifshres: area weighted rmse: 77.8242085682596
# Fold 34:
#   mse: 5245.4560546875
#   PiggyCast: area weighted rmse: 55.47862501204999
#   graphcast: area weighted rmse: 66.37963259691732
#   pangu: area weighted rmse: 72.51466440005107
#   neuralgcm: area weighted rmse: 58.00275911482397
#   ifshres: area weighted rmse: 72.31309205465031
# Fold 35:
#   mse: 5948.59326171875
#   PiggyCast: area weighted rmse: 60.70777871813926
#   graphcast: area weighted rmse: 70.69860478526155
#   pangu: area weighted rmse: 71.72694958035213
#   neuralgcm: area weighted rmse: 59.45657124159923
#   ifshres: area weighted rmse: 75.87354276251459
# Fold 36:
#   mse: 5272.44189453125
#   PiggyCast: area weighted rmse: 55.93129424696722
#   graphcast: area weighted rmse: 65.47352228127664
#   pangu: area weighted rmse: 70.17750818663806
#   neuralgcm: area weighted rmse: 58.83197512546123
#   ifshres: area weighted rmse: 72.09323046573591
# Fold 37:
#   mse: 4961.04248046875
#   PiggyCast: area weighted rmse: 57.198299627370766
#   graphcast: area weighted rmse: 74.05762331279371
#   pangu: area weighted rmse: 76.90927013582306
#   neuralgcm: area weighted rmse: 60.08053516517397
#   ifshres: area weighted rmse: 76.35570081909316
# Fold 38:
#   mse: 5345.70751953125
#   PiggyCast: area weighted rmse: 59.77750108540626
#   graphcast: area weighted rmse: 71.24031120549722
#   pangu: area weighted rmse: 72.4471492017786
#   neuralgcm: area weighted rmse: 60.392784154856805
#   ifshres: area weighted rmse: 72.55926252608074
# Fold 39:
#   mse: 6167.6650390625
#   PiggyCast: area weighted rmse: 59.71812735894705
#   graphcast: area weighted rmse: 66.89244327961339
#   pangu: area weighted rmse: 72.81660931411295
#   neuralgcm: area weighted rmse: 61.10431596120065
#   ifshres: area weighted rmse: 72.33080963318145
# Fold 40:
#   mse: 8935.388671875
#   PiggyCast: area weighted rmse: 63.66976970365141
#   graphcast: area weighted rmse: 68.68091791740216
#   pangu: area weighted rmse: 67.7130888407223
#   neuralgcm: area weighted rmse: 55.310433451113845
#   ifshres: area weighted rmse: 68.30274269904606
# Fold 41:
#   mse: 5346.53125
#   PiggyCast: area weighted rmse: 59.90978834575415
#   graphcast: area weighted rmse: 71.09379610324787
#   pangu: area weighted rmse: 74.42250253820265
#   neuralgcm: area weighted rmse: 62.01012456862443
#   ifshres: area weighted rmse: 73.77957242034078
# Fold 42:
#   mse: 6751.8193359375
#   PiggyCast: area weighted rmse: 60.26227119871414
#   graphcast: area weighted rmse: 69.20294994490088
#   pangu: area weighted rmse: 73.46758766756066
#   neuralgcm: area weighted rmse: 59.29053991895373
#   ifshres: area weighted rmse: 72.9105621052856
# Fold 43:
#   mse: 5503.38818359375
#   PiggyCast: area weighted rmse: 58.48708910773459
#   graphcast: area weighted rmse: 68.9896795914389
#   pangu: area weighted rmse: 73.98051472441293
#   neuralgcm: area weighted rmse: 60.66810804473785
#   ifshres: area weighted rmse: 71.16892890696909
# Fold 44:
#   mse: 4441.0615234375
#   PiggyCast: area weighted rmse: 54.24040236273507
#   graphcast: area weighted rmse: 67.21512881495151
#   pangu: area weighted rmse: 75.55058586019881
#   neuralgcm: area weighted rmse: 58.458152614537255
#   ifshres: area weighted rmse: 73.80552419219231
# Fold 45:
#   mse: 4163.49267578125
#   PiggyCast: area weighted rmse: 54.4927159173514
#   graphcast: area weighted rmse: 64.68925791328384
#   pangu: area weighted rmse: 71.46294228145602
#   neuralgcm: area weighted rmse: 60.18565177784519
#   ifshres: area weighted rmse: 72.43567308940683
# Fold 46:
#   mse: 4155.4306640625
#   PiggyCast: area weighted rmse: 54.49455846978901
#   graphcast: area weighted rmse: 66.6184147384827
#   pangu: area weighted rmse: 74.4584094935832
#   neuralgcm: area weighted rmse: 59.351481672655254
#   ifshres: area weighted rmse: 74.7755603244467
# Fold 47:
#   mse: 4171.96630859375
#   PiggyCast: area weighted rmse: 54.791094883215344
#   graphcast: area weighted rmse: 67.40431472625734
#   pangu: area weighted rmse: 73.60452652691663
#   neuralgcm: area weighted rmse: 58.71159922714324
#   ifshres: area weighted rmse: 74.66322955396006
# Fold 48:
#   mse: 3732.126708984375
#   PiggyCast: area weighted rmse: 51.69649184620315
#   graphcast: area weighted rmse: 65.46444935617437
#   pangu: area weighted rmse: 67.03228472712844
#   neuralgcm: area weighted rmse: 57.11274302766549
#   ifshres: area weighted rmse: 67.5595511750235
# Fold 49:
#   mse: 3612.84619140625
#   PiggyCast: area weighted rmse: 50.849154018143764
#   graphcast: area weighted rmse: 64.373500470157
#   pangu: area weighted rmse: 69.29924373138155
#   neuralgcm: area weighted rmse: 56.37334939468531
#   ifshres: area weighted rmse: 70.34009527447243
# Fold 50:
#   mse: 4116.8505859375
#   PiggyCast: area weighted rmse: 52.556624849254014
#   graphcast: area weighted rmse: 72.66075832449428
#   pangu: area weighted rmse: 74.77157159239104
#   neuralgcm: area weighted rmse: 56.697786393053036
#   ifshres: area weighted rmse: 73.85641840021128
# {48: {'PiggyCast': 62.21914826449831,
#       'graphcast': 69.46556019429909,
#       'ifshres': 74.58882984327866,
#       'neuralgcm': 60.4314984922077,
#       'pangu': 75.82875875527417}}
# ======Lead time: 72========
# Shape of x :(1497088, 6)
# Shape of y : (1497088,)
# Train times Min Date: 2020-01-04 12:00:00 Train times Max Date:2020-01-16 12:00:00
# Test times Min Date: 2020-01-20 00:00:00 Test times Max Date:2020-01-26 12:00:00
# Train times Min Date: 2020-01-04 12:00:00 Train times Max Date:2020-01-23 12:00:00
# Test times Min Date: 2020-01-27 00:00:00 Test times Max Date:2020-02-02 12:00:00
# Train times Min Date: 2020-01-04 12:00:00 Train times Max Date:2020-01-30 12:00:00
# Test times Min Date: 2020-02-03 00:00:00 Test times Max Date:2020-02-09 12:00:00
# Train times Min Date: 2020-01-04 12:00:00 Train times Max Date:2020-02-06 12:00:00
# Test times Min Date: 2020-02-10 00:00:00 Test times Max Date:2020-02-16 12:00:00
# Train times Min Date: 2020-01-04 12:00:00 Train times Max Date:2020-02-13 12:00:00
# Test times Min Date: 2020-02-17 00:00:00 Test times Max Date:2020-02-23 12:00:00
# Train times Min Date: 2020-01-04 12:00:00 Train times Max Date:2020-02-20 12:00:00
# Test times Min Date: 2020-02-24 00:00:00 Test times Max Date:2020-03-01 12:00:00
# Train times Min Date: 2020-01-04 12:00:00 Train times Max Date:2020-02-27 12:00:00
# Test times Min Date: 2020-03-02 00:00:00 Test times Max Date:2020-03-08 12:00:00
# Train times Min Date: 2020-01-06 00:00:00 Train times Max Date:2020-03-05 12:00:00
# Test times Min Date: 2020-03-09 00:00:00 Test times Max Date:2020-03-15 12:00:00
# Train times Min Date: 2020-01-13 00:00:00 Train times Max Date:2020-03-12 12:00:00
# Test times Min Date: 2020-03-16 00:00:00 Test times Max Date:2020-03-22 12:00:00
# Train times Min Date: 2020-01-20 00:00:00 Train times Max Date:2020-03-19 12:00:00
# Test times Min Date: 2020-03-23 00:00:00 Test times Max Date:2020-03-29 12:00:00
# Fold 1:
#   mse: 13093.9765625
#   PiggyCast: area weighted rmse: 96.8329200482463
#   graphcast: area weighted rmse: 112.36481517508207
#   pangu: area weighted rmse: 119.76187380838239
#   neuralgcm: area weighted rmse: 97.68319606121942
#   ifshres: area weighted rmse: 118.25210902630512
# Fold 2:
#   mse: 15869.9189453125
#   PiggyCast: area weighted rmse: 94.70867977929811
#   graphcast: area weighted rmse: 110.70637183928743
#   pangu: area weighted rmse: 124.28262076397449
#   neuralgcm: area weighted rmse: 97.10167278518675
#   ifshres: area weighted rmse: 118.81238470397493
# Fold 3:
#   mse: 15190.1884765625
#   PiggyCast: area weighted rmse: 99.13470408326185
#   graphcast: area weighted rmse: 121.9414270569667
#   pangu: area weighted rmse: 130.6952533994007
#   neuralgcm: area weighted rmse: 104.8456933216301
#   ifshres: area weighted rmse: 126.06484559304855
# Fold 4:
#   mse: 14930.7607421875
#   PiggyCast: area weighted rmse: 98.43156512218657
#   graphcast: area weighted rmse: 119.86029705088232
#   pangu: area weighted rmse: 122.80342738313325
#   neuralgcm: area weighted rmse: 100.84632523012215
#   ifshres: area weighted rmse: 126.5470260470347
# Fold 5:
#   mse: 13286.201171875
#   PiggyCast: area weighted rmse: 90.70847265483988
#   graphcast: area weighted rmse: 103.71146566101426
#   pangu: area weighted rmse: 117.06457755364866
#   neuralgcm: area weighted rmse: 95.59215076953633
#   ifshres: area weighted rmse: 119.808998399036
# Fold 6:
#   mse: 14060.8896484375
#   PiggyCast: area weighted rmse: 96.38786213514204
#   graphcast: area weighted rmse: 109.34396764402956
#   pangu: area weighted rmse: 121.81283282333439
#   neuralgcm: area weighted rmse: 101.74969115954897
#   ifshres: area weighted rmse: 130.25296096910418
# Fold 7:
#   mse: 20995.73046875
#   PiggyCast: area weighted rmse: 106.42894891904764
#   graphcast: area weighted rmse: 115.69170831091617
#   pangu: area weighted rmse: 134.9170666334175
#   neuralgcm: area weighted rmse: 104.86028537480225
#   ifshres: area weighted rmse: 124.41708494515164
# Fold 8:
#   mse: 27283.841796875
#   PiggyCast: area weighted rmse: 106.09823331227541
#   graphcast: area weighted rmse: 109.28335859289622
#   pangu: area weighted rmse: 116.0473108903989
#   neuralgcm: area weighted rmse: 101.70408989337751
#   ifshres: area weighted rmse: 128.93048856694742
# Fold 9:
#   mse: 28403.857421875
#   PiggyCast: area weighted rmse: 116.49329343451707
#   graphcast: area weighted rmse: 123.72162956952872
#   pangu: area weighted rmse: 138.5308401312618
#   neuralgcm: area weighted rmse: 106.98571820725081
#   ifshres: area weighted rmse: 134.2504270354584
# Fold 10:
#   mse: 19173.12109375
#   PiggyCast: area weighted rmse: 105.1582973355097
#   graphcast: area weighted rmse: 128.70762876350125
#   pangu: area weighted rmse: 139.99550497910354
#   neuralgcm: area weighted rmse: 104.5546149741894
#   ifshres: area weighted rmse: 132.89228511181008
# Fold 11:
#   mse: 16330.0693359375
#   PiggyCast: area weighted rmse: 105.75247198017216
#   graphcast: area weighted rmse: 125.79245110207782
#   pangu: area weighted rmse: 139.45471597983672
#   neuralgcm: area weighted rmse: 114.2353744252658
#   ifshres: area weighted rmse: 132.1995121650541
# Fold 12:
#   mse: 17854.63671875
#   PiggyCast: area weighted rmse: 110.49339261464324
#   graphcast: area weighted rmse: 122.67443764358275
#   pangu: area weighted rmse: 137.0718024914255
#   neuralgcm: area weighted rmse: 122.5916191760077
#   ifshres: area weighted rmse: 128.17075072308245
# Fold 13:
#   mse: 25204.509765625
#   PiggyCast: area weighted rmse: 109.82198841283375
#   graphcast: area weighted rmse: 123.52625108076855
#   pangu: area weighted rmse: 141.38661055312159
#   neuralgcm: area weighted rmse: 106.31595371720535
#   ifshres: area weighted rmse: 134.2915300289041
# Fold 14:
#   mse: 22785.017578125
#   PiggyCast: area weighted rmse: 107.80703618831329
#   graphcast: area weighted rmse: 125.72421553654699
#   pangu: area weighted rmse: 131.88809360984612
#   neuralgcm: area weighted rmse: 104.04201304432392
#   ifshres: area weighted rmse: 128.35592156081873
# Fold 15:
#   mse: 17566.015625
#   PiggyCast: area weighted rmse: 104.24671715840736
#   graphcast: area weighted rmse: 121.80003487606226
#   pangu: area weighted rmse: 140.87449483826808
#   neuralgcm: area weighted rmse: 114.0155340768967
#   ifshres: area weighted rmse: 132.38074201673928
# Fold 16:
#   mse: 15394.5888671875
#   PiggyCast: area weighted rmse: 101.86184776317415
#   graphcast: area weighted rmse: 116.54607628539252
#   pangu: area weighted rmse: 121.1729064255376
#   neuralgcm: area weighted rmse: 111.2418472622752
#   ifshres: area weighted rmse: 128.74187124594812
# Fold 17:
#   mse: 16414.81640625
#   PiggyCast: area weighted rmse: 100.86557279208213
#   graphcast: area weighted rmse: 116.57611366232696
#   pangu: area weighted rmse: 136.7779047161893
#   neuralgcm: area weighted rmse: 108.98960118751178
#   ifshres: area weighted rmse: 130.11109100485052
# Fold 18:
#   mse: 18156.29296875
#   PiggyCast: area weighted rmse: 103.6270607366269
#   graphcast: area weighted rmse: 116.11441690279031
#   pangu: area weighted rmse: 122.16377086867567
#   neuralgcm: area weighted rmse: 103.80297163142751
#   ifshres: area weighted rmse: 133.71995966480404
# Fold 19:
#   mse: 16389.91796875
#   PiggyCast: area weighted rmse: 102.56339341927513
#   graphcast: area weighted rmse: 113.07630334503892
#   pangu: area weighted rmse: 122.6866422181686
#   neuralgcm: area weighted rmse: 108.01553929490059
#   ifshres: area weighted rmse: 122.8383967860079
# Fold 20:
#   mse: 15864.0185546875
#   PiggyCast: area weighted rmse: 98.47947170570954
#   graphcast: area weighted rmse: 111.5705213782873
#   pangu: area weighted rmse: 114.93573369198597
#   neuralgcm: area weighted rmse: 102.08373743662277
#   ifshres: area weighted rmse: 119.13443368977276
# Fold 21:
#   mse: 19998.349609375
#   PiggyCast: area weighted rmse: 110.33185497886105
#   graphcast: area weighted rmse: 118.21192784799125
#   pangu: area weighted rmse: 130.3116578111673
#   neuralgcm: area weighted rmse: 115.23427444592495
#   ifshres: area weighted rmse: 129.15479577283205
# Fold 22:
#   mse: 27381.037109375
#   PiggyCast: area weighted rmse: 119.96719315434572
#   graphcast: area weighted rmse: 114.98731055877613
#   pangu: area weighted rmse: 133.0073991301169
#   neuralgcm: area weighted rmse: 111.90953081965665
#   ifshres: area weighted rmse: 127.21997752201743
# Fold 23:
#   mse: 19098.349609375
#   PiggyCast: area weighted rmse: 101.57236035976639
#   graphcast: area weighted rmse: 107.59253176918278
#   pangu: area weighted rmse: 128.78784930894622
#   neuralgcm: area weighted rmse: 104.18905010303803
#   ifshres: area weighted rmse: 122.0392964773036
# Fold 24:
#   mse: 17382.87890625
#   PiggyCast: area weighted rmse: 101.42761486414518
#   graphcast: area weighted rmse: 114.1448894680766
#   pangu: area weighted rmse: 123.68076088973665
#   neuralgcm: area weighted rmse: 112.20099144547675
#   ifshres: area weighted rmse: 122.0873693213987
# Fold 25:
#   mse: 17006.06640625
#   PiggyCast: area weighted rmse: 102.35473128345419
#   graphcast: area weighted rmse: 118.83753851420217
#   pangu: area weighted rmse: 132.10135833049208
#   neuralgcm: area weighted rmse: 109.78698139963913
#   ifshres: area weighted rmse: 127.50700676729956
# Fold 26:
#   mse: 15297.1806640625
#   PiggyCast: area weighted rmse: 98.09148275448457
#   graphcast: area weighted rmse: 112.71629949007901
#   pangu: area weighted rmse: 127.76554362622215
#   neuralgcm: area weighted rmse: 104.05580735404818
#   ifshres: area weighted rmse: 123.29093071663216
# Fold 27:
#   mse: 19466.658203125
#   PiggyCast: area weighted rmse: 103.83320173366043
#   graphcast: area weighted rmse: 113.70186428261262
#   pangu: area weighted rmse: 124.46780116557848
#   neuralgcm: area weighted rmse: 114.65361803350822
#   ifshres: area weighted rmse: 120.8363379681734
# Fold 28:
#   mse: 17647.97265625
#   PiggyCast: area weighted rmse: 101.13799535191433
#   graphcast: area weighted rmse: 118.77773966055393
#   pangu: area weighted rmse: 120.42212916093203
#   neuralgcm: area weighted rmse: 104.4374402743696
#   ifshres: area weighted rmse: 120.97852432337453
# Fold 29:
#   mse: 21033.013671875
#   PiggyCast: area weighted rmse: 108.9864280926171
#   graphcast: area weighted rmse: 116.89497340530667
#   pangu: area weighted rmse: 123.56985805731298
#   neuralgcm: area weighted rmse: 105.05041448402916
#   ifshres: area weighted rmse: 123.6415960150693
# Fold 30:
#   mse: 16138.8525390625
#   PiggyCast: area weighted rmse: 97.49878110628403
#   graphcast: area weighted rmse: 116.12467946126449
#   pangu: area weighted rmse: 128.1156233958429
#   neuralgcm: area weighted rmse: 101.0872294170439
#   ifshres: area weighted rmse: 128.9737956163738
# Fold 31:
#   mse: 16604.033203125
#   PiggyCast: area weighted rmse: 98.90814514976151
#   graphcast: area weighted rmse: 115.46927854108515
#   pangu: area weighted rmse: 128.41727780223326
#   neuralgcm: area weighted rmse: 100.49181894672415
#   ifshres: area weighted rmse: 123.32911472009228
# Fold 32:
#   mse: 17528.046875
#   PiggyCast: area weighted rmse: 96.17847138563438
#   graphcast: area weighted rmse: 113.20362528078877
#   pangu: area weighted rmse: 127.18449132441775
#   neuralgcm: area weighted rmse: 101.6048589534745
#   ifshres: area weighted rmse: 122.97208904083034
# Fold 33:
#   mse: 19619.771484375
#   PiggyCast: area weighted rmse: 107.68922568432353
#   graphcast: area weighted rmse: 120.53657914786027
#   pangu: area weighted rmse: 144.10822715102773
#   neuralgcm: area weighted rmse: 110.94334005100127
#   ifshres: area weighted rmse: 134.49625379646935
# Fold 34:
#   mse: 14855.9267578125
#   PiggyCast: area weighted rmse: 93.02485063154529
#   graphcast: area weighted rmse: 110.55704282204341
#   pangu: area weighted rmse: 118.468774182798
#   neuralgcm: area weighted rmse: 98.48156821145129
#   ifshres: area weighted rmse: 120.75965445288513
# Fold 35:
#   mse: 16527.572265625
#   PiggyCast: area weighted rmse: 100.6321080880706
#   graphcast: area weighted rmse: 119.78377560987654
#   pangu: area weighted rmse: 120.66792592027565
#   neuralgcm: area weighted rmse: 102.48303890234624
#   ifshres: area weighted rmse: 133.36114358079394
# Fold 36:
#   mse: 14481.3330078125
#   PiggyCast: area weighted rmse: 93.17461914389148
#   graphcast: area weighted rmse: 112.4682462666493
#   pangu: area weighted rmse: 115.2256228237179
#   neuralgcm: area weighted rmse: 98.93838973934155
#   ifshres: area weighted rmse: 119.78088093385878
# Fold 37:
#   mse: 15815.5986328125
#   PiggyCast: area weighted rmse: 99.7093204185575
#   graphcast: area weighted rmse: 121.23455998982443
#   pangu: area weighted rmse: 129.61373276528883
#   neuralgcm: area weighted rmse: 105.99879737864579
#   ifshres: area weighted rmse: 134.38224855857763
# Fold 38:
#   mse: 14211.7236328125
#   PiggyCast: area weighted rmse: 98.90995952629402
#   graphcast: area weighted rmse: 113.55860555779213
#   pangu: area weighted rmse: 118.95311390757873
#   neuralgcm: area weighted rmse: 104.30918315115977
#   ifshres: area weighted rmse: 125.31386485093375
# Fold 39:
#   mse: 16371.439453125
#   PiggyCast: area weighted rmse: 101.08911283592332
#   graphcast: area weighted rmse: 118.41905497586367
#   pangu: area weighted rmse: 124.9801746437583
#   neuralgcm: area weighted rmse: 108.93495205660166
#   ifshres: area weighted rmse: 121.76920147407877
# Fold 40:
#   mse: 14609.3388671875
#   PiggyCast: area weighted rmse: 92.68893876184227
#   graphcast: area weighted rmse: 107.60106255842535
#   pangu: area weighted rmse: 111.69381981227521
#   neuralgcm: area weighted rmse: 94.37092779072043
#   ifshres: area weighted rmse: 114.28263349901304
# Fold 41:
#   mse: 14824.6669921875
#   PiggyCast: area weighted rmse: 99.55680882429553
#   graphcast: area weighted rmse: 114.59092838688257
#   pangu: area weighted rmse: 124.61939955060073
#   neuralgcm: area weighted rmse: 106.7940679278517
#   ifshres: area weighted rmse: 127.48832881269666
# Fold 42:
#   mse: 13972.5205078125
#   PiggyCast: area weighted rmse: 91.77935053029356
#   graphcast: area weighted rmse: 108.55000519778072
#   pangu: area weighted rmse: 116.15199053027659
#   neuralgcm: area weighted rmse: 97.46560096069506
#   ifshres: area weighted rmse: 116.74674209969916
# Fold 43:
#   mse: 14737.7998046875
#   PiggyCast: area weighted rmse: 96.10522695548109
#   graphcast: area weighted rmse: 114.07934437196278
#   pangu: area weighted rmse: 120.51650869239897
#   neuralgcm: area weighted rmse: 106.39626117179372
#   ifshres: area weighted rmse: 121.55008332003325
# Fold 44:
#   mse: 13441.279296875
#   PiggyCast: area weighted rmse: 92.35382976447227
#   graphcast: area weighted rmse: 110.6138116739036
#   pangu: area weighted rmse: 124.22202602697624
#   neuralgcm: area weighted rmse: 99.45830330147065
#   ifshres: area weighted rmse: 118.09662661672036
# Fold 45:
#   mse: 11128.373046875
#   PiggyCast: area weighted rmse: 89.7114623279094
#   graphcast: area weighted rmse: 105.19007162948161
#   pangu: area weighted rmse: 115.46972373642289
#   neuralgcm: area weighted rmse: 98.73804525537972
#   ifshres: area weighted rmse: 119.14751925555616
# Fold 46:
#   mse: 12838.6044921875
#   PiggyCast: area weighted rmse: 95.02945044460012
#   graphcast: area weighted rmse: 111.64034483005383
#   pangu: area weighted rmse: 125.84289851881805
#   neuralgcm: area weighted rmse: 105.89638899096649
#   ifshres: area weighted rmse: 128.46778442362708
# Fold 47:
#   mse: 12116.935546875
#   PiggyCast: area weighted rmse: 93.56901328856645
#   graphcast: area weighted rmse: 109.81550213788007
#   pangu: area weighted rmse: 118.3320495528233
#   neuralgcm: area weighted rmse: 100.6314340483918
#   ifshres: area weighted rmse: 120.49618186506098
# Fold 48:
#   mse: 10266.0419921875
#   PiggyCast: area weighted rmse: 85.7094171711675
#   graphcast: area weighted rmse: 105.2287871524704
#   pangu: area weighted rmse: 106.59108695235513
#   neuralgcm: area weighted rmse: 94.94356694981977
#   ifshres: area weighted rmse: 109.29082174129898
# Fold 49:
#   mse: 9767.5361328125
#   PiggyCast: area weighted rmse: 84.15419900588124
#   graphcast: area weighted rmse: 108.61703320630694
#   pangu: area weighted rmse: 115.56762551895287
#   neuralgcm: area weighted rmse: 90.04509996819289
#   ifshres: area weighted rmse: 112.21916129118664
# Fold 50:
#   mse: 11290.8974609375
#   PiggyCast: area weighted rmse: 88.22686609937588
#   graphcast: area weighted rmse: 114.01419188554092
#   pangu: area weighted rmse: 120.84541657927147
#   neuralgcm: area weighted rmse: 94.98249754890665
#   ifshres: area weighted rmse: 118.12671605174803
# {48: {'PiggyCast': 62.21914826449831,
#       'graphcast': 69.46556019429909,
#       'ifshres': 74.58882984327866,
#       'neuralgcm': 60.4314984922077,
#       'pangu': 75.82875875527417},
#  72: {'PiggyCast': 99.98607898625964,
#       'graphcast': 115.11790194314993,
#       'ifshres': 124.75959000338975,
#       'neuralgcm': 104.3154221622194,
#       'pangu': 125.48051701255454}}

# %%
# @title Training and Evaluation Loop- Time series split : 60 Days Training, 3 Day Gap and  14 Days Testing

# Initialize xgb regressor
xgb = xgboost.XGBRegressor(random_state=42, device="cuda")

# Calculate Cross-Validation using 10 folds
cv_timeseries = TimeSeriesSplit(n_splits=20, max_train_size=32 * 64 * 2 * 60,
                                test_size= 32 * 64 * 2 * 14, gap=32 * 64 * 2 * 3)

# Lead Times
lead_times=[48, 72]

nested_scores = {} # Nested scores for each lead time
rmse_results = {} # rmse results for each lead time, models

for lead_time in lead_times:
  print(f"======Lead time: {lead_time}========")

  df_filtered = data_per_lead_time(full_df,lead_time)

  X = df_filtered[[f"graphcast_lt{lead_time}", f"pangu_lt{lead_time}",
                   f"neuralgcm_lt{lead_time}",
                  #  f"keisler_lt{lead_time}",
                   f"ifshres_lt{lead_time}", "longitude", "latitude"]]
  y = df_filtered["era5"]
  area_weight = df_filtered["area_weight"]

  print(f"Shape of x :{X.shape}")
  print(f"Shape of y : {y.shape}")

  # Nested Scores
  nested_score = cross_validate(xgb, X=X, y=y, cv=cv_timeseries,
                              scoring=('neg_mean_squared_error', 'r2'),
                              params={'sample_weight': area_weight}
                              )
  nested_scores[lead_time] = nested_score

  # Cross validation plot
  cross_validation_plot(df_filtered, cv_timeseries, lead_time)

  # RMSE
  rmse_result = train_and_evaluate(xgb, cv_timeseries,X,y, area_weight, lead_time)
  rmse_results[lead_time] = rmse_result

  # RMSE plots per model
  rmse_per_fold_plot(rmse_result, lead_time)

  # print nicely average RMSE per Leadtime
  average_scores = rmse_mean_per_lead_time_and_model(rmse_results)
  pprint(average_scores)
# Out:
# ======Lead time: 48========
# Shape of x :(1497088, 6)
# Shape of y : (1497088,)
# Train times Min Date: 2020-01-26 00:00:00 Train times Max Date:2020-03-25 12:00:00
# Test times Min Date: 2020-03-29 00:00:00 Test times Max Date:2020-04-11 12:00:00
# Train times Min Date: 2020-02-09 00:00:00 Train times Max Date:2020-04-08 12:00:00
# Test times Min Date: 2020-04-12 00:00:00 Test times Max Date:2020-04-25 12:00:00
# Train times Min Date: 2020-02-23 00:00:00 Train times Max Date:2020-04-22 12:00:00
# Test times Min Date: 2020-04-26 00:00:00 Test times Max Date:2020-05-09 12:00:00
# Train times Min Date: 2020-03-08 00:00:00 Train times Max Date:2020-05-06 12:00:00
# Test times Min Date: 2020-05-10 00:00:00 Test times Max Date:2020-05-23 12:00:00
# Train times Min Date: 2020-03-22 00:00:00 Train times Max Date:2020-05-20 12:00:00
# Test times Min Date: 2020-05-24 00:00:00 Test times Max Date:2020-06-06 12:00:00
# Train times Min Date: 2020-04-05 00:00:00 Train times Max Date:2020-06-03 12:00:00
# Test times Min Date: 2020-06-07 00:00:00 Test times Max Date:2020-06-20 12:00:00
# Train times Min Date: 2020-04-19 00:00:00 Train times Max Date:2020-06-17 12:00:00
# Test times Min Date: 2020-06-21 00:00:00 Test times Max Date:2020-07-04 12:00:00
# Train times Min Date: 2020-05-03 00:00:00 Train times Max Date:2020-07-01 12:00:00
# Test times Min Date: 2020-07-05 00:00:00 Test times Max Date:2020-07-18 12:00:00
# Train times Min Date: 2020-05-17 00:00:00 Train times Max Date:2020-07-15 12:00:00
# Test times Min Date: 2020-07-19 00:00:00 Test times Max Date:2020-08-01 12:00:00
# Train times Min Date: 2020-05-31 00:00:00 Train times Max Date:2020-07-29 12:00:00
# Test times Min Date: 2020-08-02 00:00:00 Test times Max Date:2020-08-15 12:00:00
# Fold 1:
#   mse: 5804.4599609375
#   PiggyCast: area weighted rmse: 61.718955981983356
#   graphcast: area weighted rmse: 73.26967257115749
#   pangu: area weighted rmse: 80.64946444297773
#   neuralgcm: area weighted rmse: 63.51443718492743
#   ifshres: area weighted rmse: 77.59091040500961
# Fold 2:
#   mse: 13222.6240234375
#   PiggyCast: area weighted rmse: 74.1288496331018
#   graphcast: area weighted rmse: 72.66352481670117
#   pangu: area weighted rmse: 81.77676507528979
#   neuralgcm: area weighted rmse: 60.92429963302961
#   ifshres: area weighted rmse: 76.49096788257647
# Fold 3:
#   mse: 5668.515625
#   PiggyCast: area weighted rmse: 59.35307086218736
#   graphcast: area weighted rmse: 69.55253602397016
#   pangu: area weighted rmse: 78.89377789319788
#   neuralgcm: area weighted rmse: 62.5520480746315
#   ifshres: area weighted rmse: 76.06622284788064
# Fold 4:
#   mse: 6443.7490234375
#   PiggyCast: area weighted rmse: 61.45721206943577
#   graphcast: area weighted rmse: 70.25378990590347
#   pangu: area weighted rmse: 76.50082655554775
#   neuralgcm: area weighted rmse: 61.65155848174878
#   ifshres: area weighted rmse: 77.68709762048174
# Fold 5:
#   mse: 8340.1904296875
#   PiggyCast: area weighted rmse: 69.1218912889257
#   graphcast: area weighted rmse: 70.65618867514956
#   pangu: area weighted rmse: 72.89174692161858
#   neuralgcm: area weighted rmse: 61.345840176559115
#   ifshres: area weighted rmse: 72.52543986979123
# Fold 6:
#   mse: 12259.427734375
#   PiggyCast: area weighted rmse: 76.37119526114438
#   graphcast: area weighted rmse: 68.9256601106413
#   pangu: area weighted rmse: 77.1006952812546
#   neuralgcm: area weighted rmse: 63.312797500456384
#   ifshres: area weighted rmse: 74.46708926517923
# Fold 7:
#   mse: 8697.474609375
#   PiggyCast: area weighted rmse: 68.71765594917332
#   graphcast: area weighted rmse: 67.12948260517251
#   pangu: area weighted rmse: 74.95417988324022
#   neuralgcm: area weighted rmse: 61.43953644706062
#   ifshres: area weighted rmse: 71.71321162070475
# Fold 8:
#   mse: 5746.328125
#   PiggyCast: area weighted rmse: 60.39894096360514
#   graphcast: area weighted rmse: 70.29357156626783
#   pangu: area weighted rmse: 78.74522193252014
#   neuralgcm: area weighted rmse: 62.43302614506842
#   ifshres: area weighted rmse: 75.5864649507571
# Fold 9:
#   mse: 7445.1201171875
#   PiggyCast: area weighted rmse: 63.51852116249329
#   graphcast: area weighted rmse: 68.36234859541459
#   pangu: area weighted rmse: 73.41677378429175
#   neuralgcm: area weighted rmse: 62.924791766697474
#   ifshres: area weighted rmse: 70.22466145310733
# Fold 10:
#   mse: 9086.0205078125
#   PiggyCast: area weighted rmse: 70.09185909845033
#   graphcast: area weighted rmse: 70.2437533952996
#   pangu: area weighted rmse: 75.76987727524963
#   neuralgcm: area weighted rmse: 60.91234459245292
#   ifshres: area weighted rmse: 75.37029685170722
# Fold 11:
#   mse: 6267.98583984375
#   PiggyCast: area weighted rmse: 60.13287792303427
#   graphcast: area weighted rmse: 70.49241430443924
#   pangu: area weighted rmse: 77.64280811372662
#   neuralgcm: area weighted rmse: 61.571053009144826
#   ifshres: area weighted rmse: 74.641183639471
# Fold 12:
#   mse: 5777.94287109375
#   PiggyCast: area weighted rmse: 58.95412822864885
#   graphcast: area weighted rmse: 69.69292840659666
#   pangu: area weighted rmse: 78.88233682805276
#   neuralgcm: area weighted rmse: 61.11892160583327
#   ifshres: area weighted rmse: 75.11920766947793
# Fold 13:
#   mse: 5701.17431640625
#   PiggyCast: area weighted rmse: 59.052216110380975
#   graphcast: area weighted rmse: 68.13616821666537
#   pangu: area weighted rmse: 70.9564583085572
#   neuralgcm: area weighted rmse: 59.1450976876793
#   ifshres: area weighted rmse: 74.00752789521091
# Fold 14:
#   mse: 5034.73681640625
#   PiggyCast: area weighted rmse: 58.10296098470249
#   graphcast: area weighted rmse: 72.66262282424073
#   pangu: area weighted rmse: 74.71152943251053
#   neuralgcm: area weighted rmse: 60.236861985452194
#   ifshres: area weighted rmse: 74.48167434310123
# Fold 15:
#   mse: 7802.67041015625
#   PiggyCast: area weighted rmse: 62.209437845951676
#   graphcast: area weighted rmse: 67.7925787011131
#   pangu: area weighted rmse: 70.31116907133502
#   neuralgcm: area weighted rmse: 58.27941951339398
#   ifshres: area weighted rmse: 70.34561351784355
# Fold 16:
#   mse: 6354.96142578125
#   PiggyCast: area weighted rmse: 60.8226520568791
#   graphcast: area weighted rmse: 70.15474369366137
#   pangu: area weighted rmse: 73.94658653967569
#   neuralgcm: area weighted rmse: 60.66557373377988
#   ifshres: area weighted rmse: 73.34635428239437
# Fold 17:
#   mse: 5044.42041015625
#   PiggyCast: area weighted rmse: 56.7620182450023
#   graphcast: area weighted rmse: 68.10818391258104
#   pangu: area weighted rmse: 74.76967160121927
#   neuralgcm: area weighted rmse: 59.573378873589654
#   ifshres: area weighted rmse: 72.49921324762603
# Fold 18:
#   mse: 4223.73681640625
#   PiggyCast: area weighted rmse: 54.716906176118805
#   graphcast: area weighted rmse: 65.6609216796408
#   pangu: area weighted rmse: 72.97604697377365
#   neuralgcm: area weighted rmse: 59.77002198704453
#   ifshres: area weighted rmse: 73.61491410628143
# Fold 19:
#   mse: 4015.185791015625
#   PiggyCast: area weighted rmse: 53.54275789151033
#   graphcast: area weighted rmse: 66.44146210471092
#   pangu: area weighted rmse: 70.39514727944815
#   neuralgcm: area weighted rmse: 57.917688575912806
#   ifshres: area weighted rmse: 71.20003792975801
# Fold 20:
#   mse: 3845.114501953125
#   PiggyCast: area weighted rmse: 51.851383862555885
#   graphcast: area weighted rmse: 68.64230970426283
#   pangu: area weighted rmse: 72.0873536070561
#   neuralgcm: area weighted rmse: 56.5358006215864
#   ifshres: area weighted rmse: 72.11969059185199
# {48: {'PiggyCast': 62.051274579764254,
#       'graphcast': 69.45674309067948,
#       'ifshres': 73.9548889995106,
#       'neuralgcm': 60.79122487980245,
#       'pangu': 75.36892184002714}}
# ======Lead time: 72========
# Shape of x :(1497088, 6)
# Shape of y : (1497088,)
# Train times Min Date: 2020-01-27 00:00:00 Train times Max Date:2020-03-26 12:00:00
# Test times Min Date: 2020-03-30 00:00:00 Test times Max Date:2020-04-12 12:00:00
# Train times Min Date: 2020-02-10 00:00:00 Train times Max Date:2020-04-09 12:00:00
# Test times Min Date: 2020-04-13 00:00:00 Test times Max Date:2020-04-26 12:00:00
# Train times Min Date: 2020-02-24 00:00:00 Train times Max Date:2020-04-23 12:00:00
# Test times Min Date: 2020-04-27 00:00:00 Test times Max Date:2020-05-10 12:00:00
# Train times Min Date: 2020-03-09 00:00:00 Train times Max Date:2020-05-07 12:00:00
# Test times Min Date: 2020-05-11 00:00:00 Test times Max Date:2020-05-24 12:00:00
# Train times Min Date: 2020-03-23 00:00:00 Train times Max Date:2020-05-21 12:00:00
# Test times Min Date: 2020-05-25 00:00:00 Test times Max Date:2020-06-07 12:00:00
# Train times Min Date: 2020-04-06 00:00:00 Train times Max Date:2020-06-04 12:00:00
# Test times Min Date: 2020-06-08 00:00:00 Test times Max Date:2020-06-21 12:00:00
# Train times Min Date: 2020-04-20 00:00:00 Train times Max Date:2020-06-18 12:00:00
# Test times Min Date: 2020-06-22 00:00:00 Test times Max Date:2020-07-05 12:00:00
# Train times Min Date: 2020-05-04 00:00:00 Train times Max Date:2020-07-02 12:00:00
# Test times Min Date: 2020-07-06 00:00:00 Test times Max Date:2020-07-19 12:00:00
# Train times Min Date: 2020-05-18 00:00:00 Train times Max Date:2020-07-16 12:00:00
# Test times Min Date: 2020-07-20 00:00:00 Test times Max Date:2020-08-02 12:00:00
# Train times Min Date: 2020-06-01 00:00:00 Train times Max Date:2020-07-30 12:00:00
# Test times Min Date: 2020-08-03 00:00:00 Test times Max Date:2020-08-16 12:00:00
# Fold 1:
#   mse: 16996.279296875
#   PiggyCast: area weighted rmse: 107.85067758111649
#   graphcast: area weighted rmse: 124.24322598322598
#   pangu: area weighted rmse: 138.2683927137097
#   neuralgcm: area weighted rmse: 118.48718467048657
#   ifshres: area weighted rmse: 130.20071497038109
# Fold 2:
#   mse: 24566.22265625
#   PiggyCast: area weighted rmse: 109.82539342991352
#   graphcast: area weighted rmse: 124.63007878989166
#   pangu: area weighted rmse: 136.71986483269285
#   neuralgcm: area weighted rmse: 105.18512844769032
#   ifshres: area weighted rmse: 131.35725643684688
# Fold 3:
#   mse: 16633.166015625
#   PiggyCast: area weighted rmse: 103.17000040190803
#   graphcast: area weighted rmse: 119.20200584161854
#   pangu: area weighted rmse: 131.39348642065426
#   neuralgcm: area weighted rmse: 112.63722873269602
#   ifshres: area weighted rmse: 130.57398337496403
# Fold 4:
#   mse: 17222.5546875
#   PiggyCast: area weighted rmse: 102.07893068854504
#   graphcast: area weighted rmse: 116.34549430314604
#   pangu: area weighted rmse: 129.67687174551455
#   neuralgcm: area weighted rmse: 106.4278865864765
#   ifshres: area weighted rmse: 131.92786592534065
# Fold 5:
#   mse: 16483.876953125
#   PiggyCast: area weighted rmse: 101.67220671172723
#   graphcast: area weighted rmse: 112.32593560438775
#   pangu: area weighted rmse: 118.87437709213039
#   neuralgcm: area weighted rmse: 105.0914986528348
#   ifshres: area weighted rmse: 121.00058887364885
# Fold 6:
#   mse: 25169.119140625
#   PiggyCast: area weighted rmse: 117.5980497163295
#   graphcast: area weighted rmse: 116.61076595897806
#   pangu: area weighted rmse: 131.66642773473612
#   neuralgcm: area weighted rmse: 113.58406819478347
#   ifshres: area weighted rmse: 128.19103703423374
# Fold 7:
#   mse: 17953.568359375
#   PiggyCast: area weighted rmse: 101.26949047908572
#   graphcast: area weighted rmse: 110.91710572355832
#   pangu: area weighted rmse: 126.26012977953107
#   neuralgcm: area weighted rmse: 108.26915683314735
#   ifshres: area weighted rmse: 122.06333526594875
# Fold 8:
#   mse: 16145.958984375
#   PiggyCast: area weighted rmse: 100.28769777328513
#   graphcast: area weighted rmse: 115.81736642415005
#   pangu: area weighted rmse: 129.95153521768248
#   neuralgcm: area weighted rmse: 106.95978760484593
#   ifshres: area weighted rmse: 125.41668623378942
# Fold 9:
#   mse: 18721.640625
#   PiggyCast: area weighted rmse: 102.73543822071476
#   graphcast: area weighted rmse: 116.26750487606586
#   pangu: area weighted rmse: 122.46167302190138
#   neuralgcm: area weighted rmse: 109.66455913200976
#   ifshres: area weighted rmse: 120.90745204705115
# Fold 10:
#   mse: 18708.689453125
#   PiggyCast: area weighted rmse: 103.62132109034319
#   graphcast: area weighted rmse: 116.51046302244443
#   pangu: area weighted rmse: 125.86326465337281
#   neuralgcm: area weighted rmse: 103.08786915656079
#   ifshres: area weighted rmse: 126.33583066740759
# Fold 11:
#   mse: 16948.626953125
#   PiggyCast: area weighted rmse: 97.39856151088799
#   graphcast: area weighted rmse: 114.34206370254114
#   pangu: area weighted rmse: 127.80237101006155
#   neuralgcm: area weighted rmse: 101.04987144518454
#   ifshres: area weighted rmse: 123.15073126195313
# Fold 12:
#   mse: 17287.97265625
#   PiggyCast: area weighted rmse: 101.09338101453298
#   graphcast: area weighted rmse: 115.6544997616252
#   pangu: area weighted rmse: 131.91290988562682
#   neuralgcm: area weighted rmse: 104.89767389951706
#   ifshres: area weighted rmse: 127.81262932289697
# Fold 13:
#   mse: 15619.7255859375
#   PiggyCast: area weighted rmse: 97.24777384505823
#   graphcast: area weighted rmse: 116.18360322707531
#   pangu: area weighted rmse: 117.97816005730644
#   neuralgcm: area weighted rmse: 100.72630795098581
#   ifshres: area weighted rmse: 126.75301585064632
# Fold 14:
#   mse: 15008.326171875
#   PiggyCast: area weighted rmse: 99.28570030034734
#   graphcast: area weighted rmse: 117.4593023820518
#   pangu: area weighted rmse: 124.39767487710756
#   neuralgcm: area weighted rmse: 105.15738380014359
#   ifshres: area weighted rmse: 129.92719779079638
# Fold 15:
#   mse: 15892.0166015625
#   PiggyCast: area weighted rmse: 97.58894439514584
#   graphcast: area weighted rmse: 113.13943000801885
#   pangu: area weighted rmse: 118.52331719590315
#   neuralgcm: area weighted rmse: 101.91343334334162
#   ifshres: area weighted rmse: 118.08526315147147
# Fold 16:
#   mse: 14850.7666015625
#   PiggyCast: area weighted rmse: 96.5532601453109
#   graphcast: area weighted rmse: 111.61134462277093
#   pangu: area weighted rmse: 120.46011715189748
#   neuralgcm: area weighted rmse: 102.23628591456179
#   ifshres: area weighted rmse: 122.23558355558322
# Fold 17:
#   mse: 13937.2998046875
#   PiggyCast: area weighted rmse: 94.40862953898159
#   graphcast: area weighted rmse: 112.35993980366554
#   pangu: area weighted rmse: 122.38329260493819
#   neuralgcm: area weighted rmse: 102.98572349346261
#   ifshres: area weighted rmse: 119.83579593209221
# Fold 18:
#   mse: 12095.3583984375
#   PiggyCast: area weighted rmse: 92.67623090206199
#   graphcast: area weighted rmse: 108.46316831807192
#   pangu: area weighted rmse: 120.76773618682965
#   neuralgcm: area weighted rmse: 102.37979972186774
#   ifshres: area weighted rmse: 123.89532472912093
# Fold 19:
#   mse: 11249.9765625
#   PiggyCast: area weighted rmse: 89.8549359400294
#   graphcast: area weighted rmse: 107.54659956357213
#   pangu: area weighted rmse: 112.61468325457467
#   neuralgcm: area weighted rmse: 97.8288465223595
#   ifshres: area weighted rmse: 115.03002556060362
# Fold 20:
#   mse: 10394.630859375
#   PiggyCast: area weighted rmse: 86.20998317503985
#   graphcast: area weighted rmse: 111.34831802468534
#   pangu: area weighted rmse: 118.23597332518261
#   neuralgcm: area weighted rmse: 92.54673108465235
#   ifshres: area weighted rmse: 115.21080940186921
# {48: {'PiggyCast': 62.051274579764254,
#       'graphcast': 69.45674309067948,
#       'ifshres': 73.9548889995106,
#       'neuralgcm': 60.79122487980245,
#       'pangu': 75.36892184002714},
#  72: {'PiggyCast': 100.12133034301823,
#       'graphcast': 115.04891079707727,
#       'ifshres': 124.49555636933228,
#       'neuralgcm': 105.0558212593804,
#       'pangu': 125.31061293806769}}
